# %% [markdown]
# <H1 style="text-align: center;font-size:30px ; font-family: 'Times New Roman'; color:#00008B"> Project Title</H1>

# %% [markdown]
# <p style="text-align: center;font-size:22px ;font-weight: bold ; font-family: 'Times New Roman'"> Indian Start-up Funding Analysis</p>

# %% [markdown]
# <H1 style="text-align: center;font-size:30px ; font-family: 'Times New Roman'; color: #00008B"> Project Description</H1>

# %% [markdown]
# In this project seeks to explore whhich start-ups receive the much funding in India
#
# Overview
# Start-ups are usually newly established companies or organizations in their early stages of development. Therefore, they are usually associated with many uncertainties and risks for their limited resources. Hence, they require significant funding and support to get off the ground. Investors provide start-ups and other ventures with the capital, popularly known as funding, to think big, grow rich, and leave a lasting impact. However, not all start-ups can thrive and flourish even after the funding. This has resulted in the question of what is necessary for a start-up to flourish. A common cliche is that Ideas, creativity, and execution are necessary for a start-up to flourish, but are they enough?
#
# Introduction
# In recent years, India has become a hub for innovation and entrepreneurship due to their pool of skilled entrepreneurs and a supportive government. However, that doesnt necessarily mean that every start-up in the Indian ecosystem,flourishes.Therefore, it is necessary for a start-up to look into the investors, funding, and the factors that separate the start_ups that flourishes, and those that fail after the funding. This project will analyze the funding received by start-ups in India from 2018 to 2021, which includes start-ups' details, funding details, funding amount, and investors' information. The mode of inquiry adapted for this project involved posing questions, examining the dataset for each year, and performing exploratory data analysis(EDA) to identify the trends and patterns in the funding data. By doing so, we hope to provide insights to our team on the best course of action when venturing in the Indian start-up ecosystem.

# %% [markdown]
# <H1 style="text-align: center;font-size:30px ; font-family: 'Times New Roman'; color: #00008B"> Questions :</H1>

# %% [markdown]
# 1. Which Sector receive the most funding?
# 2. What the trend of funding over the years with respect to location?
# 3. Which stage had the highest amount of funding?Who are the top 10 investors?
# 4. Which investor makes the highest investment?
# 5. Can the age of the startup affect the sum of money received from investors?

# %% [markdown]
# <H1 style="text-align: center;font-size:30px ; font-family: 'Times New Roman'; color: #00008B"> Hypothesis :</H1>

# %% [markdown]
# ###### NULL: Fintech startups do not have a higher success rate of being funded
#
# ###### ALTERNATE: Fintech startups have a higher success rate of being funded

# %% [markdown]
# <H1 style="text-align: center;font-size:30px ; font-family: 'Times New Roman'; color: #00008B"> Data Preparation :</H1>

# %% [markdown]
# ## Importing all Relevant Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
from summarytools import dfSummary
import warnings
warnings.filterwarnings("ignore")

sns.set_theme(style="whitegrid")

import os
import plotly.express as px
from scipy import stats

from scipy.stats import pearsonr

from scipy.stats import chi2_contingency
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# numpy and pandas will be used for data handling
# seaborn and matplotlib will be used for data visualization

# %% [markdown]
# ## Data Loading

# %%
# For CSV, use pandas.read_csv, this helps you to load the CSV file or data and to hande the dataframe
data_2018 = pd.read_csv("C:/Users/PROSPER/Desktop/azubi Africa/LP1/startup_funding2018.csv")
data_2019 = pd.read_csv("C:/Users/PROSPER/Desktop/azubi Africa/LP1/startup_funding2019.csv")
data_2020 = pd.read_csv("C:/Users/PROSPER/Desktop/azubi Africa/LP1/startup_funding2020.csv")
data_2021 = pd.read_csv("C:/Users/PROSPER/Desktop/azubi Africa/LP1/startup_funding2021.csv")

# %% [markdown]
# <H1 style="text-align: center;font-size:30px ; font-family: 'Times New Roman'; color: #00008B"> DATA CLEANING :</H1>
#
# <p style="text-align: center;font-size:17px ; font-family: 'Times New Roman';">
#     In this section, the following properties of the data loaded will be analysed:
# </p>
# <ul style="font-size:17px ; font-family: 'Times New Roman';">
#     <li> Data Types </li>
#     <li> Missing Data </li>
#     <li> Categorical data values </li>
#     <li> Continous data values </li>
#     <li> Duplicated data </li>
#     <li> Standard rule base check, that is, checks relating to industry standards, example email, dates, websites, currencies etc</li>

# %% [markdown]
# # 2018 Data Set

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
data_2018
# Out:
#                                           Company Name  \
# 0                                      TheCollegeFever
# 1                                      Happy Cow Dairy
# 2                                           MyLoanCare
# 3                                          PayMe India
# 4                                             Eunimart
# 5                                               Hasura
# 6                                            Tripshelf
# 7                                         Hyperdata.IO
# 8                                         Freightwalla
# 9                                   Microchip Payments
# 10                          BizCrum Infotech Pvt. Ltd.
# 11                                             Emojifi
# 12                                               Flock
# 13                                           Freshboxx
# 14                          Wide Mobility Mechatronics
# 15                                             Pitstop
# 16                                              Mihuru
# 17                                                Fyle
# 18                                            AppWharf
# 19                    Antariksh Waste Ventures Pvt ltd
# 20                                            Cogoport
# 21                                          PaisaDukan
# 22                                   Sleepy Owl Coffee
# 23                                            BlueJack
# 24                                           PregBuddy
# 25                                 AgNext Technologies
# 26                                               Pando
# 27                                             Mintifi
# 28                                             Carcrew
# 29                                             NicheAI
# 30                                        Chariot Tech
# 31              Ideal Insurance Brokers/ 121Policy.com
# 32                                             Loanzen
# 33                                  Mojro Technologies
# 34                                          Elemential
# 35                                           Loadshare
# 36                                             Yumlane
# 37                                       Kriger Campus
# 38                                          Pipa+Bella
# 39                                          Kaleidofin
# 40                                    Chakr Innovation
# 41                                         IndigoLearn
# 42                                              UClean
# 43                                            Coutloot
# 44                                           Letstrack
# 45                                             Pooltoo
# 46                                               Finzy
# 47                                          Fitternity
# 48                                               Keito
# 49                                  Tolet for Students
# 50                                          Chai Kings
# 51                                       Dainik Jagran
# 52                                           Playtoome
# 53                                      ONGO Framework
# 54                                            Notesgen
# 55                                      Arogya MedTech
# 56                                          Propshop24
# 57                                            myUpchar
# 58                            MissMalini Entertainment
# 59                                              Rooter
# 60                                           ZestMoney
# 61                                alphaics Corporation
# 62                                     MyDentistChoice
# 63                                            Sattviko
# 64                                           Sensibull
# 65                              Bombay Shaving Company
# 66                                            MedCords
# 67                                   University Living
# 68                                                 &ME
# 69                                             Enakshi
# 70                            Ultraviolette Automotive
# 71                                      Inthree Access
# 72                             BUGWORKS Research India
# 73                                         Guardian.in
# 74                                          PrestLoans
# 75                                             Wimoxez
# 76                                   India Accelerator
# 77                                            HappyEMI
# 78                                              Wishup
# 79                                           Hansel.io
# 80                                            Propelld
# 81                                          PivotRoots
# 82                                          ZiffyHomes
# 83                                             Carmesi
# 84                                           OckyPocky
# 85                                           Racetrack
# 86                                                 WHR
# 87                                   Asteria Aerospace
# 88                                            FabAlley
# 89                                            Tranzmeo
# 90                                            SBI Life
# 91                                  Studds Accessories
# 92                                         Design Cafe
# 93                    NoPaperForms Solutions Pvt. Ltd.
# 94                                    Rays Power Infra
# 95                                          AuthMetrik
# 96                                              Khidki
# 97                                       LetsTransport
# 98                              Next Digital Solutions
# 99                                      Portea Medical
# 100                                   Aavas Financiers
# 101                                             Swiggy
# 102                                         Milkbasket
# 103                              Nutrisattva (Proliva)
# 104                                              Toppr
# 105                                   Jagaran Microfin
# 106                                    Vivriti Capital
# 107                                        Be U Salons
# 108                                        Impact Guru
# 109                                           MobiKwik
# 110                                  Stones2Milestones
# 111                                           Generico
# 112                                 Adiuvo Diagnostics
# 113                                        DataTrained
# 114                                          OneAssist
# 115            Satin Creditcare Network Limited (SCNL)
# 116                            APAC Financial Services
# 117                                             Moglix
# 118                               SEDEMAC Mechatronics
# 119                                        MadGuy Labs
# 120                                       Dee Dee Labs
# 121                                             FLEECA
# 122                                            Shop101
# 123                                      FeedMyPockets
# 124                                           Housejoy
# 125                                              Ambee
# 126                                          FoodBuddy
# 127                                          Ninjacart
# 128                             Olly Smart Credit Card
# 129                                              Zestl
# 130                                             BYJU’S
# 131                                            Wakefit
# 132                                      Hero Electric
# 133                                Pentation Analytics
# 134                                        PerkFinance
# 135                                             Roposo
# 136                                      Plum Goodness
# 137                                            Drstore
# 138                                          Wow Venue
# 139                                             Chizel
# 140                                        OTO Capital
# 141                                             Boodmo
# 142                                             Khabri
# 143                                        MyNewCar.in
# 144                              HalaPlay Technologies
# 145                                        PlanetSpark
# 146                                          WheelsEMI
# 147  Forum for Innovation Incubation Research and E...
# 148                                                OYO
# 149                                              Quikr
# 150                                             Tabono
# 151                                           LearnApp
# 152                                         Shopkirana
# 153                                        Fric Bergen
# 154                                           Articbot
# 155                                        BuildSupply
# 156                                Fusion Microfinance
# 157                                    Any time Doctor
# 158                                        Go Payments
# 159                                      Guiddoo World
# 160                                         ION Energy
# 161                                             UnoTag
# 162                                          CivilCops
# 163                                         Rockmetric
# 164                                   Classworks India
# 165                                           Snapmint
# 166                                          artbandhu
# 167                                          Survaider
# 168                                              Credy
# 169                                             iChamp
# 170                                             Qandle
# 171                                      Avishkaar Box
# 172                                    Gegadyne Energy
# 173                                       HyperXchange
# 174                                           Deftouch
# 175                                          Doodhwala
# 176                                            DronaHQ
# 177                                            FastFox
# 178                                     BuyForexOnline
# 179                                          Colive.in
# 180                          Agricxlab Private Limited
# 181                                        Corefactors
# 182                                        Fincash.com
# 183                              Pandorum Technologies
# 184                                        Shirsa Labs
# 185                                           PetSutra
# 186                                           Awaaz De
# 187                                           PinkBlue
# 188                                            Eduvanz
# 189                                             Rupeek
# 190          Backpacker Panda Holidays Private Limited
# 191       Shape (School Health and Physical Education)
# 192                                             Placio
# 193                        Aviom India Housing Finance
# 194                                         GenRobotic
# 195                                        HeyHolidays
# 196                                          Pratilipi
# 197                                         SectorQube
# 198                                      Food Memories
# 199                                             ZAMROO
# 200                 Silversparro Technologies Pvt. Ltd
# 201                                  Creator’s Gurukul
# 202                                      Emflux Motors
# 203                     Tricog Health Services Pvt Ltd
# 204                                             Scapic
# 205                                            6Degree
# 206                               Chrysalis (EZ Vidya)
# 207                                           Ekincare
# 208                                              Streo
# 209                                              Groww
# 210                                    Cell Propulsion
# 211                                            Chezuba
# 212                      Ontrack Technologies Pvt. Ltd
# 213                                        Wealthtrust
# 214                                        Faclon Labs
# 215                                  Awign Enterprises
# 216                                           CollPoll
# 217                                        Zyla Health
# 218                                          Hubhopper
# 219                              Rubix108 Technologies
# 220                                          Workflexi
# 221                                             Streak
# 222                                             Kuants
# 223                                     NiYO Solutions
# 224                                        Hippo Video
# 225                                          Satvacart
# 226                                              Daaki
# 227                                          Simulanis
# 228                                     MY CHIRAAG CAB
# 229                                               WOTU
# 230                                           Flathalt
# 231                                      True Elements
# 232                             Trendlyne Technologies
# 233                                Planys Technologies
# 234                                         HealthPlix
# 235                                              dishq
# 236                                Entropik Technology
# 237                                               myHQ
# 238                                              Trell
# 239                            Kidovators (by GyanLab)
# 240                                    Log 9 Materials
# 241                                              VTION
# 242                                     HousingMan.com
# 243                           Steradian Semiconductors
# 244                                        RupeeCircle
# 245                                      Wooden Street
# 246                                            The Ken
# 247                                       SaffronStays
# 248                                            Vebbler
# 249                                               Foyr
# 250                                            MEngage
# 251                               Inner Being Wellness
# 252                                            Kobster
# 253                                          Wishberry
# 254                                             McXtra
# 255                                        Magic Crate
# 256                                          SmartVizX
# 257                                           MySEODoc
# 258           ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED
# 259                                         Scale Labs
# 260                                          HungerBox
# 261                                    Biryani By Kilo
# 262                     Wholesome Habits (EAT Anytime)
# 263                                            GoBumpr
# 264                                          Fixpocket
# 265                                           edureka!
# 266                    Hashtag Loyalty Private Limited
# 267                                        Wow Express
# 268                                            ZunRoof
# 269                                              Eggoz
# 270                                      Sqrrl Fintech
# 271                                         GalaxyCard
# 272                                           IndiQube
# 273                                          EGK Foods
# 274                                        NirogStreet
# 275                                              Pixr8
# 276                                         Nivesh.com
# 277                           Theranosis Life Sciences
# 278         Poshmiles Online Solutions Private Limited
# 279                                            Reculta
# 280                                            Orbo.ai
# 281                                Inntot Technologies
# 282                                       Zoctr Health
# 283                                         Hey Deedee
# 284                           DigiConnectt Technologys
# 285                                           Locus.sh
# 286                            Sports Flashes Pvt. Ltd
# 287                                              Inc42
# 288                                              Picxy
# 289                                             Huddle
# 290                                            Benepik
# 291                                       Cash Suvidha
# 292                                          Smartcoin
# 293                                    Carmel Organics
# 294                                           Roadcast
# 295                          Printline Media(ThePrint)
# 296                                 Creditas Solutions
# 297                                         UrbanPiper
# 298                                             Doxper
# 299                                         i2ifunding
# 300                                          ShakeDeal
# 301                                        HelloVerify
# 302                                              Fasal
# 303                                           CoinGeto
# 304                                      Avail Finance
# 305                                            Tripeur
# 306                                          Wedeterna
# 307                                            Stumagz
# 308                                           Doubtnut
# 309                                          MCaffeine
# 310                                        TrustCheckr
# 311                                       HealthAssure
# 312                                       Picture TIme
# 313                                             1Crowd
# 314                             Aarav Unmanned Systems
# 315                       Wellthy Therapeutics Pvt Ltd
# 316                                                Nua
# 317                                          Kuvera.in
# 318                                         Livehealth
# 319                                         Gramophone
# 320                                                Ora
# 321                                    Buddy4Study.com
# 322                                    Predible Health
# 323                    Syncremedies Healthcare Pvt Ltd
# 324                        Blueleaf Cyberspace Systems
# 325                                             Toffee
# 326                                         ORO Wealth
# 327                                         HealWell24
# 328                             Acko General Insurance
# 329                                         arzooo.com
# 330                               Bonphul Air Products
# 331                           DheeYantra Research Labs
# 332                                              Edyoo
# 333                                            Chtrbox
# 334          Aashiyaan Housing and Development Finance
# 335             BetterPlace Safety Solutions Pvt. Ltd.
# 336                                          Cashkumar
# 337                                          Rocketium
# 338                                      FreightBazaar
# 339                                               OPEN
# 340                                              mfine
# 341                                         Earth Food
# 342                                      Charcoal Eats
# 343                                            Wishfie
# 344                                    The Social Hook
# 345                                         FreightBro
# 346                                            Finwego
# 347                                           Cricnwin
# 348                                    TheCollegeFever
# 349     Wicked Ride Adventure Services Private Limited
# 350                                        Career Anna
# 351                       ERUDITUS Executive Education
# 352                                  Gaia Smart Cities
# 353                                         Square Off
# 354                                          UrbanClap
# 355                                            Hospals
# 356                      Kogta Financial India Limited
# 357                                        Perspectico
# 358                                   The Souled Store
# 359                  Hush - Speak Up. Make Work Better
# 360                                            Drivezy
# 361                                       Freyr Energy
# 362                            NIRAMAI Health Analytix
# 363                                           CloudSek
# 364                                            Lendbox
# 365                                            Verloop
# 366                                         Flickstree
# 367                                          Paymatrix
# 368                                   Idha Skin Clinic
# 369                                             InCred
# 370                                            Vedantu
# 371                                           Sportido
# 372                                   Stelis Biopharma
# 373                                           Magicpin
# 374                                          Try & Buy
# 375                                         Mech Mocha
# 376                                        Aye Finance
# 377                                            Aldopay
# 378                                Detect Technologies
# 379                                             Signzy
# 380                                           CashRich
# 381                                Cloudnine Hospitals
# 382                                CropIn Technologies
# 383                                           Billdesk
# 384                                            Yaantra
# 385                                          TECHBOOZE
# 386                                        HealthifyMe
# 387                                          hoi foods
# 388                                            Perpule
# 389       Royal Sundaram General Insurance Co. Limited
# 390                                         CleanseCar
# 391                                             DRIVEU
# 392                                             Spinny
# 393          Asset Reconstruction Company (India) Ltd.
# 394                                  Med365 Healthcare
# 395                                              Dunzo
# 396                        Mobile Premier League (MPL)
# 397                                      WalMart India
# 398                                               Cred
# 399                                             Meesho
# 400                                        BhaskarGuru
# 401                                               Gugu
# 402                                          FarmTaaza
# 403                                            Vizzbee
# 404                      BIGPHI TECHNOLOGIES PVT. LTD.
# 405                                             Mobycy
# 406                              Traveo Soft Pvt. Ltd.
# 407                                   Em Personal Care
# 408                                           Lucideus
# 409                                   Eupheus Learning
# 410                                         GamingMonk
# 411                                   Sukkhi Jewellery
# 412                                          INDwealth
# 413                                       Medikabazaar
# 414                                               NIRA
# 415                                 Duroflex Pvt. Ltd.
# 416                                            Clensta
# 417                                  Jetbrain Robotics
# 418                                          Medimetry
# 419                                         Healthkart
# 420                                Indiabulls Ventures
# 421                                            Vistara
# 422                                           ClearTax
# 423                                             Shuttl
# 424                                              GuruQ
# 425                                        Azure Power
# 426                                               Cube
# 427                                          RAHI Care
# 428                                             Mynvax
# 429                                          Loans4SME
# 430                                       UpCyclersLab
# 431                                  Cellerite Systems
# 432                                      Taru Naturals
# 433                                             LetsMD
# 434                                  Twenty Two Motors
# 435                                            Truebil
# 436                                          FarmersFZ
# 437                                            Worxogo
# 438                       Vivish Technologies (myGate)
# 439                               Singularity Dynamics
# 440                   Virtual MetalStreet(MetalStreet)
# 441                                    Veritas Finance
# 442                              Manjushree Technopack
# 443                                             GoZefo
# 444                                             Zomato
# 445                                   Innov8 Coworking
# 446                                             RevFin
# 447                                   Lavelle Networks
# 448                                          Blackbuck
# 449                                           Cardekho
# 450                                         ElasticRun
# 451                   Droom Technology Private Limited
# 452                                       Vogo Rentals
# 453                                          InnerChef
# 454                                            LivQuik
# 455                                             Disprz
# 456                                            9stacks
# 457                                              Origo
# 458                                        YourOwnROOM
# 459                                        Vahdam Teas
# 460                                            Spoofin
# 461                                       Strom Motors
# 462                                          PharmEasy
# 463                                            Licious
# 464                                      Stanza Living
# 465                                          docturnal
# 466                               Bounce (Metro Bikes)
# 467                            Technology 9 Labs (T9L)
# 468                                           Goals101
# 469                                 Satya MicroCapital
# 470             Ummeed Housing Finance Private Limited
# 471                                          StockEdge
# 472                                          Sequretek
# 473                   Avenues Payments India Pvt. Ltd.
# 474                                              Qbera
# 475                                       Urban Ladder
# 476      Planet11 eCommerce Solutions India (Avenue11)
# 477                                         DailyNinja
# 478                                     Iba Halal Care
# 479                                         Knocksense
# 480                                             Togedr
# 481                                         Parkwheels
# 482                                          ShareChat
# 483                                    Cyclops Medtech
# 484                                           Livspace
# 485                                          NewsBytes
# 486                                           Leena AI
# 487                                     Max Healthcare
# 488                                             GoBolt
# 489                                             GoGaga
# 490                                          Mate Labs
# 491                                           Furlenco
# 492                                                Ola
# 493                                           DocPrime
# 494                                CLP India Pvt. Ltd.
# 495                                          Xplorabox
# 496                                               Myra
# 497                                              Vokal
# 498                                             Kissht
# 499                                    Upwards Fintech
# 500                            Bon(Bonfleet Solutions)
# 501                                          Mamaearth
# 502                                         BabyChakra
# 503     Belstar Investment and Finance Private Limited
# 504                                            Naaptol
# 505                                  Moonshine Meadery
# 506                                             Verzeo
# 507                                             Haazri
# 508                                      Connect India
# 509                                            Flyrobe
# 510                                           Scholify
# 511                                            Dream11
# 512                                              srJna
# 513                                              Nykaa
# 514                                            Chaayos
# 515                                            Heelium
# 516                                           LT Foods
# 517                                         Multibashi
# 518                                         Cleardekho
# 519                                          Dailyhunt
# 520                                           SlicePay
# 521                                              Udaan
# 522                                  Happyeasygo Group
# 523                                             Mombay
# 524                                         Droni Tech
# 525                                            Netmeds
#
#                                               Industry  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# 5                     Cloud Infrastructure, PaaS, SaaS
# 6                       Internet, Leisure, Marketplace
# 7                                      Market Research
# 8         Information Services, Information Technology
# 9                                      Mobile Payments
# 10                                          B2B, Shoes
# 11                                            Internet
# 12   Apps, Collaboration, Developer Platform, Enter...
# 13                                       Food Delivery
# 14                               Industrial Automation
# 15         Automotive, Search Engine, Service Industry
# 16                           Finance, Internet, Travel
# 17   Accounting, Business Information Systems, Busi...
# 18   Artificial Intelligence, Product Search, SaaS,...
# 19                Internet of Things, Waste Management
# 20   Air Transportation, Freight Service, Logistics...
# 21                                  Financial Services
# 22                                   Food and Beverage
# 23                                 Autonomous Vehicles
# 24   Enterprise Software, Health Care, Hospital, Pa...
# 25           Agriculture, Analytics, Big Data, Farming
# 26                  Logistics, Supply Chain Management
# 27                         Financial Services, Lending
# 28             Automotive, Marketplace, Online Portals
# 29                             Artificial Intelligence
# 30              Internet of Things, Telecommunications
# 31                                           Insurance
# 32                                  Financial Services
# 33   Information Technology, Logistics, Supply Chai...
# 34    Blockchain, Developer Tools, Enterprise Software
# 35   Industrial Automation, Logistics, Supply Chain...
# 36        Food and Beverage, Food Delivery, Snack Food
# 37                                           Education
# 38                E-Commerce, Fashion, Jewelry, Retail
# 39                                  Financial Services
# 40                                    Renewable Energy
# 41                               E-Learning, Education
# 42   Clean Energy, CleanTech, Laundry and Dry-cleaning
# 43                         E-Commerce, Fashion, Mobile
# 44          Apps, Messaging, Navigation, Public Safety
# 45                                      Transportation
# 46                         Financial Services, Lending
# 47                      Fitness, Health Care, Wellness
# 48   Artificial Intelligence, Machine Learning, Saa...
# 49                                         Hospitality
# 50                              Food and Beverage, Tea
# 51             Media and Entertainment, News, Outdoors
# 52   Broadcasting, Media and Entertainment, Music, ...
# 53   B2B, Information Services, Information Technology
# 54   EdTech, Education, Enterprise Software, Peer t...
# 55                                Health Care, Medical
# 56                                          E-Commerce
# 57                     Health Care, Hospital, Wellness
# 58                                                   —
# 59                                              Sports
# 60                 Big Data, Consumer Lending, FinTech
# 61            Cloud Computing, Computer, Semiconductor
# 62                Health Care, Medical, Pharmaceutical
# 63                             Food Processing, Retail
# 64                                    Trading Platform
# 65                    Consumer Goods, Lifestyle, Men's
# 66                                            Wellness
# 67                                           Education
# 68       Food and Beverage, Food Processing, Nutrition
# 69                                             Fashion
# 70        Automotive, Electric Vehicle, Energy Storage
# 71                          Consulting, Retail, Social
# 72   Biotechnology, Life Science, Pharmaceutical, P...
# 73                                         Health Care
# 74   Credit, Financial Services, FinTech, Personal ...
# 75                                            Internet
# 76                  Communities, Coworking, Incubators
# 77               Consumer, Financial Services, FinTech
# 78   Consumer Applications, Information Services, L...
# 79   Mobile, Mobile Apps, Personalization, Test and...
# 80              Education, Financial Services, FinTech
# 81          Advertising, Consulting, Digital Marketing
# 82           Marketplace, Real Estate, Rental Property
# 83                                         Health Care
# 84                   E-Learning, Internet, Video Games
# 85     Artificial Intelligence, Cloud Computing, Video
# 86                 Health Care, Information Technology
# 87                                           Aerospace
# 88                      E-Commerce, Fashion, Lifestyle
# 89   Artificial Intelligence, Business Intelligence...
# 90                                           Insurance
# 91                                          E-Commerce
# 92   Home Decor, Home Improvement, Home Renovation,...
# 93       EdTech, Education, Information Services, SaaS
# 94                                       Energy, Solar
# 95   B2B, Biometrics, Cyber Security, Fraud Detecti...
# 96                     Artificial Intelligence, Social
# 97                   Logistics, Transportation, Travel
# 98        Digital Marketing, SEM, SEO, Web Development
# 99                      Health Care, Hospital, Medical
# 100                        Finance, Financial Services
# 101           Food Delivery, Food Processing, Internet
# 102            E-Commerce, Food and Beverage, Internet
# 103  Fitness, Food and Beverage, Health Care, Nutri...
# 104            EdTech, Education, Knowledge Management
# 105                                                  —
# 106                                 Financial Services
# 107                     Apps, Beauty, Consumer, Retail
# 108  Creative Agency, Crowdfunding, EdTech, Health ...
# 109  Consumer Lending, Financial Services, FinTech,...
# 110            E-Learning, Education, Higher Education
# 111               Health Care, Medical, Pharmaceutical
# 112                                 Health Diagnostics
# 113                                  EdTech, Education
# 114                 Financial Services, SaaS, Security
# 115   Banking, Finance, Financial Services, Non Profit
# 116                        Finance, Financial Services
# 117                            B2B, E-Commerce, Mobile
# 118     Automotive, Electric Vehicle, Renewable Energy
# 119                                         E-Learning
# 120  Embedded Systems, Health Care, Medical, Produc...
# 121                                                  —
# 122                         Apps, E-Commerce, Internet
# 123            Advertising, Human Resources, Marketing
# 124           Beauty, Fitness, Home Services, Internet
# 125         Health Care, Medical Device, Public Safety
# 126         Food Delivery, Online Portals, Restaurants
# 127               AgTech, B2B, Supply Chain Management
# 128  Credit Cards, Finance, Mobile Apps, Mobile Pay...
# 129                                           Software
# 130  EdTech, Education, Higher Education, Secondary...
# 131                              Manufacturing, Retail
# 132                                      Manufacturing
# 133  Information Services, Information Technology, ...
# 134                          Consumer Lending, FinTech
# 135                       Internet, Social Network, TV
# 136                                Beauty, Health Care
# 137                                           Hospital
# 138                                             Events
# 139         3D Printing, Manufacturing, Product Design
# 140                                         Automotive
# 141                                 Automotive, Retail
# 142                                        Apps, Audio
# 143                             Automotive, E-Commerce
# 144      Digital Entertainment, Fantasy Sports, Sports
# 145                      E-Learning, EdTech, Education
# 146                                                  —
# 147           Funding Platform, Incubators, Non Profit
# 148                Hospitality, Hotel, Leisure, Travel
# 149  Classifieds, Internet, Marketplace, Rental Pro...
# 150                                             Sports
# 151              Banking, E-Learning, Trading Platform
# 152                         E-Commerce, Mobile, Retail
# 153                                                  —
# 154    Artificial Intelligence, Information Technology
# 155  Enterprise Resource Planning (ERP), Informatio...
# 156               Banking, Finance, Financial Services
# 157                                           Software
# 158       Information Services, Information Technology
# 159                     Audio, Mobile, Tourism, Travel
# 160             Energy, Energy Storage, Infrastructure
# 161                            Artificial Intelligence
# 162       Government, Information Technology, Software
# 163                             Information Technology
# 164  Education, Information Technology, Internet, M...
# 165  Consumer Lending, Financial Services, Lending,...
# 166  Digital Media, Internet, Media and Entertainme...
# 167  Business Intelligence, Customer Service, Marke...
# 168       Credit, Financial Services, FinTech, Lending
# 169                                         E-Learning
# 170                                           Software
# 171                     Children, Education, Parenting
# 172        Automotive, Battery, Energy, Energy Storage
# 173                E-Commerce, Mobile, Sharing Economy
# 174                                                  —
# 175               Food Delivery, Organic, Organic Food
# 176                                             Mobile
# 177                                             Rental
# 178                                             Travel
# 179                                           Consumer
# 180                          B2B, Farming, Marketplace
# 181                                                  —
# 182                                  Wealth Management
# 183                                      Biotechnology
# 184                        Education, Gaming, Training
# 185                                         Veterinary
# 186  Internet, Mobile, Social Entrepreneurship, Tel...
# 187     Health Care, Hospital, Supply Chain Management
# 188                        Finance, Financial Services
# 189                        Financial Services, Lending
# 190                                    Tourism, Travel
# 191                                          Education
# 192                           Hospitality, Real Estate
# 193                                            Finance
# 194                                    Market Research
# 195                                    Tourism, Travel
# 196    Digital Media, EBooks, Publishing, Reading Apps
# 197  Consumer Electronics, Embedded Systems, Hardwa...
# 198                 Food and Beverage, Food Processing
# 199                    Internet, Marketplace, Shopping
# 200  Analytics, Computer Vision, Enterprise Softwar...
# 201                        Facilities Support Services
# 202               Automotive, Electric Vehicle, Energy
# 203  Health Care, Health Diagnostics, Predictive An...
# 204          Cloud Computing, Computer, SaaS, Software
# 205                         Fashion, Lifestyle, Retail
# 206                                          Education
# 207                                            Medical
# 208                                    Music Streaming
# 209                Finance, Impact Investing, Internet
# 210                                                  —
# 211                  Internet, Social Entrepreneurship
# 212                                             Retail
# 213             Finance, Impact Investing, Mobile Apps
# 214                Cloud Computing, Computer, Software
# 215  Business Development, Market Research, Outsour...
# 216                                          Education
# 217                           Health Care, Hospitality
# 218                      Internet, Social News, Sports
# 219                             Information Technology
# 220                                    Human Resources
# 221                                 Financial Services
# 222                                 Financial Services
# 223               Finance, Financial Services, FinTech
# 224  Customer Service, Software, Video, Video Strea...
# 225                        E-Commerce, Food Processing
# 226                                        Health Care
# 227                                           Training
# 228                                             Travel
# 229                                  Food and Beverage
# 230                                                  —
# 231  Dietary Supplements, Food and Beverage, Health...
# 232                                 Financial Services
# 233               Manufacturing, Oil and Gas, Robotics
# 234                     Fitness, Health Care, Wellness
# 235                                                  —
# 236  Artificial Intelligence, Computer, Machine Lea...
# 237  Collaboration, Communities, Coworking, Sharing...
# 238                                                  —
# 239                 Big Data, EdTech, Machine Learning
# 240                                     Nanotechnology
# 241  Analytics, Audio, Digital Media, Innovation Ma...
# 242                                                  —
# 243                                                  —
# 244          Financial Services, Lending, Peer to Peer
# 245  E-Commerce, Furniture, Home Decor, Interior De...
# 246                                      Digital Media
# 247                                                  —
# 248        File Sharing, Personalization, Social Media
# 249                        Home Decor, Interior Design
# 250           Health Care, Medical Device, Mobile Apps
# 251                                                  —
# 252  E-Commerce, Facilities Support Services, Procu...
# 253          Crowdfunding, Finance, Financial Services
# 254             Finance, Financial Services, Insurance
# 255                Children, Education, Online Portals
# 256                          Software, Virtual Reality
# 257                                                  —
# 258                                                  —
# 259                                                  —
# 260              B2B, Food and Beverage, Food Delivery
# 261  Catering, Food and Beverage, Food Delivery, Fo...
# 262                      Food and Beverage, Snack Food
# 263                     Automotive, E-Commerce, Mobile
# 264  Computer, Digital Marketing, Facilities Suppor...
# 265  Android, Big Data, Blockchain, Cloud Computing...
# 266  Analytics, CRM, Loyalty Programs, Machine Lear...
# 267      Delivery, Information Technology, Mobile Apps
# 268         Environmental Consulting, Renewable Energy
# 269                 Food and Beverage, Food Processing
# 270  Big Data, Business Intelligence, Financial Ser...
# 271               Finance, Financial Services, FinTech
# 272  Commercial Real Estate, Coworking, Office Admi...
# 273  Food and Beverage, Food Processing, Organic Fo...
# 274  Apps, Health Care, Internet, Mobile Apps, Pers...
# 275  Digital Media, Incubators, Social Entrepreneur...
# 276             Finance, Financial Services, Marketing
# 277  Biotechnology, Health Care, Life Science, Medi...
# 278                                             Travel
# 279                         Education, Human Resources
# 280                                           Internet
# 281                               Consumer Electronics
# 282           Apps, Health Care, Hospital, Mobile Apps
# 283      Delivery Service, Logistics, Service Industry
# 284       Information Services, Information Technology
# 285  Big Data, Data Visualization, Logistics, Software
# 286  Basketball, Cricket, Cycling, eSports, Fitness...
# 287          Media and Entertainment, News, Publishing
# 288                                           Internet
# 289                                         Consulting
# 290                                    Human Resources
# 291                                            Finance
# 292  Big Data, Financial Services, Machine Learning...
# 293                 Agriculture, AgTech, Manufacturing
# 294                                                  —
# 295                    Digital Media, News, Publishing
# 296                                 Financial Services
# 297                                           Software
# 298                              Health Care, Hospital
# ...
# 246  The Ken is India’s first subscriptions-only bu...
# 247  SaffronStays connects travellers to India's In...
# 248                A personal network for close people
# 249  Foyr.com is India's first online, automated in...
# 250  MEngage is a mass consumer engagement applicat...
# 251  Inner Being Wellness manufactures beauty, well...
# 252  Kobster is a pioneer of B2B eProcurement and a...
# 253  Wishberry is a rewards-based crowdfunding plat...
# 254     McXtra is a digital insurance broking startup.
# 255  Magic Crate is a theme based stimulating, fun ...
# 256          It is a Virtual Reality Solutions StartUp
# 257  SEO, PPC, Search Engine Marketing, Social Medi...
# 258                           Digital Marketing Agency
# 259  Scale Labs is a cross border e-commerce soluti...
# 260  HungerBox is a full stack B2B F&B technology c...
# 261  BBK delivers both authentic taste of Hyderabad...
# 262  Wholesome Habits (EAT Anytime) is a healthy sn...
# 263            Car Service and Bike Service Mobile App
# 264             Fixpocket is a internet-based startup.
# 265  Edureka is the fastest growing online learning...
# 266  Hashtag Loyalty is a customer engagement and m...
# 267  WOW, as customers react to his studiously taug...
# 268        ZunRoof is a rooftop focused solar startup.
# 269  Eggoz is a full-stack layer poultry business o...
# 270                                   Personal Finance
# 271  GalaxyCard is a mobile based Instant credit card.
# 272  IndiQube is a provider of co-working spaces ba...
# 273  A food processing enterprise registered with S...
# 274  NirogStreet is an Ayurvedic doctor discovery a...
# 275  Pixr8 is a global media platform dedicated to ...
# 276  Nivesh.com is a mass market mutual funds inves...
# 277  A fully functioning cell culture facility and ...
# 278  Poshmiles aims to help point travellers to lon...
# 279            A campus recruitment solution provider.
# 280  Orbo is a computer vision and deep facial tech...
# 281  Inntot Technologies, is a technology driven co...
# 282  Zoctr Health Network is a first-of-its kind pa...
# 283  Hey Deedee is a Mumbai-based company that prov...
# 284  A technology company focused on introducing pr...
# 285  Locus is an intelligent logistics automation p...
# 286  Sports Flashes operates a sports content app t...
# 287  Inc42 is one of the leading tech media publica...
# 288  A stock photo startup based in Amravati, Andhr...
# 289                     A coworking incubator Company.
# 290                            HR Technology start-up.
# 291  Cash Suvidha is an Digital Lending Platform th...
# 292  Providing financial access to the millions of ...
# 293  Carmel Organics is an India-based herb company...
# 294  Transforming the way businesses deliver. Work-...
# 295                           A digital news platform.
# 296  Creditas was set-up in 2015 with an aim to hel...
# 297  UrbanPiper offers restaurants and chains with ...
# 298  Doxper is Health tech startup which has create...
# 299  i2ifunding is an online marketplace that conne...
# 300                               Home of B2B Commerce
# 301  HelloVerify is an online background check plat...
# 302       Climate Smart Precision Agriculture Platform
# 303  CoinGeto is one of India’s most advanced digit...
# 304  Avail is a mobile-first platform aiming to fin...
# 305  Radical Travel Automation - Cloud Based Corpor...
# 306  Wedeterna is a new-age, personalised and fresh...
# 307  Stumagz is about connecting with Stories Stuma...
# 308                 Gurgaon based E-learning platform.
# 309  MCaffeine is India's First Caffeine Infuse Per...
# 310  A Bengaluru-based fraud analytics solution pro...
# 311  HealthAssure provides access to Discounted & H...
# 312  Operator of low-cost mobile cinema theatres in...
# 313  Equity crowd funding platform focused on conne...
# 314    Professional Drones for Enterprise Applications
# 315  Wellthy is a digital therapeutics company focu...
# 316  Nua is an e-commerce and feminine care brand p...
# 317    An online platform for mutual fund investments.
# 318  Livehealth is an end-to-end collaborative repo...
# 319            An agricultural inputs startup Company.
# 320  Ora is an online marketplace of unique accommo...
# 321  Buddy4Study is the best scholarship search eng...
# 322            Healthcare devices for cancer detection
# 323  Syncremedies is an Integrated Medicine service...
# 324  Bluleaf Cyberspace is Cloud Based Software Com...
# 325  Toffee is a bite size, micro-event & contextua...
# 326                  Online wealth management platform
# 327  HealWell24 is India's emerging technology-empo...
# 328  Acko General Insurance is a digital insurance ...
# 329  E-commerce website promising the best price on...
# 330                       A clean tech product Company
# 331  DheeYantra is building a cognitive conversatio...
# 332  Edyoo.com is a technology platform that offers...
# 333  Chtrbox connects social media influencers with...
# 334  Provide housing finance to those in the inform...
# 335  BetterPlace provides businesses with contracto...
# 336  A P2P Lending Platform connecting millions of ...
# 337              Easy video creation for social media.
# 338  FreightBazaar.com is an online platform that c...
# 339                  Open up to a new world of Banking
# 340                    Hospital & Health Care Start up
# 341             Earth Food is a healthy Food Start Up.
# 342  Charcoal Eats aims to bring Dominos style stan...
# 343  A platform for people to express their opinion...
# 344  Fast growing Influencer Marketing platform in ...
# 345                   Software for the new-age freight
# 346  Finwego partners with Small and Medium Busines...
# 347  Cricnwin is a Gurugram - based Fan Engagement ...
# 348  TheCollegeFever is a hub for fun, fiesta and f...
# 349                Peer-to-Peer motor vehicles sharing
# 350               India's Go to Career Commerce Portal
# 351  Eruditus, promoted by Alumni of INSEAD and oth...
# 352  Gaia Smart Cities is an early leader in the ra...
# 353                             Delivering Imagination
# 354  UrbanClap is India's leading managed marketpla...
# 355              Hospals is a medical tourism company.
# 356  Kogta Financial (India) Ltd is a retail-focuse...
# 357                   An Education Management startup.
# 358  The Souled Store bring to you awesome t-shirts...
# 359    Enabling diversity of opinions in organizations
# 360  Drivezy is India's largest vehicle sharing pla...
# 361  Freyr Energy is a company that provides full s...
# 362  NIRAMAI has developed a novel breast cancer sc...
# 363  Cloudsek is an Infosec Risk assessment company...
# 364  Lendbox is India's leading peer-to-peer lendin...
# 365  Verloop is an automated customer support and e...
# 366  Flickstree is a smart video content aggregator...
# 367  India's Leading Property Rent management platform
# 368  Idha skin clinic jayanagar is dedicated to res...
# 369  InCred Finance is a mumbai-based non-banking f...
# 370  Vedantu provides personalized LIVE Online Tuto...
# 371  Sportido is a sports discovery app that helps ...
# 372  Stelis Biopharma is a vertically integrated bi...
# 373  Magicpin is a platform where users and merchan...
# 374                                          Try & Buy
# 375  Mech Mocha is a mobile gaming startup based in...
# 376  Aye Finance provides financial services to mic...
# 377  Mobile Wallet Focusing on hassle free checkout...
# 378        Completely automated remote control system.
# 379  Signzy are creating 'building blocks for a Dig...
# 380                    A Mumbai-based fin-tech startup
# 381  Cloudnine is an Indian chain of women and chil...
# 382  To discover, develop and deliver innovative so...
# 383  BillDesk, a property of IndiaIdeas.com Ltd. wa...
# 384  Yaantra, India’s leading mobile phone repair, ...
# 385  Techbooze[1] "AN OPEN FORUM" is an educational...
# 386  HealthifyMe is an application that allows its ...
# 387  India's first hotel dedicated food brand which...
# 388  Perpule is a self-checkout product for retail ...
# 389  Royal Sundaram provides comprehensive insuranc...
# 390  CleanseCar is a company provides Washing and R...
# 391  DriveU is a convenient and a quick way of gett...
# 392  Used cars marketplace in India. Ushering new e...
# 393  Asset Reconstruction Company (India) Ltd. oper...
# 394  Wellness, Specialised Testing, Healthcare at Home
# 395  Dunzo is an app that connects you with the nea...
# 396  Mobile Premier League(MPL) is a skill based E-...
# 397  Wal-Mart India Private Limited is a wholly own...
# 398  Cred is a platform to celebrate and reward the...
# 399  Meesho is an online reseller network of housew...
# 400        Bhaskarguru.com is your local search Engine
# 401  Gugu designs & Sells all Electric Connected Tw...
# 402  Farm Taaza provides expert advice to the farme...
# 403  Autonomous Drone Solutions for last mile deliv...
# 404  BIGPHI technologies is the India's first techn...
# 405           India's 1st Dockless Bicycle Sharing App
# 406      AI based Business Travel & Expense management
# 407  Em Personal Care is a Cosmetic products manufa...
# 408  Lucideus is a cybersecurity company that offer...
# 409  Eupheus Learning offers a seamless integrated ...
# 410  GamingMonk is an eSports gaming company based ...
# 411  Sukkhi Jewellery is a Contemporary fashion jew...
# 412  INDwealth is an Artificial Intelligence (AI) p...
# 413  India's largest medical and surgical supplies ...
# 414  NIRA promotes financial inclusion by creating ...
# 415  Duroflex Pvt. Ltd. operates as a dominant matt...
# 416  A biotechnology start-up was incorporated to i...
# 417  Jetbrain Robotics is Hong Kong / Gurgaon based...
# 418  MediMetry is an online platform where patients...
# 419    The one stop shop for health, fitness & beauty.
# 420  Indiabulls Ventures Limited is one of India’s ...
# 421  Vistara is a joint venture of Tata Sons Limite...
# 422  ClearTax India helps individuals prepare and e...
# 423  Shuttl provides an app-based office shuttle se...
# 424  A one of its kind digital integrated platform ...
# 425  Azure Power produces and distributes solar pow...
# 426  Cube is consumer banking focused fintech company.
# 427                RAHI Care is a Health Care company.
# 428                       Mynvax is a biotech Company.
# 429      Loans4SME is an alternative lending platform.
# 430  UpCyclersLab is a startup that makes sustainab...
# 431  Cellerite Systems is a charging solutions prov...
# 432  Taru Naturals is a network that connects farme...
# 433  LetsMD.com is a marketplace for elective surge...
# 434  Twenty Two Motors aim of making cutting edge E...
# 435  Truebil is a team of young, highly motivated p...
# 436  FarmersFZ is an online venture for fresh and s...
# 437  worxogo’s is a pioneering persuasive technolog...
# 438  India's leading mobile based security manageme...
# 439  Singularity Dynamics is a Chip-design testing ...
# 440  Virtual MetalStreet(Metalstreet) is a B2B mark...
# 441  Veritas Finance has been promoted with a prima...
# 442  Manjushree Technopack is a Rigid plastics pack...
# 443  Startup working on a white space in the eComme...
# 444  Zomato is a search app offering detailed infor...
# 445  Innov8 is a Y- Combinator backed company that ...
# 446               RevFin is a digital lending company.
# 447  Lavelle Networks provides Software Defined WAN...
# 448   Blackbuck is a logistics startup based in India.
# 449  Cardekho is a car search venture that helps us...
# 450  ElasticRun develops an online system that impr...
# 451  Droom is a marketplace for automobiles and aut...
# 452  Vogo is a dockless scooter rental company in I...
# 453  InnerChef is an online food discovery and deli...
# 454  LivQuik was incorporated with the vision to si...
# 455  Disprz is a one-of-its-kind “knowledge-tech” s...
# 456                             Online gaming startup.
# 457  Origo Commodities, a complete post-harvest man...
# 458  Good quality, strategically located homes clos...
# 459  Vahdam Teas is a vertically integrated online-...
# 460  A social networking app that lets you create a...
# 461    Strom Motors is a smart urban mobility Company.
# 462  PharmEasy - Indias largest healthcare delivery...
# 463  Licious is an online meat and fish ordering st...
# 464  Stanza Living is a co-living platform created ...
# 465  Docturnal, an online platform, enables individ...
# 466  Bounce (formerly Metro Bikes) is an urban mobi...
# 467  Technology 9 Labs is an Information Technology...
# 468  Goals101 is a one of the fastest growing big-d...
# 469     New Delhi-based non-banking financial company.
# 470             Ummeed Housing Finance Private Limited
# 471  StockEdge is a unique platform, which is 100% ...
# 472            Sequretek is a cyber security start-up.
# 473  Avenues Payments is an IT solutions provider f...
# 474  Qbera is a managed marketplace for unsecured p...
# 475  Urban Ladder is a Bangalore-based online furni...
# 476  Planet11 is backed by SK Planet, which is a pa...
# 477  Daily Ninja, a mobile app that delivers daily ...
# 478       Iba Halal Care is a cosmetics brand company.
# 479    Knocksense is a fast growing lifestyle website.
# 480  Togedr is an activity discovery & booking plat...
# 481  Parkwheels aims at solving the big, bad & unse...
# 482  ShareChat is a social networking and regional ...
# 483  Medtech startup working on clinical and wearab...
# 484  Livspace is the new online shopping destinatio...
# 485  NewsBytes provides your everyday news in a con...
# 486  Leena is smart AI powered HR companion dedicat...
# 487  Max Healthcare is one of the leading chain of ...
# 488                  Delhi-based logistics technology.
# 489  GoGaga is a new age dating app that has remove...
# 490  Mate Labs is a machine learning solutions plat...
# 491  Furlenco is a Bangalore-based company that off...
# 492  Ola is a mobile app that brings together cab d...
# 493  DocPrime offers a one-stop healthcare solution...
# 494  CLP India Pvt. Ltd. is a foreign investor in t...
# 495  Xplorabox is as an educational activity box su...
# 496  Myra is a unique solution of technology and op...
# 497  India's Largest Peer-to-Peer Knowledge Sharing...
# 498  Kissht is a financial technology platform that...
# 499                 Upwards Fintech financial company.
# 500  Bon, a Pune-based FinTech firm was created to ...
# 501  Mamaearth is an online retailer specializing i...
# 502  BabyChakra is India's largest & most loved pla...
# 503  Belstar Investment and Finance Private Limited...
# 504  Koku Gamer is an online platform that offers g...
# 505        Moonshine Meadery is a first craft meadery.
# 506            Verzeo is anAI-focussed edtech startup.
# 507  Haazri is a tea and snack quick service restau...
# 508  To create pervasive network where connections ...
# 509  Flyrobe is an on-demand apparel rental platfor...
# 510                                            Edutech
# 511  Dream11 is India’s Biggest Sports Game with 30...
# 512  SRJNA is a brand of Elation Edtech Pvt. Ltd., ...
# 513  Nykaa.com is a premier online beauty and welln...
# 514  Chaayos was born in November 2012 out of this ...
# 515  Heelium is an athletic footwear and wearable s...
# 516  LT Foods believe that nature will continue to ...
# 517                   Free language learning platform.
# 518    Uttar Pradesh based online eyewear marketplace.
# 519      NewsHunt is a Bangalore based eBooks company.
# 520  SlicePay is an AI based instant credit app for...
# 521  Udaan is a B2B trade platform, designed specif...
# 522            HappyEasyGo is an online travel domain.
# 523  Mombay is a unique opportunity for housewives ...
# 524  Droni Tech manufacture UAVs and develop softwa...
# 525       Welcome to India's most convenient pharmacy!

# %% [markdown]
# ### Renaming Columns to reflect consistency

# %%
# rename the column headings to be consistent with other data set
data_2018.rename(columns={'Company Name':'Company/Brand','Industry':'Sector','Round/Series':'Stage','Amount':'Amount($)','Location':'HeadQuarter','About Company':'What it does'}, inplace=True)

# %% [markdown]
# ### Cleaning the Sector Column

# %%
# Cleaning the Sector column to get of multiple sectors represented as one. 
#This is done by first stipping and using slicing to select the first part.
data_2018['Sector'] = data_2018['Sector'].str.split(',').str[0] 
data_2018['Sector'].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        '—', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear'], dtype=object)

# %%
#rename similar sectors with wrong or different spelling to make it consistent
data_2018.replace({'Sector':{'E-Commerce Platforms':'E-Commerce','Autonomous Vehicles':'Automotive','eSports':'Sports',
                           'Funding Platform':'Crowdfunding','Crowdsourcing':'Crowdfunding','Last Mile Transportation':'Transportation',
                           'Delivery':'Logistics','Delivery Service':'Logistics','Children':'Child Care','Travel':'Transportation','Health Care':'Healthcare',
                           'Commercial Real Estate':'Real Estate','Cooking':'Catering','Fantasy Sports':'Sports','Consumer':'Consumer Goods',
                           'Consumer Lending':'Consumer Goods','Credit':'Credit Cards','Business Travel':'Transportation','Hospital':'Healthcare',
                           'Basketball':'Sports','Alternative Medicine':'Healthcare','Renewable Energy':'Energy','Clean Energy':'Energy','Music':'Music Streaming',
                           'Health Diagnostics':'Healthcare','Medical':'Healthcare','Enterprise Software':'ERP','Enterprise Resource Planning (ERP)':'ERP',
                           'Audio':'Music Streaming','Air Transportation':'Aerospace','Wellness':'Fitness','Beauty':'Cosmetics','Big Data':'Analytics',
                           'Food and Beverage':'Catering','Wealth Management':'Finance','Social Media':'Digital Media','Broadcasting':'Media and Entertainment',
                           'News':'Media and Entertainment','Packaging Services':'Logistics','Mobile':'Mobile Phones','Medical Device':'Healthcare',
                           'Continuing Education':'Education','Dental':'Healthcare','Android':'Software','Banking':'Financial Services','Training':'Education',
                           'Digital Marketing':'Advertising','Marketplace':'Advertising','Consumer Electronics':'Consumer Goods','Rental':'Facilities Support Services',
                           'Retail':'Business Development','3D Printing':'Creative Agency','Electric Vehicle':'Automotive','Industrial Automation':'Manufacturing',
                           'Battery':'Energy','Reading Apps':'Apps','B2B':'E-Commerce','Communities':'Environmental Consulting','Smart Cities':'Environmental Consulting',
                           'Health Insurance':'Insurance','Commercial':'Business Development','Digital Entertainment':'Digital Media',
                           'Cloud Infrastructure':'Cloud Computing','Marketing':'Advertising','Events':'Creative Agency','Food Delivery':'Catering',
                           'Artificial Intelligence':'AI','Business Intelligence':'ERP','Information Services':'IT','Information Technology':'IT',
                           'E-Learning':'Education','Tourism':'Hospitality','Industrial':'Manufacturing','Internet':'IT','Internet of Things':'IoT',
                           'Farming':'Agriculture','Food Processing':'Catering','Collaboration':'Human Resources','Computer':'IT','Career Planning':'Human Resources',
                           'Wedding':'Customer Service','Online Games':'Gaming','—':'Unknown','Brand Marketing':'Advertising'}}, inplace=True)

# %% [markdown]
# ### Cleaning the Stage Column

# %%
data_2018['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round'], dtype=object)

# %%
data_2018.replace({'Stage':{'Pre-Seed':'Seed','Private Equity':'Seed','Venture - Series Unknown':'Seed',
                           'Debt Financing':'Seed','Post-IPO Debt':'Seed','Corporate Round':'Seed','Undisclosed':'Seed',
                           'Post-IPO Equity':'Seed','Non-equity Assistance':'Seed','Funding Round':'Seed','Debt':'Seed',
                            'Angel':'Seed','Secondary Market':'Seed','Equity':'Seed','Grant':'Seed','Unknown':'Seed'}},inplace=True)
data_2018['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Series B', 'Series H', 'Series C', 'Series E',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D'], dtype=object)

# %%
data_2018.loc[data_2018['Stage']=='https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593']
# Out:
#       Company/Brand          Sector  \
# 178  BuyForexOnline  Transportation
#
#                                                  Stage Amount($)  \
# 178  https://docs.google.com/spreadsheets/d/1x9ziNe...   2000000
#
#                      HeadQuarter  \
# 178  Bangalore, Karnataka, India
#
#                                           What it does
# 178  BuyForexOnline.com is India's first completely...

# %% [markdown]
# Looking at the 'What it does' and 'Company/Brand', it is obvious the sector should be in the FinTech Sector, this needs to be corrected and the stage replaced with 'Unknwon' since there is no futher information to tell the stage

# %%
# correcting the name of the sector from transportation to FinTech based on the information above.
data_2018.iloc[178].replace({'Transportation':'FinTech'},inplace=True)

# %%
# correcting the stage name to Unknown since there is no information to correct it to the right stage. 
data_2018.iloc[178].replace({'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593':'Seed'},inplace=True)

# %%
data_2018['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Series B', 'Series H', 'Series C', 'Series E',
#        'Series D'], dtype=object)

# %% [markdown]
# ### Cleaning the Amount($) Column

# %% [markdown]
# Since some of the currencies are in ₹ (rupees) and others in $ (dollars), the rupees are changed to dollars based on the current exchange rate.
#
# Duty is to select all rows where 'Amount' column is in rupees

# %%
# since some of the currencies are in ₹ (rupees) and others in $ (dollars), the rupees are changed to dollars based on the current exchange rate
# select all rows where 'Amount($)' column is in rupees

# this should be done before stripping off the currency symbol in order to identify the values and make the conversion 
rupees_index = data_2018.index[data_2018['Amount($)'].str.contains('₹')]
rupees_index
# Out:
# Int64Index([  1,   2,   6,   7,  15,  19,  22,  23,  30,  37,
#             ...
#             488, 496, 500, 507, 509, 513, 514, 516, 517, 524],
#            dtype='int64', length=144)

# %%
# removing or stripping all special characters form the amount column
#data_2018["Amount"]=data_2018.Amount.apply(lambda x: str(x).replace("-",np.nan))
data_2018['Amount($)']=data_2018['Amount($)'].replace('—', np.nan)    # replacing '-' in the amount column with 0
data_2018['Amount($)']=data_2018['Amount($)'].apply(lambda x: str(x).replace("₹" ,""))   # replacing '₹' in the amount column with nothing
data_2018['Amount($)']=data_2018['Amount($)'].apply(lambda x: str(x).replace("$" ,""))   # replacing '$' in the amount column with nothing
data_2018['Amount($)']=data_2018['Amount($)'].apply(lambda x: str(x).replace("," ,""))   # replacing ',' in the amount column 
with nothing
# Out:
#   File "C:\Users\PROSPER\AppData\Local\Temp\ipykernel_8328\627018180.py", line 7
#     with nothing
#                 ^
# SyntaxError: invalid syntax

# %%
# change the data type from a string to a float
data_2018['Amount($)']=pd.to_numeric(data_2018['Amount($)'], errors='coerce')

# %%
#Convert the rows with rupees to dollars
#Multiply the rupees values in the amount column with 0.0146 which is the average 2018 exchange rate from rupees to dollars
# the is done on only the records with rupees whose indexes were stored to the rupees_index variable
data_2018.loc[rupees_index,['Amount($)']]=data_2018.loc[rupees_index,['Amount($)']].values*0.0146
data_2018.loc[rupees_index,["Amount($)"]].head()
# Out:
#     Amount($)
# 1         NaN
# 2         NaN
# 6         NaN
# 7         NaN
# 15        NaN

# %%
# all nan values are to be filled with median on the 
data_2018['Amount($)']=data_2018['Amount($)'].fillna(data_2018['Amount($)'].median())

# %% [markdown]
# ### Cleaning the HeadQuarter Column

# %%
#Strip the location data to only the city-area.
# use ',' as the delimeter to separate them and select preferred choice with slicing
data_2018['HeadQuarter']=data_2018['HeadQuarter'].str.split(',').str[0]     
data_2018['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow'],
#       dtype=object)

# %%
# replacing wrongly spelt names and similar names entered differently
data_2018.replace({'HeadQuarter':{'Bangalore':'Bengaluru','Bangalore City':'Bengaluru','New Delhi':'Delhi','India':'Delhi'}}, inplace=True)

# %% [markdown]
# ### Creating an Artificial `Founded` Column

# %% [markdown]
# This column is being created to hold the year in which the startups were founded.
# This is on the operational assumption that empty values are to be replace with the year in which the data set is located, hence 2018 will be used for all the entries in this data set.

# %%
# creating a founded column and assign 2018 as the value for all
data_2018['Founded']=2018

# %%
# checking for null values
data_2018.isnull().sum()
# Out:
# Company/Brand    0
# Sector           0
# Stage            0
# Amount($)        0
# HeadQuarter      0
# What it does     0
# Founded          0
# dtype: int64

# %%
# checking for duplicate entries
data_2018.duplicated().value_counts()
# Out:
# False    525
# True       1
# dtype: int64

# %%
 # remove the duplicate record
data_2018=data_2018.drop_duplicates(keep='first')

# %% [markdown]
# # 2019 Data Set

# %%
data_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Cleaning the Founded Column

# %%
# convert the data type from float to a string
data_2019['Founded']=data_2019['Founded'].astype(str)   
data_2019['Founded']=data_2019.Founded.str.split('.').str[0]    # removing the decimal points in the year
data_2019['Founded'].unique()
# Out:
# array(['nan', '2014', '2004', '2013', '2010', '2018', '2019', '2017',
#        '2011', '2015', '2016', '2012', '2008'], dtype=object)

# %%
# changing the data type to numeric
data_2019['Founded']=pd.to_numeric(data_2019['Founded'],errors='coerce', downcast='unsigned')

# %%
# all nan values are to be filled with unknown on the 
data_2019['Founded']=data_2019['Founded'].fillna(2019)

# %%
data_2019['Founded'].unique()
# Out:
# array([2019., 2014., 2004., 2013., 2010., 2018., 2017., 2011., 2015.,
#        2016., 2012., 2008.])

# %% [markdown]
# ### Cleaning the HeadQuarter Column

# %%
data_2019['HeadQuarter'].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# replacing wrongly spelt names and similar names entered differently
data_2019.replace({'HeadQuarter':{'Bangalore':'Bengaluru','New Delhi':'Delhi','nan':'Delhi'}}, inplace=True)

# %%
# all nan values are to be filled with Delhi on the assuption that this is an India Start Up data set
data_2019['HeadQuarter']=data_2019['HeadQuarter'].fillna('Delhi')

# %% [markdown]
# ### Cleaning the Sector Column

# %%
data_2019['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
#rename similar sectors with wrong or different spelling to make it consistent
data_2019.replace({'Sector':{'Edtech':'EdTech','Interior desEcommerce':'E-Commerce','ign':'Home Decor','Virtual Banking':'Financial Services',
                           'AgriTech':'AgTech','E-commerce & AR':'E-Commerce','Fintech':'FinTech','Infratech':'IT','B2B Supply Chain':'E-Commerce',
                           'Marketing & Customer loyalty':'Customer Service','Automobile & Technology':'Automotive','Transport & Rentals':'Transportation',
                           'HR tech':'Human Resources','AI & Tech':'AI','E-commerce':'E-Commerce','Travel':'Transportation','Health Care':'Healthcare',
                           'Commercial Real Estate':'Real Estate','Cooking':'Catering','Fantasy Sports':'Sports','Consumer':'Consumer Goods',
                           'Healthtech':'Healthcare','E-Sports':'Sports','Mutual Funds':'Finance','Legal tech':'Legal','Accomodation':'Real Estate',
                           'Consumer Lending':'Consumer Goods','Credit':'Credit Cards','Business Travel':'Transportation','Hospital':'Healthcare',
                           'Automobile':'Automotive','Alternative Medicine':'Healthcare','Renewable Energy':'Energy','Clean Energy':'Energy','Music':'Music Streaming',
                           'Health Diagnostics':'Healthcare','Medical':'Healthcare','Enterprise Software':'ERP','Enterprise Resource Planning (ERP)':'ERP',
                           'Audio':'Music Streaming','Air Transportation':'Aerospace','Yoga & wellness':'Fitness','Beauty':'Cosmetics','Big Data':'Analytics',
                           'Food and Beverage':'Catering','Wealth Management':'Finance','Social Media':'Digital Media','Broadcasting':'Media and Entertainment',
                           'News':'Media and Entertainment','Packaging Services':'Logistics','Mobile':'Mobile Phones','Medical Device':'Healthcare',
                           'Continuing Education':'Education','Dental':'Healthcare','Android':'Software','Banking':'Financial Services','Training':'Education',
                           'Digital Marketing':'Advertising','Marketplace':'Advertising','Consumer Electronics':'Consumer Goods','Rental':'Facilities Support Services',
                           'Retail':'Business Development','3D Printing':'Creative Agency','Electric Vehicle':'Automotive','Industrial Automation':'Manufacturing',
                           'Battery':'Energy','Reading Apps':'Apps','B2B':'E-Commerce','Communities':'Environmental Consulting','Smart Cities':'Environmental Consulting',
                           'Health Insurance':'Insurance','Commercial':'Business Development','Digital Entertainment':'Digital Media','Food & tech':'Catering',
                           'Cloud Infrastructure':'Cloud Computing','Marketing':'Advertising','Events':'Creative Agency','Food tech':'Catering',
                           'Artificial Intelligence':'AI','Business Intelligence':'ERP','Information Services':'IT','Information Technology':'IT',
                           'E-Learning':'Education','Tourism':'Hospitality','Industrial':'Manufacturing','Internet':'IT','Internet of Things':'IoT',
                           'Jewellery':'Fashion','Food & Nutrition':'Healthcare','Robotics & AI':'AI', 'E-marketplace':'E-Commerce','Foodtech':'Catering',
                           'Insurance technology':'Insurance','Pharmaceutical':'Healthcare','Safety tech':'Cybersecurity',
                           'Technology':'IT','Farming':'Agriculture','Food Processing':'Catering','Collaboration':'Human Resources','Computer':'IT','Career Planning':'Human Resources',
                           'Wedding':'Customer Service','Games':'Gaming'}}, inplace=True)
data_2019['Sector'].unique()
# Out:
# array(['Ecommerce', 'EdTech', 'Interior design', 'AgTech', 'IT', 'SaaS',
#        'AI', 'E-Commerce', 'FinTech', 'Human Resources', 'Catering',
#        'Health', 'Healthcare', 'Cybersecurity', 'Insurance', 'Food',
#        'IoT', 'Logistics', 'Transportation', 'Manufacturing',
#        'Digital Media', nan, 'Sports', 'Cosmetics', 'Fashion', 'Gaming',
#        'Real Estate', 'Automotive tech', 'Legal', 'Finance', 'Automotive',
#        'Fitness', 'Financial Services', 'Customer Service', 'Hospitality'],
#       dtype=object)

# %%
# all nan values are to be filled with unknown on the 
data_2019['Sector']=data_2019['Sector'].fillna('Unknown')

# %% [markdown]
# ### Cleaning the Amount($) Column

# %%
# stripping off special characters
#data_2019.replace({'Amount($)':{'$':'',',':''}},inplace=True)
data_2019["Amount($)"]=data_2019['Amount($)'].apply(lambda x: str(x).replace("$" ,"")) 
data_2019["Amount($)"]=data_2019['Amount($)'].apply(lambda x: str(x).replace("," ,""))
data_2019["Amount($)"]=data_2019['Amount($)'].replace("Undisclosed" ,np.nan)

# %%
# change the data type to a float
# The downcast parameter is used to set the data type to float
data_2019['Amount($)'] = pd.to_numeric(data_2019['Amount($)'], errors='coerce', downcast='float')

# %%
# all nan values are to be filled with median on the 
data_2019['Amount($)']=data_2019['Amount($)'].fillna(data_2019['Amount($)'].median())

# %% [markdown]
# ### Cleaning the Stage Column

# %%
data_2019['Stage'].unique()
# Out:
# array([nan, 'Series C', 'Fresh funding', 'Series D', 'Pre series A',
#        'Series A', 'Series G', 'Series B', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series E', 'Series F', 'Series B+',
#        'Seed round', 'Pre-series A'], dtype=object)

# %%
# replacing wrongly spelt and similar enteries to promote consistency
data_2019.replace({'Stage':{'Seed fund':'Seed','Post series A':'Series A',
                           'Pre series A':'Series A','Series B+':'Series B','Fresh funding':'Seed',
                           'Pre-series A':'Series A','Seed round':'Seed','Seed funding':'Seed','Debt':'Seed',
                            'Angel':'Seed','Secondary Market':'Seed','Equity':'Seed','Grant':'Seed'}},inplace=True)
data_2019['Stage'].unique()
# Out:
# array([nan, 'Series C', 'Seed', 'Series D', 'Series A', 'Series G',
#        'Series B', 'Series E', 'Series F'], dtype=object)

# %%
# all nan values are to be filled with unknown on the 
data_2019['Stage']=data_2019['Stage'].fillna('Seed')

# %% [markdown]
# ### Cleaning the Founders Column

# %%
# all nan values are to be filled with unknown on the 
data_2019['Founders']=data_2019['Founders'].fillna('Unknown')

# %%
data_2019.isnull().sum()
# Out:
# Company/Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# What it does     0
# Founders         0
# Investor         0
# Amount($)        0
# Stage            0
# dtype: int64

# %%
# checking for duplicate entries
data_2019.duplicated().value_counts()
# Out:
# False    89
# dtype: int64

# %% [markdown]
# # 2020 Data Set

# %%
data_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %% [markdown]
# ### Cleaning the Founded Column

# %%
data_2020['Founded'].unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', nan, '1999', '1994', '2005', '1973', '-',
#        '2002', '2004', '2001'], dtype=object)

# %%
# all - values are to be filled with nan 
data_2020['Founded']=data_2020['Founded'].replace({'-':np.nan},inplace=True)

# %%
# changing the data type to numeric
data_2020['Founded']=pd.to_numeric(data_2020['Founded'],errors='coerce',downcast='signed')

# %%
# all nan values are to be filled with 2020
data_2020['Founded']=data_2020['Founded'].fillna(2020)

# %% [markdown]
# ### Cleaning the HeadQuarter Column

# %%
data_2020['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli, Tamilnadu', 'Thane', nan,
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Jaipur, Rajastan', 'Delhi', 'Frisco, Texas, United States',
#        'California', 'Dhingsara, Haryana', 'New York, United States',
#        'Patna', 'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Chandigarh', 'Warangal',
#        'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Banglore', 'Coimbatore', 'Bengaluru'],
#       dtype=object)

# %%
#strip and select only the City name, which is the first part and ignore the country 
data_2020['HeadQuarter']=data_2020['HeadQuarter'].str.split(',').str[0]

# %%
# replacing wrongly spelt names and similar names entered differently
data_2020.replace({'HeadQuarter':{'Bangalore':'Bengaluru','New Delhi':'Delhi','nan':'Delhi','Bangaldesh':'Bangladesh',
                                  'Banglore':'Bengaluru'}}, inplace=True)

# %%
# all nan values are to be filled with Delhi on the assuption that this is an India Start Up data set
data_2020['HeadQuarter']=data_2020['HeadQuarter'].fillna('Delhi')

# %% [markdown]
# ### Cleaning the Sector Column

# %%
data_2020['Sector'].unique()
# Out:
# array(['AgriTech', 'EdTech', 'Hygiene management', 'Escrow',
#        'Networking platform', 'FinTech', 'Crowdsourcing',
#        'Food & Bevarages', 'HealthTech', 'Fashion startup',
#        'Food Industry', 'Food Delivery', 'Virtual auditing startup',
#        'E-commerce', 'Gaming', 'Work fulfillment', 'AI startup',
#        'Telecommunication', 'Logistics', 'Tech Startup', 'Sports',
#        'Retail', 'Medtech', 'Tyre management', 'Cloud company',
#        'Software company', 'Venture capitalist', 'Renewable player',
#        'IoT startup', 'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Hospitality', 'Digital Media', 'Dairy startup',
#        'Content management', 'Spacetech', 'Transportation',
#        'Trading platform', 'AI Company', 'Photonics startup',
#        'Entertainment', 'Cosmetics', 'Scanning app', 'Skincare startup',
#        'Food and Beverages', 'Biotechnology company', 'FoodTech',
#        'Proptech', 'CleanTech', 'Fitness startup', 'Healthcare',
#        'PaaS startup', 'Beverages', 'Social Media', 'Automobiles',
#        'Deeptech', 'EV startup', 'AR/VR startup', 'Recruitment startup',
#        'QSR startup', 'Video platform', 'Edtech', 'Fertility tech',
#        'Luxury car startup', 'FM', 'Food', 'Nutrition sector',
#        'Tech platform', 'Video', 'Retail Tech', 'HeathTech',
#        'Sles and marketing', 'LegalTech', 'Car Service',
#        'Bike marketplace', 'Agri tech', 'Reatil startup', 'AR platform',
#        'Consumer Goods', 'Content marketplace', 'Interior Design',
#        'Rental space', 'Soil-Tech', 'Ayurveda tech',
#        'Packaging solution startup', 'Cleantech', 'Sanitation solutions',
#        'HealthCare', 'Home Design', 'InsureTech', 'AI Startup',
#        'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Fashion', 'Finance',
#        'Venture capital', 'Entreprenurship', 'Food devlivery',
#        'Warehouse', 'Online financial service', 'Eyeglasses',
#        'Battery design', 'Online credit management startup', 'Beverage',
#        'TravelTech', 'Agriculture', 'Startup laboratory',
#        'Personal care startup', 'Customer service company',
#        'SaaS\xa0\xa0startup', 'Marketing startup', 'Service industry',
#        'Social media', 'AI', 'Jewellery', 'AR startup', 'HR Tech startup',
#        'Automotive Startup', 'Food Startup', 'EdTech Startup',
#        'Car Trade', 'EdtTech', 'Manufacturing', 'AI Platform',
#        'Automation', 'Solar SaaS', 'WL & RAC protection',
#        'Social commerce', 'Home interior services', 'Agritech startup',
#        'API platform', 'Deep Tech', 'Electricity', 'Automotive company',
#        'FMCG', 'Insurance Tech', 'Video personalization',
#        'Software Company', 'Biomaterial startup', 'Health', 'IT',
#        'Craft Beer', 'Healthtech', 'Education', 'Investment',
#        'Linguistic Spiritual', 'Construction', 'Battery manufacturer',
#        'Nano Distribution Network', 'AI health', 'Dating app', 'Media',
#        'Fintech', 'Healthcare/Edtech', 'Social Commerce',
#        'Agritech/Commerce', 'Mobility tech', 'Social e-commerce',
#        'Food & Logistics', 'SpaceTech', 'Nutrition Tech', 'HR', 'IoT',
#        nan, 'Agritech', 'Interior design', 'Foodtech', 'AR/VR',
#        'Appliance', 'HR tech', 'Food tech', 'Mental Health', 'Ecommerce',
#        'Solar Solution', 'SaaS', 'Automobile', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages', 'Automotive',
#        'B2B', 'Defense tech', 'Marketplace', 'Construction tech',
#        'Nutrition', 'Coworking', 'Micro-mobiity', 'Auto-tech', 'Beauty',
#        'Robotics', 'Yoga & wellness', 'Logitech', 'Med Tech',
#        'Life sciences', 'Retail Aggregator', 'Deep Tech AI', 'Biotech',
#        'Blockchain', 'HrTech', 'Mobility/Transport', 'Travel', 'Rental',
#        'AI & Debt', 'SaaS/Edtech', 'Transport', 'Co-working', 'Insurtech',
#        'Cryptocurrency', 'Automotive tech', 'Legal', 'Fitness', 'EV',
#        'Supply chain, Agritech', 'Pharma', 'Insurance technology',
#        'Foodtech & Logistics', 'Housing', 'Pharmaceutical',
#        'Data Analytics', 'Investment Tech', 'Financial Services',
#        'Biopharma', 'Dairy', 'Beauty & wellness', 'Travel & SaaS',
#        'Tourism & EV', 'Media Tech', 'Location Analytics', 'E store',
#        'Data Science', 'Insurance', 'Health and Fitness', 'Technology',
#        'Interior & decor', 'eMobility', 'Automation tech',
#        'Media & Networking', 'E-market', 'AI & Data science',
#        'Travel tech', 'Automotive and Rentals', 'E-tail', 'Accomodation',
#        'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'Marketing',
#        'E tailor', 'E-mobility', 'Ad-tech', 'Neo-banking',
#        'Transport Automation', 'Techonology', 'Transport & Rentals',
#        'AI Robotics', 'Preschool Daycare', 'Food diet', 'B2B Agritech',
#        'E-connect', 'Tech hub', 'Consultancy', 'Pharmacy', 'Deisgning',
#        'Taxation', 'Automobile Technology'], dtype=object)

# %%
#rename similar sectors with wrong or different spelling to make it consistent
data_2020.replace({'Sector':{'Ecommerce':'E-Commerce','Edtech':'EdTech','Interior design':'Home Decor','Virtual Banking':'Financial Services',
                           'AgriTech':'AgTech','E-commerce & AR':'E-Commerce','Fintech':'FinTech','Infratech':'IT','B2B Supply Chain':'E-Commerce',
                           'Marketing & Customer loyalty':'Customer Service','Automobile & Technology':'Automotive','Transport & Rentals':'Transportation',
                           'HR tech':'Human Resources','AI & Tech':'AI','E-commerce':'E-Commerce','Travel':'Transportation','Health Care':'Healthcare',
                           'Commercial Real Estate':'Real Estate','Cooking':'Catering','Fantasy Sports':'Sports','Consumer':'Consumer Goods',
                           'Healthtech':'Healthcare','E-Sports':'Sports','Mutual Funds':'Finance','Legal tech':'Legal','Accomodation':'Real Estate',
                           'Consumer Lending':'Consumer Goods','Credit':'Credit Cards','Business Travel':'Transportation','Hospital':'Healthcare',
                           'Automobile':'Automotive','Alternative Medicine':'Healthcare','Renewable Energy':'Energy','Clean Energy':'Energy','Music':'Music Streaming',
                           'Health Diagnostics':'Healthcare','Medical':'Healthcare','Enterprise Software':'ERP','Enterprise Resource Planning (ERP)':'ERP',
                           'Audio':'Music Streaming','Air Transportation':'Aerospace','Yoga & wellness':'Fitness','Beauty':'Cosmetics','Big Data':'Analytics',
                           'Food and Beverage':'Catering','Wealth Management':'Finance','Social Media':'Digital Media','Broadcasting':'Media and Entertainment',
                           'News':'Media and Entertainment','Packaging Services':'Logistics','Mobile':'Mobile Phones','Medical Device':'Healthcare',
                           'Continuing Education':'Education','Dental':'Healthcare','Android':'Software','Banking':'Financial Services','Training':'Education',
                           'Digital Marketing':'Advertising','Marketplace':'Advertising','Consumer Electronics':'Consumer Goods','Rental':'Facilities Support Services',
                           'Retail':'Business Development','3D Printing':'Creative Agency','Electric Vehicle':'Automotive','Industrial Automation':'Manufacturing',
                           'Battery':'Energy','Reading Apps':'Apps','B2B':'E-Commerce','Communities':'Environmental Consulting','Smart Cities':'Environmental Consulting',
                           'Health Insurance':'Insurance','Commercial':'Business Development','Digital Entertainment':'Digital Media','Food & tech':'Catering',
                           'Cloud Infrastructure':'Cloud Computing','Marketing':'Advertising','Events':'Creative Agency','Food tech':'Catering',
                           'Artificial Intelligence':'AI','Business Intelligence':'ERP','Information Services':'IT','Information Technology':'IT',
                           'E-Learning':'Education','Tourism':'Hospitality','Industrial':'Manufacturing','Internet':'IT','Internet of Things':'IoT',
                           'Jewellery':'Fashion','Food & Nutrition':'Healthcare','Robotics & AI':'AI', 'E-marketplace':'E-Commerce','Foodtech':'Catering',
                           'Insurance technology':'Insurance','Pharmaceutical':'Healthcare','Safety tech':'Cybersecurity',"Fashion startup":'Fashion',
                             'Deisgning':'Creative Agency','Pharmacy':'Healthcare','Consultancy':'Creative Agency','Tech hub':'IT','E-connect':'Digital Media',
                             'B2B Agritech':'AgTech','Food diet':'Healthcare','Preschool Daycare':'Child Care','AI Robotics':'AI','SaaS/Edtech':'Saas',
                             'Transport & Rentals':'Transportation','Transport Automation':'Transportation','Neo-banking':'Financial Services',
                             'Ad-tech':'Advertising','E-mobility':'Mobile Payment','E tailor':'E-Commerce','Estore':'E-Commerce','Housing & Rentals':'Real Estate',
                             'AI & Deep learning':'AI','Sales & Services':'Business Development','VR & SaaS':'Saas','Hygiene':'CleanTech','Cleantech':'CleanTech',
                             'Visual Media':'Media and Entertainment','Content Marktplace':'Advertising','Machine Learning':'AI','AI & Media':'AI',
                             'E-tail':'E-Commerce','Automotive and Rentals':'Automotive','ravel tech':'Transportation','AI & Data science':'AI',
                             'Finance company':'Finance','Tech company':'IT','Solar Monitoring Company':'Energy','Video sharing platform':'Media and Entertainment',
                             'Gaming startup':'Gaming','Video streaming platform':'Media and Entertainment','Consumer appliances':'Consumer Goods',
                             'Blockchain startup':'Blockchain','Conversational AI platform':'AI','SaaS platform':'Saas','AI platform':'AI',
                             'Escrow':'Legal','Networking platform':'IT','Spacetech':'Aerospace','Trading platform':'E-Commerce','AI Company':'AI',
                             'Photonics startup':'Media and Entertainment','Entertainment':'Media and Entertainment','Scanning app':'Apps',
                             'Skincare startup':'Cosmetics','Food and Beverages':'Catering','FoodTech':'Catering','Biotechnology company':'Environmental Consulting',
                             'Proptech':'Facilities Support Services','Fitness startup':'Fitness','PaaS startup':'Saas','Beverages':'Catering',
                             'Automobiles':'Automotive','Deeptech':'AI','EV startup':'Environmental Consulting','AR/VR startup':'IT','Recruitment startup':'Human Resources',
                             'Tourism & EV':'Hospitality','QSR startup':'Customer Service','Video platform':'Media and Entertainment',
                             'Fusion beverages':'Catering','Job portal':'Human Resources','Dairy startup':'Catering','Content management':'Creative Agency',
                             'Work fulfillment':'Human Resources','HR Tech':'Human Resources','Software Company':'Software','Soil-Tech':'Agriculture',
                             'Travel & SaaS':'Transportation','Hygiene management':'CleanTech','Food & Bevarages':'Catering','Food Delivery':'Catering',
                             'Virtual auditing startup':'FinTech','HealthTech':'Healthcare','AI startup':'AI','Tech Startup':'IT','Medtech':'Healthcare',
                             'Tyre management':'Automotive','Cloud company':'Cloud Computing','Software company':'Software','Venture capitalist':'Finance',
                             'Renewable player':'Energy','IoT startup':'IoT','SaaS startup':'Saas','Aero company':'Aerospace','Marketing company':'Advertising',
                             'Retail startup':'Business Development','Co-working Startup':'Human Resources','—':'Unknown','Brand Marketing':'Advertising',
                             'Fertility tech':'Healthcare','Luxury car startup':'Automotive','FM':'Media and Entertainment','Food':'Catering',
                             'Nutrition sector':'Healthcare','Tech platform':'IT','Video':'Media and Entertainment','Retail Tech':'Business Development',
                             'HeathTech':'Healthcare','Sles and marketing':'Advertising','LegalTech':'Legal','Car Service':'Automotive',
                             'Bike marketplace':'Automotive','Agri tech':'AgTech','Reatil startup':'Business Development','AR platform':'IT',
                             'Content marketplace':'Creative Agency','Interior Design':'Home Decor','Home Design':'Home Decor','InsureTech':'Insurance',
                             'Rental space':'Facilities Support Services','Ayurveda tech':'IT','Packaging solution startup':'Logistics',
                             'Sanitation solutions':'CleanTech','HealthCare':'Healthcare','AI Startup':'AI','Solar solution':'Energy','Tech':'IT',
                             'Jewellery startup':'Fashion','Multinational conglomerate company':'Business Development','Deeptech startup':'AI',
                             'Social Network':'Digital Media','Publication':'Creative Agency','Venture capital':'Finance','Entreprenurship':'Business Development',
                             'E-market':'E-Commerce','Media & Networking':'Media and Entertainment','Automation tech':'Automotive','eMobility':'Mobile Payment',
                             'Food devlivery':'Catering','Warehouse':'Facilities Support Services','Online financial service':'FinTech',
                             'Eyeglasses':'Healthcare','Battery design':'Energy','Online credit management startup':'FinTech','Beverage':'Catering',
                             'TravelTech':'Transportation','Startup laboratory':'Business Development','Personal care startup':'Fitness',
                             'Customer service company':'Customer Service','SaaS\xa0\xa0startup':'Saas','Marketing startup':'Advertising',
                             'Service industry':'Human Resources','Social media':'Digital Media','R startup':'IT','HR Tech startup':'Human Resources',
                             'AR startup':'IT','Automotive Startup':'Automotive','Food Startup':'Catering','EdTech Startup':'Education',
                             'Car Trade':'Automotive','EdtTech':'Education','AI Platform':'AI','Automation':'Automotive','Solar SaaS':'Saas',
                             'WL & RAC protection':'Environmental Consulting','Social commerce':'E-Commerce','Home interior services':'Home Decor',
                             'Agritech startup':'AgTech','API platform':'Software','Deep Tech':'AI','Electricity':'Energy','Automotive company':'Automotive',
                             'FMCG':'Legal','Insurance Tech':'Insurance','Video personalization':'Media and Entertainment','Biomaterial startup':'Manufacturing',
                             'Health':'Healthcare','Craft Beer':'Creative Agency','Investment':'Finance','Linguistic Spiritual':'Education',
                             'Battery manufacturer':'Energy','Nano Distribution Network':'IT','AI health':'AI','Dating app':'Dating',
                             'Media':'Media and Entertainment','Healthcare/Edtech':'Healthcare','Social Commerce':'E-Commerce','Agritech/Commerce':'AgTech',
                             'Mobility tech':'Mobile Phones','Social e-commerce':'E-Commerce','Food & Logistics':'Logistics','SpaceTech':'Aerospace',
                             'Nutrition Tech':'Healthcare','HR':'Human Resources','nan':'Unknown','Agritech':'AgTech','AR/VR':'IT',
                             'Appliance':'Consumer Goods','Mental Health':'Healthcare','Solar Solution':'Energy','Saas':'SaaS','B2B marketplace':'E-Commerce',
                             'Fashion Tech':'Fashion','Nutrition tech':'Healthcare','Health & Wellness':'Fitness','Cloud Kitchen':'Cloud Computing',
                             'IoT/Automobile':'IoT','Eye Wear':'Healthcare','Digital tech':'IT','Data Intelligence':'ERP','Co-living':'Human Resources',
                             'Food & Beverages':'Catering','Defense tech':'Cybersecurity','Construction tech':'Construction','Nutrition':'Healthcare',
                             'Coworking':'Human Resources','Micro-mobiity':'Mobile Phones','Auto-tech':'Automotive','Robotics':'AI','Logitech':'IT',
                             'Med Tech':'Healthcare','Life sciences':'Healthcare','Retail Aggregator':'Business Development','Deep Tech AI':'AI',
                             'Biotech':'Environmental Consulting','HrTech':'Human Resources','AI & Debt':'AI','Transport':'Transportation',
                             'Co-working':'Human Resources','Insurtech':'Insurance','Automotive tech':'Automotive','EV':'Environmental Consulting',
                             'Supply chain, Agritech':'Logistics','Pharma':'Healthcare','Foodtech & Logistics':'Logistics','Housing':'Real Estate',
                             'Data Analytics':'ERP','Investment Tech':'Finance','Biopharma':'Healthcare','Dairy':'Catering','Beauty & wellness':'Fitness',
                             'Media Tech':'Media and Entertainment','E store':'E-Commerce','Data Science':'ERP','Travel tech':'Transportation',
                             'Techonology':'IT','Taxation':'Accounting','Automobile Technology':'Automotive','Food Industry':'Catering','Financial Services':'Financial Services',
                             'Interior & decor':'Home Decor','Health and Fitness':'Fitness','Location Analytics':'ERP','Mobility/Transport':'Transportation',
                           'Technology':'IT','Farming':'Agriculture','Food Processing':'Catering','Collaboration':'Human Resources','Computer':'IT','Career Planning':'Human Resources',
                           'Wedding':'Customer Service','Games':'Gaming'}}, inplace=True)

# %%
data_2020['Sector'].unique()
# Out:
# array(['AgTech', 'EdTech', 'CleanTech', 'Legal', 'IT', 'FinTech',
#        'Crowdsourcing', 'Catering', 'Healthcare', 'Fashion', 'E-Commerce',
#        'Gaming', 'Human Resources', 'AI', 'Telecommunication',
#        'Logistics', 'Sports', 'Business Development', 'Automotive',
#        'Cloud Computing', 'Software', 'Finance', 'Energy', 'IoT', 'Saas',
#        'Aerospace', 'Advertising', 'Media and Entertainment',
#        'Consumer Goods', 'Blockchain', 'Real Estate', 'Hospitality',
#        'Digital Media', 'Creative Agency', 'Transportation', 'Cosmetics',
#        'Apps', 'Environmental Consulting', 'Facilities Support Services',
#        'Fitness', 'Customer Service', 'Home Decor', 'Agriculture',
#        'Insurance', 'Education', 'Manufacturing', 'Construction',
#        'Dating', 'Mobile Phones', nan, 'SaaS', 'ERP', 'Cybersecurity',
#        'Cryptocurrency', 'Financial Services', 'Mobile Payment',
#        'Child Care', 'Accounting'], dtype=object)

# %%
# all nan values are to be filled with Unknown
data_2020['Sector']=data_2020['Sector'].fillna('Unknown')

# %% [markdown]
# ### Cleaning the Amount($) Column

# %%
#First change the data type to a string to work on the special characters
data_2020['Amount($)']=data_2020['Amount($)'].astype(str)

# %%
# retrieveing records with Undisclosed in the Amount($) column
data_2020.loc[data_2020['Amount($)']=='Undiclsosed']
#und_1=data_2020['Amount($)']=='Undiclsosed'
#und_2=data_2020['Amount($)']=='Undislosed'
#und_3=data_2020['Amount($)']=='Undisclosed'
# Out:
#     Company/Brand  Founded HeadQuarter Sector  \
# 665   Credgencies   2020.0       Delhi     AI
#
#                                           What it does  \
# 665  Tech-enabled platform for resolution of non-pe...
#
#                                       Founders       Investor    Amount($)  \
# 665  Rishabh Goel, Anand Agrawal, Mayank Khera  Titan Capital  Undiclsosed
#
#           Stage Unnamed: 9
# 665  Seed Round        NaN

# %%
# correcting the name of the Amount($) from Undiclsosed to 0 based on the information above.
data_2020.iloc[665].replace({'Undiclsosed':np.nan},inplace=True)

# %%
# retrieveing records with Undislosed in the Amount($) column
data_2020.loc[data_2020['Amount($)']=='Undislosed']
# Out:
#      Company/Brand  Founded HeadQuarter   Sector  \
# 1012        Toddle   2020.0   Bengaluru  Unknown
#
#                                            What it does  \
# 1012  Collaboration and productivity platform for te...
#
#                             Founders               Investor   Amount($) Stage  \
# 1012  Deepanshu Arora, Parita Parekh  Matrix Partners India  Undislosed   NaN
#
#      Unnamed: 9
# 1012        NaN

# %%
# correcting the name of the Amount($) from Undislosed to 0 based on the information above.
data_2020.iloc[665].replace({'Undislosed':np.nan},inplace=True)

# %%
# retrieveing records with Undisclosed in the Amount($) column
data_2020.loc[data_2020['Amount($)']=='Undisclosed']
# Out:
#                               Company/Brand  Founded             HeadQuarter  \
# 2                              PadCare Labs   2020.0                    Pune
# 7                                     Metvy   2020.0                 Gurgaon
# 11                                   Medfin   2020.0               Bengaluru
# 12                                  MasterG   2020.0                   Delhi
# 18                                Pine Labs   2020.0                   Noida
# 20                                     EWar   2020.0               Bengaluru
# 28                                    Voosh   2020.0               Bengaluru
# 35                                    Hudle   2020.0                   Delhi
# 40                             Fleeca India   2020.0                  Jaipur
# 47                            Tinker Coders   2020.0                   Noida
# 52                                  NeoDocs   2020.0                  Mumbai
# 53                               The ePlane   2020.0                 Chennai
# 61                                   Swipez   2020.0                    Pune
# 62                                    Humus   2020.0               Bengaluru
# 63                             Artivatic.ai   2020.0               Bengaluru
# 64                                Prescinto   2020.0               Ahmedabad
# 65                                   Toppeq   2020.0                  Mumbai
# 68                              FreshToHome   2020.0               Bengaluru
# 69                                  KIKO TV   2020.0                  Mumbai
# 72                                Smallcase   2020.0               Bengaluru
# 74                                  Gamerji   2020.0               Ahmedabad
# 90                                KopyKitab   2020.0               Bengaluru
# 96                            Omatra Hotels   2020.0                 Kolkata
# 97                                    Awign   2020.0               Bengaluru
# 105                          Astrogate Labs   2020.0               Bengaluru
# 106                           Power Gummies   2020.0                   Delhi
# 110                                  Inntot   2020.0                  Kerala
# 114                            LightSpeedAI   2020.0               Bengaluru
# 115                             Grip Invest   2020.0                Gurugram
# 116                               Unacademy   2020.0               Bengaluru
# 120                                   Nykaa   2020.0                  Mumbai
# 123                                 Prolixr   2020.0                Gurugram
# 132                               Instamojo   2020.0               Bengaluru
# 137                                  Thrive   2020.0                  Mumbai
# 138                         Kitchens Centre   2020.0                   Delhi
# 142                         Shilpa Sciences   2020.0               Bengaluru
# 143                                  Arzooo   2020.0               Bengaluru
# 148                               Oga Fit's   2020.0               Bengaluru
# 149                                   LAVAL   2020.0               Bengaluru
# 155                              GalaxyCard   2020.0                Gurugram
# 163                                   iKure   2020.0                 Kolkata
# 166                                   TUBBR   2020.0                  Frisco
# 170             Universal Sportsbiz Pvt Ltd   2020.0               Bengaluru
# 171                              Lattu Kids   2020.0                  Mumbai
# 173                Steradian Semiconductors   2020.0               Bengaluru
# 180                                   Traya   2020.0                  Mumbai
# 182                               Mitron TV   2020.0               Bengaluru
# 185                              Expertrons   2020.0                  Mumbai
# 193                                   Agrix   2020.0                   Patna
# 194                              BharatAgri   2020.0                    Pune
# 203                            Finelistings   2020.0                   Delhi
# 204                              Wellversed   2020.0                   Delhi
# 205                                   Nykaa   2020.0                  Mumbai
# 210                               Snackible   2020.0                  Mumbai
# 213                                   Nykaa   2020.0                  Mumbai
# 214                              TagZ Foods   2020.0               Bengaluru
# 228                                 Ahaguru   2020.0                 Chennai
# 244                             Hire Me Car   2020.0                   Noida
# 246                        Harmonizer India   2020.0               Bengaluru
# 251                               RACEnergy   2020.0               Hyderabad
# 256                                ReNEWate   2020.0                    Pune
# 257                               Tango Eye   2020.0                 Chennai
# 258                             Rare Planet   2020.0                 Kolkata
# 263                               MikeLegal   2020.0                Gurugram
# 265                          Gourmet Garden   2020.0               Palmwoods
# 286                            PakkaProfile   2020.0               Bengaluru
# 288                                 Unocoin   2020.0                  Tumkur
# 289                                   Pesto   2020.0                   Delhi
# 291                                 Bambrew   2020.0               Bengaluru
# 292                                  Omnify   2020.0  San Francisco Bay Area
# 298                                 FanPlay   2020.0                   Delhi
# 314                                 Invento   2020.0               Bengaluru
# 316              AnalytIQSports's SuperCric   2020.0               Bengaluru
# 331                                 SpeakIn   2020.0                   Noida
# 332                                  LetsUp   2020.0                  Mumbai
# 333                               Newsreach   2020.0                 Gujarat
# 347                                  WE-Hub   2020.0               Hyderabad
# 349                                  Vicara   2020.0               Bengaluru
# 355                                  Trukky   2020.0               Ahmedabad
# 363                              ConnectedH   2020.0                 Gurgaon
# 368                            Customfit ai   2020.0               Bengaluru
# 369                                 Nirmata   2020.0          San Franciscao
# 370                             Hire Me Car   2020.0                   Noida
# 371                                 Oga Fit   2020.0               Bengaluru
# 377                               Codeyoung   2020.0               Bengaluru
# 381                              MobiGarage   2020.0                   Delhi
# 383                 WeInnovate Biosolutions   2020.0                    Pune
# 395                               Recordent   2020.0               Hyderabad
# 399                                 Precily   2020.0              California
# 411                               Burgerama   2020.0                 Gurgaon
# 448                         Cell Propulsion   2020.0               Bengaluru
# 462                       Chiratae Ventures   2020.0               Bengaluru
# 478                                   Settl   2020.0                Gurugram
# 479                                Fanspole   2020.0                   Thane
# 480                                   Sarva   2020.0                  Mumbai
# 481                                 Univ.ai   2020.0               Bengaluru
# 482                               PurohitJi   2020.0               Bengaluru
# 489                          Virtual Forest   2020.0               Bengaluru
# 493                                Fanspole   2020.0                  Mumbai
# 496                          The Money Club   2020.0                   Delhi
# 498                                 OneCode   2020.0                Gurugram
# 501                                   Evage   2020.0              Chandigarh
# 505                               Teachmint   2020.0               Bengaluru
# 507                           Habbit Health   2020.0                   Delhi
# 510                                Vieroots   2020.0                   Kochi
# 511                           Stack Finance   2020.0               Bengaluru
# 516                              Suno India   2020.0                   Delhi
# 519                        Eden Smart Homes   2020.0                   Delhi
# 525                                  DaveAI   2020.0               Bengaluru
# 529                                  CUSMAT   2020.0                Warangal
# 536                     Probus Smart Things   2020.0                   Delhi
# 537                              CrowdPouch   2020.0               Bengaluru
# 543                                 DatStop   2020.0                   Delhi
# 544                           IPHM Services   2020.0                  Mumbai
# 546                                 VilCart   2020.0               Bengaluru
# 553                              WYN Studio   2020.0                Gurugram
# 556                              Snack Amor   2020.0                  Mumbai
# 558                               Leap Club   2020.0                Gurugram
# 562                                    Finn   2020.0               Bengaluru
# 567                               ThriveFNC   2020.0                    Pune
# 575                  uFony Services Pvt ltd   2020.0                    Pune
# 576     Protinus Fashion Networking Pvt Ltd   2020.0                  Mumbai
# 577                                   Uable   2020.0               Bengaluru
# 585                                    NOTO   2020.0                  Mumbai
# 589                         Earth Energy EV   2020.0                  Mumbai
# 590                              Green Cure   2020.0                   Delhi
# 592                                  Edhusk   2020.0                  Jaipur
# 596                              Brainwired   2020.0                  Kerala
# 603                           Aerostrovilos   2020.0                 Chennai
# 611                                  Walrus   2020.0               Bengaluru
# 614                              Rusk Media   2020.0                   Delhi
# 615                               Bold Care   2020.0                  Mumbai
# 616                            Samosa Party   2020.0               Bengaluru
# 618                                  Byju's   2020.0               Bengaluru
# 624                       Aether Biomedical   2020.0                   Delhi
# 629                              GoMechanic   2020.0                   Delhi
# 635                              Peppermint   2020.0                   Delhi
# 636                                   Sarva   2020.0                  Mumbai
# 638                                  Agro2o   2020.0                   Delhi
# 640                             GabbarDeals   2020.0                    Pune
# 642                               Biomoneta   2020.0               Bengaluru
# 646                                Innoviti   2020.0               Bengaluru
# 649                                      F5   2020.0                   Delhi
# 651                          Myelin Foundry   2020.0                   Delhi
# 654                                  MyKaam   2020.0               Bengaluru
# 661                                  Timios   2020.0               Bengaluru
# 668                                   Vahak   2020.0                   Delhi
# 669                                 Nutrova   2020.0                  Mumbai
# 676                               Swiflearn   2020.0                Gurugram
# 677                                  Remedo   2020.0                   Delhi
# 678                                Blowhorn   2020.0               Bengaluru
# 680                              Gram Cover   2020.0                   Noida
# 682                             HomeCapital   2020.0                  Mumbai
# 684                               Riskcovry   2020.0                  Mumbai
# 685   NWNT (No Worry No Tension Healthcare)   2020.0                   Delhi
# 686                                Voicezen   2020.0                Gurugram
# 690                                   Tring   2020.0                  Mumbai
# 691                             Vakilsearch   2020.0                 Chennai
# 697                                 Winuall   2020.0               Bengaluru
# 700                                 DeepTek   2020.0                    Pune
# 701                    Stepathlon Lifestyle   2020.0                  Mumbai
# 704                       Tesco Charge Zone   2020.0                 Gujarat
# 708                                 GroCurv   2020.0                Gurugram
# 711                                   Spyne   2020.0                Gurugram
# 715                         Generic Aadhaar   2020.0                   Delhi
# 716                                    Nium   2020.0                   Delhi
# 719                               Blackbuck   2020.0               Bengaluru
# 723                               Codeninja   2020.0               Bengaluru
# 724                           MetaMerphoSys   2020.0                    Pune
# 726                              Aker Foods   2020.0                    Pune
# 727                 Sascan Meditech pvt ltd   2020.0                  Kerala
# 734                                  Remedo   2020.0                   Noida
# 735                              News Reach   2020.0               Ahmedabad
# 736                                RoomSoom   2020.0                   Noida
# 740                                    Qin1   2020.0                   Noida
# 743                                   Sarva   2020.0                   Delhi
# 744                              Expertrons   2020.0                  Mumbai
# 750                                 AsknBid   2020.0               Bengaluru
# 752                  Finaureus Technologies   2020.0                    Pune
# 760                                   Credr   2020.0                  Mumbai
# 763                              DrinkPrime   2020.0               Bengaluru
# 765                             UzhavarBumi   2020.0              Tamil Nadu
# 767                                Pariksha   2020.0                    Pune
# 773                         Morning Context   2020.0                   Delhi
# 775                             Savvy Co op   2020.0                   Delhi
# 776                                   BLive   2020.0                   Delhi
# 782                           Power Gummies   2020.0                   Delhi
# 783                               Locale ai   2020.0               Bengaluru
# 794                                    Plop   2020.0                  Mumbai
# 804                            Obviously AI   2020.0                   Delhi
# 814                                Samadhan   2020.0                   Delhi
# 815                                  SaScan   2020.0               Bengaluru
# 818                                  Nimesa   2020.0               Bengaluru
# 820                        Driftly Electric   2020.0               Bengaluru
# 823                                  Rupifi   2020.0               Bengaluru
# 824                               SnackAmor   2020.0                  Mumbai
# 825                                 Zealthy   2020.0               Bengaluru
# 839                               Khatabook   2020.0               Bengaluru
# 843                               OM Bhakti   2020.0               Bengaluru
# 845                   Anaxee Digital Runner   2020.0                  Indore
# 846                           CollegeKhabri   2020.0                  Bhopal
# 855                               StyleNook   2020.0                  Mumbai
# 856                        Callido Learning   2020.0                  Mumbai
# 857                                Soxytoes   2020.0                   Delhi
# 858                                      F5   2020.0                   Delhi
# 864                              Sleepy Owl   2020.0                   Delhi
# 866                                 GogoBus   2020.0                   Delhi
# 873                               Oda Class   2020.0               Bengaluru
# 875                                 goStops   2020.0                   Delhi
# 880                              MinionLabs   2020.0               Bengaluru
# 882                            PhoneParLoan   2020.0                   Delhi
# 892                                ElecTorq   2020.0                   Delhi
# 909                                  CamCom   2020.0               Bengaluru
# 912                                  HooLiv   2020.0                   Delhi
# 913                            ClassMonitor   2020.0                  Indore
# 914                                  Friyey   2020.0                    Pune
# 917                                 CYFIRMA   2020.0               Bengaluru
# 932                                   Altor   2020.0                   Delhi
# 942                                NEETprep   2020.0                   Delhi
# 947                             AlphaVector   2020.0               Bengaluru
# 954                       Seal Professional   2020.0               Bengaluru
# 955                           Sprinng Foods   2020.0                  Mumbai
# 957                                   Aagey   2020.0               Bengaluru
# 960                               RACEnergy   2020.0                   Delhi
# 971                        Uniplatform Tech   2020.0                   Delhi
# 977                              GetVantage   2020.0                  Mumbai
# 978                               Konfinity   2020.0                   Noida
# 979                               Pine Labs   2020.0                   Noida
# 980                               Instoried   2020.0                   Delhi
# 981                                   Nupay   2020.0                 Haryana
# 997                                   Zimyo   2020.0                Gurugram
# 998                      Sabse Sasta Dukaan   2020.0                 Kolkata
# 999                               Fitphilia   2020.0                  Mumbai
# 1003                               Dealberg   2020.0               Bengaluru
# 1013                    Aesthetic Nutrition   2020.0                   Delhi
# 1020                                 Aadhar   2020.0                  Mumbai
# 1021                            IncubateHub   2020.0               Bengaluru
# 1022                            Rage Coffee   2020.0                   Delhi
# 1023                              Skilancer   2020.0                   Noida
# 1024                      Harappa Education   2020.0                   Delhi
# 1028                                PayMart   2020.0              Chandigarh
# 1040                               BuildPan   2020.0                  Indore
# 1046                                FarmERP   2020.0                    Pune
#
#                            Sector  \
# 2                       CleanTech
# 7                              IT
# 11                     Healthcare
# 12                        Fashion
# 18                        FinTech
# 20                         Gaming
# 28                       Catering
# 35                         Sports
# 40                     Automotive
# 47                         EdTech
# 52                     Healthcare
# 53                      Aerospace
# 61                        FinTech
# 62                         AgTech
# 63                             IT
# 64                         Energy
# 65                           Saas
# 68                     E-Commerce
# 69        Media and Entertainment
# 72                        FinTech
# 74                         Gaming
# 90                         EdTech
# 96                    Hospitality
# 97                Human Resources
# 105                     Aerospace
# 106                    Healthcare
# 110                            IT
# 114       Media and Entertainment
# 115                       FinTech
# 116                        EdTech
# 120                     Cosmetics
# 123                     Cosmetics
# 132                       FinTech
# 137                      Catering
# 138   Facilities Support Services
# 142                    Healthcare
# 143                            IT
# 148                       Fitness
# 149                     Cosmetics
# 155                       FinTech
# 163                    Healthcare
# 166                 Digital Media
# 170                       Fashion
# 171                        EdTech
# 173                            AI
# 180                    Healthcare
# 182       Media and Entertainment
# 185                        EdTech
# 193                        AgTech
# 194                        AgTech
# 203                    Automotive
# 204                    Healthcare
# 205                     Cosmetics
# 210                    Healthcare
# 213                    E-Commerce
# 214                      Catering
# 228                        EdTech
# 244                    Automotive
# 246                            IT
# 251                    Automotive
# 256                   Real Estate
# 257                          Saas
# 258          Business Development
# 263                         Legal
# 265                Consumer Goods
# 286               Human Resources
# 288                       FinTech
# 289                        EdTech
# 291                     Logistics
# 292                          Saas
# 298                        Gaming
# 314                            AI
# 316       Media and Entertainment
# 331                 Digital Media
# 332               Creative Agency
# 333               Creative Agency
# 347          Business Development
# 349                            IT
# 355                     Logistics
# 363                    Healthcare
# 368                          Saas
# 369                            IT
# 370                Transportation
# 371                       Fitness
# 377                        EdTech
# 381                    E-Commerce
# 383          Business Development
# 395                       FinTech
# 399                          Saas
# 411                      Catering
# 448                    Automotive
# 462                       Finance
# 478                Transportation
# 479       Media and Entertainment
# 480                    Healthcare
# 481                        EdTech
# 482                     Education
# 489                            IT
# 493                        Gaming
# 496                            AI
# 498                    E-Commerce
# 501                 Mobile Phones
# 505                        EdTech
# 507                    Healthcare
# 510                    Healthcare
# 511                       FinTech
# 516       Media and Entertainment
# 519                           IoT
# 525                            AI
# 529                            IT
# 536                           IoT
# 537                            IT
# 543                   Hospitality
# 544                    Healthcare
# 546                    E-Commerce
# 553       Media and Entertainment
# 556                      Catering
# 558                    E-Commerce
# 562                       FinTech
# 567                       Fitness
# 575                        EdTech
# 576                       Fashion
# 577                        EdTech
# 585                      Catering
# 589                    Automotive
# 590                       Fitness
# 592                        EdTech
# 596                        AgTech
# 603                    Automotive
# 611                       FinTech
# 614                 Digital Media
# 615                       Fitness
# 616                      Catering
# 618                        EdTech
# 624                    Healthcare
# 629                    Automotive
# 635                            AI
# 636                       Fitness
# 638                        AgTech
# 640                    E-Commerce
# 642                    Healthcare
# 646                          SaaS
# 649          Business Development
# 651                            AI
# 654               Human Resources
# 661                      Catering
# 668                Transportation
# 669                    Healthcare
# 676                        EdTech
# 677                    Healthcare
# 678                     Logistics
# 680                     Insurance
# 682                       FinTech
# 684                     Insurance
# 685                    Healthcare
# 686                            AI
# 690       Media and Entertainment
# 691                         Legal
# 697                        EdTech
# 700                    Healthcare
# 701                       Fitness
# 704      Environmental Consulting
# 708                    E-Commerce
# 711                            AI
# 715                    Healthcare
# 716                       FinTech
# 719                     Logistics
# 723                          SaaS
# 724                     Insurance
# 726                     Logistics
# 727                    Healthcare
# 734                    Healthcare
# 735       Media and Entertainment
# 736                   Real Estate
# 740                        EdTech
# 743                       Fitness
# 744                            AI
# 750                       Finance
# 752                       FinTech
# 760                    Automotive
# 763                       Unknown
# 765                      Catering
# 767                        EdTech
# 773                 Digital Media
# 775                    Healthcare
# 776                   Hospitality
# 782                    Healthcare
# 783                           ERP
# 794                            IT
# 804                           ERP
# 814                     Insurance
# 815                    Healthcare
# 818                          SaaS
# 820                    Automotive
# 823                       FinTech
# 824                      Catering
# 825                    Healthcare
# 839                       FinTech
# 843                         Legal
# 845                            IT
# 846                        EdTech
# 855                    E-Commerce
# 856                        EdTech
# 857                    E-Commerce
# 858                    E-Commerce
# 864                      Catering
# 866                Transportation
# 873                        EdTech
# 875                   Real Estate
# 880                            AI
# 882                       FinTech
# 892                    Automotive
# 909                            AI
# 912                   Real Estate
# 913                        EdTech
# 914               Human Resources
# 917                          SaaS
# 932                            IT
# 942                        EdTech
# 947                    E-Commerce
# 954                        EdTech
# 955                      Catering
# 957                       FinTech
# 960                Mobile Payment
# 971                          SaaS
# 977                       FinTech
# 978                        EdTech
# 979                       FinTech
# 980                          SaaS
# 981            Financial Services
# 997               Human Resources
# 998                    Healthcare
# 999                    Healthcare
# 1003                   E-Commerce
# 1013                   Healthcare
# 1020                   E-Commerce
# 1021                           IT
# 1022                        Legal
# 1023                           IT
# 1024                       EdTech
# 1028                      FinTech
# 1040                         SaaS
# 1046                       AgTech
#
#                                            What it does  \
# 2      Converting bio-hazardous waste to harmless waste
# 7     AI driven networking platform for individuals ...
# 11    Medfin is a Discovery platform for medical pro...
# 12    MasterG is a design and skill development orga...
# 18    A merchant platform company that provides fina...
# 20    EWar Games is a e-sports and real-time gaming ...
# 28    Building India's largest digital food service ...
# 35    Hudle is a sports & fitness discovery & bookin...
# 40              FLEECA is a Tyre Care Provider company.
# 47    Tinker Coder is a LIVE Online Platform through...
# 52    Neodocs analyses medical reports and provides ...
# 53    Transforming the mobility landscape using aeri...
# 61             Swipez is a payment collection platform.
# 62    Farmgate to Retail outlet Agri-Fresh produce s...
# 63    Artivatic's patent pending technology solves c...
# 64    Prescinto provides solutions for solar monitor...
# 65                SaaS-based equity management platform
# 68    Freshtohome is an e-commerce platform for fres...
# 69    KIKO TV is an AI-based short live video e-comm...
# 72               Changing how India invests in equities
# 74    Gamerji is an online esports gaming platform w...
# 90    Kopykitab is an India-based digital library th...
# 96    Omatra is very new hotel management firm recen...
# 97          Operations and manpower outsourcing startup
# 105   Astrogate Labs provides high-quality products ...
# 106   Power Gummies are a team of passionate givers ...
# 110   Inntot Technologies, is a technology driven co...
# 114   Developer of an optoelectronic processor desig...
# 115   Grip is an investment platform that allows ret...
# 116   Unacademy is an online learning platform provi...
# 120   Nykaa is an online marketplace for different b...
# 123   A premium skincare brand committed towards bui...
# 132   Instamojo is an on-demand payments platform th...
# 137   Thrive is all-in-one restaurant ordering suite...
# 138   Kitchens Centre offers turnkey solutions to cl...
# 142   Shilps Sciences is a healthtech platform that ...
# 143   B2B retail tech platform transforming 300,000+...
# 148   The new-age home workout app that gives you an...
# 149     Laval Cosmetics, affordable makeup for all ages
# 155   Mobile based Instant credit card. | Easiest wa...
# 163   iKure is a social enterprise that delivers pri...
# 166               World's First Personal Social Network
# 170               A fashion startup based in Bengaluru.
# 171   Lattu kids is an edutainment platform for pres...
# 173   Semiconductor company focused on CMOS millimet...
# 180   work with our customers closely to get their h...
# 182   Mitron is a free short videoplatform for next ...
# 185   Expertrons is an AI video bot platform created...
# 193   Farming-as-a-service (covering farm machinery ...
# 194   A Smart Farming Technology Platform for Indian...
# 203                       A Used Luxury Car Marketplace
# 204   Wellversed Health enables production of custom...
# 205   Nykaa is an online marketplace for different b...
# 210   Snackible operates a health-food production co...
# 213   Nykaa is an online marketplace for different b...
# 214   TagZ Foods is a supplier of snacks and food pr...
# 228   It is conducting IIT JEE Coach for Physics, Ma...
# 244   India's largest cloud based digital discovery ...
# 246   Energy-efficient solutions based on the Artifi...
# 251   RACEnergy builds and deploys battery swapping ...
# 256   Tech platform helping millions of renovation c...
# 257                 Retail Video Analytics SaaS product
# 258   Rare Planet sells handicrafts made by local ar...
# 263   MikeLegal is an AI powered legal associate tha...
# 265   Gourmet Garden is a global market leader in ch...
# 286   PakkaProfile bridges the gap between companies...
# 288   Unocoin is an Indian bitcoin processor that en...
# 289   Pesto is a career accelerator for software eng...
# 291   Bambrew is an online shop for reusable bamboo ...
# 292   Omnify is a Global SaaS platform for Small Ser...
# 298   FanPlay Technologies operates as a real-money ...
# 314   Invento Robotics specializes in developing ser...
# 316   SuperCric is India's first strategy Cricket Ma...
# 331   AI-enabled network of speakers and thought lea...
# 332   Provides News, Jobs, Information & Entertainme...
# 333   NewsReach India offers partner publications a ...
# 347   WE HUB is the first-of-its-kind and only State...
# 349   A deep tech startup pioneering in motion-based...
# 355   Transportation, logistics services & cargo ser...
# 363   The company’s vision is simple – Connected Hea...
# 368   Operates on a SaaS model by providing a hyper-...
# 369   Nirmata offers a complete solution for Kuberne...
# 370   HireMeCar.com offers customers the fastest and...
# 371   The new-age home workout app that gives you an...
# 377   Codeyoung provides live online coding classes ...
# 381   An ecommerce platform for refurbished electron...
# 383   Startup working dedicatedly in the area of hea...
# 395   A technology-enabled platform that helps MSMEs...
# 399   Precily is Artificial Intelligence platform fo...
# 411   Burgerama is a unit of Junket Foods Private Li...
# 448   Designs and develops electric power drives and...
# 462   A leading tech venture capital fund focused on...
# 478                Get affordable AC bus-rides everyday
# 479         India's only social fantasy gaming platform
# 480   A wellness ecosystem built on the authentic fo...
# 481   A distributed, global educational powerhouse t...
# 482              App for Hindu Puja Products & Services
# 489          Tracking seasonal change in virtual forest
# 493   A free app that users can use to create contes...
# 496                      AI based chit fund cashier app
# 498   Connects new-age digital first brands with rel...
# 501   Develop emissions-free electric commercial veh...
# 505   Empowers tutors with tools to deliver effectiv...
# 507   Applies modern science for healthier life thro...
# 510   Personalised lifestyle management using epigen...
# 511   It automates invesments, expenses, borrowing u...
# 516                       Multilingual podcast platform
# 519              Develops smart home automation systems
# 525   Sales augmentation platform with a vision to d...
# 529   It builds high immersion training systems for ...
# 536   Platform for monitoring distribution sub-stati...
# 537   A reward-based fundraising and preselling plat...
# 543                        It offers urban social space
# 544   It helps design programs and workshops for the...
# 546   Retail industry in rural India through technol...
# 553               It creates video content and podcasts
# 556                               Healthy snack startup
# 558        Community led professional network for women
# 562   Neobanking startup that digitises all banking ...
# 567   Focusses on reversing chronic lifestyle disord...
# 575   School Diary, a platform that brings education...
# 576   Owns and operates fashion commerce and retail ...
# 577   Online life skills development platform for ch...
# 585                 A brand that makes healthy icecream
# 589                           Electric vehicles startup
# 590                        It sells herbal OTC products
# 592   Provieds personalised learning to students by ...
# 596   India’s first livestock health monitoring company
# 603   Manufactures micro gas turbines for power-base...
# 611   It provides banking solutions for teens and yo...
# 614                            It creates video content
# 615   Digital platform that offers sexologist consul...
# 616                      Provides quality Indian Snacks
# 618                    Provides online learning classes
# 624   Medical robotics startup, focussed on developi...
# 629   Find automobile repair and maintenance service...
# 635                         Industrial robotics startup
# 636   It drives a cultural change in making yoga-bas...
# 638   It develops products focused on making hydropo...
# 640   Online-to-Offline platforms for mobile phones ...
# 642                 It develops germicidal technologies
# 646                  Digital payments solutions company
# 649   It provides opportunities for its partner vend...
# 651   It builds AI based algorithms on video, voice ...
# 654        Online job searching and recruiting platform
# 661                    Provides healthy snacks for kids
# 668   It enables logistic companies to conncet with ...
# 669   Nutraceutical company developing evidence-base...
# 676   Learning platform for K-10 students looking fo...
# 677         The platform connects doctors with patients
# 678   Tech platform that connects logistics service ...
# 680       It provides insurance products in rural areas
# 682                Home Down Payment Assistance Program
# 684                   Offers various insurance products
# 685                           Mental healthtech startup
# 686                           Conversational AI startup
# 690                       Celebrity engagement platform
# 691   Online platform for legal, tax and compliance ...
# 697        It helps coaching institutes in digitization
# 700                       AI enabled radiology platform
# 701            It organises corporate wellness programs
# 704             Operates electric vehicle charging zone
# 708   It offers a wide range of business related ser...
# 711         Helps online businesses with visual content
# 715   It provides a platform for entrepreneurs to ac...
# 716                          Open global money platform
# 719                          Provides trucking services
# 723   AI-powered 'no-code' platform which can genera...
# 724           Digital insurance platform for businesses
# 726                     Ai driven supply chain platform
# 727   They are developing technology that can detect...
# 734   It helps doctors engage with patients, improve...
# 735   It is a platform that digitalises local newspa...
# 736             It provides co-living and student rooms
# 740   It is alearning platform for kids in the age g...
# 743   It drives a cultural change in making yoga-bas...
# 744              AI video bot platform for career hacks
# 750   It builds algorithmic investing-based tech pro...
# 752            Provides investment management solutions
# 760   A marketplace to buy and sell used bikes and s...
# 763                 Water purifier subscription service
# 765                       Provides fresh dairy products
# 767            Platform for vernacular test-preparation
# 773         A subscription-only digital media publisher
# 775      It connects patients with healthcare companies
# 776   It offers experiential, guided tours on smart ...
# 782           Offers health supplements related gummies
# 783   It helps companies with moving assets  increas...
# 794   It Provides an interactive fiction entertainme...
# 804   It provides predictive insights to clients by ...
# 814   They help find solutions to insurance related ...
# 815                          Cancer diagnostics startup
# 818           Cloud data managemnt solutions enterprise
# 820                            Electric vehicle startup
# 823                  Offers financial products for SMEs
# 824                    It offers various healthy snacks
# 825   It connects women to healthproviders for speci...
# 839   It helps SMEs to maintain their accounts and l...
# 843           A puja cotton-wicks manufacturing startup
# 845   A tech-enabled ID verification and data collec...
# 846   Platform is an end-to-end college and career c...
# 855                 Marketplace for fashionable apparel
# 856   Provides a structured educational approach to ...
# 857   Online store to buy various types of socks inc...
# 858                                   Retail Aggregator
# 864   It sells ready to drink cold brew coffees, bre...
# 866                         Inter-City Mobility Startup
# 873   It offers content and material via video, adop...
# 875   A premium chain of youth hostels catering to t...
# 880   It leverages a Machine Learning-based approach...
# 882                                 Provides easy loans
# 892                            Electric vehicle startup
# 909   AI automation platform for enterprise quality ...
# 912                           Student Co-living startup
# 913   The learning platform that blends curriculum-b...
# 914                            Co working space startup
# 917                        Offer cybersecurity services
# 932           Makes helmets that are IoT and AI enabled
# 942          Provides crash course for NEET preparation
# 947             It sells modern age bicycles named FROG
# 954   Trains students in managemnt and leadership sk...
# 955                           Provides Gluten-free food
# 957              Provides financial assistance to MSMEs
# 960   It builds electric vehicles and supporting inf...
# 971   Runs real estate SaaS platform MultiplyMyLeads...
# 977                      Revenue based finance provider
# 978                      Provides online coding courses
# 979                 Retail payment and hardware company
# 980   Augmented writing platform which improves cust...
# 981   Integrated platform for Receivables and Payabl...
# 997   Automates everyday HR processes with integrate...
# 998                Online pharmacy dealing in medicines
# 999                      Provides IoT-enabled treadmill
# 1003                           Deals in office supplies
# 1013     Markets and sells chewable dietary supplements
# 1020     Ayurveda wellness and lifestyle consumer brand
# 1021  Provides platform for Corporates to connect es...
# 1022  Provides effective Instant Coffee Infused with...
# 1023       Solar module cleaning system [MCS] providers
# 1024     Provides online courses on foundational skills
# 1028  Provides cardless cash withdrawals through sma...
# 1040  It helps developers to test, integrate and dep...
# 1046  Smart agriculture management ERP software plat...
#
#                                                Founders  \
# 2                                       Ajinkya Dhariya
# 7                                      Shawrya Mehrotra
# 11             Arjun Kumar, Arun Kumar, Sidharth Gurjar
# 12                                        Gayatri Jolly
# 18                                           Amrish Rau
# 20                            Parth Chadha, Rahul Singh
# 28                                      Priyam Saraswat
# 35                                        Suhail Narain
# 40                                           Tikam Jain
# 47                                         Anoop Gautam
# 52           Anurag Meena, Nikunj Malpani, Pratik Lodha
# 53                    Satya Chakravarthy, Pranjal Mehta
# 61                                           Vivek Iyer
# 62                     Manjunatha T N, Shilpa Gopalaiah
# 63                                          Layak Singh
# 64         Puneet Singh Jaggi, Sanjay Bhasin, Ram Menon
# 65                                       Nandini Sankar
# 68                                         Shan Kadavil
# 69                         Shivam Varshney, Alok Chawla
# 72     Anugrah Shrivastava, Rohan Gupta, Vasanth Kamath
# 74             Soham Thacker, Valay Patel, Varun Gajjar
# 90                       Amit Shrivastava, Sumeet Verma
# 96                      NAVEED AHAMED, SYED SAQQA ABBAS
# 97         Annanya Sarthak, Gurpreet Singh, Praveen Sah
# 105                                                 NaN
# 106                                         Divij Bajaj
# 110                                         Rajith Nair
# 114                                  Rohin Y, PV Ramana
# 115                       Nikhil Aggarwal, Vivek Gulati
# 116   Gaurav Munjal, Hemesh Singh, Roman Saini, Sach...
# 120                                       Falguni Nayar
# 123                          Aditya Sharma, Jayesh Hans
# 132   Aditya Sengupta, Akash Gehani, Harshad Sharma,...
# 137                         Dhruv Dewan, Krishi Fagwani
# 138                                        Lakshay Jain
# 142                                          Ashwin Lal
# 143                    Khushnud Khan, Rishi Raj Rathore
# 148                                        Ashish Rawat
# 149                                  Shrishti, Prithika
# 155                           Amit Kumar, Gunjeet Singh
# 163                                        Sujay Santra
# 166                         Saurabh Uttam, Ravi Singhal
# 170                                        Anjana Reddy
# 171                                      Vivek Bhutyani
# 173   Gireesh Rajendran, Ashish Lachhwani, Apu Sivad...
# 180                          Altaf Saiyed, Saloni Anand
# 182                   Shivank Agarwal, Anish Khandelwal
# 185                                       Jatin Solanki
# 193             Nilay Pandey, Saurav Singh, Vivek Kumar
# 194                         Siddharth Dialani, Sai Gole
# 203                                       Aneesh Mathur
# 204         Aanan Khurma, Aditya Seth, Ripunjay Chachan
# 205                                       Falguni Nayar
# 210                                                 NaN
# 213                                       Falguni Nayar
# 214                      Sagar Bhalotia, Anish Basu Roy
# 228                        Gomathi S, Dr Balaji Sampath
# 244                                       Pankaj Sharma
# 246                                        M R Srinivas
# 251                     Arun Sreyas, Gautham Maheswaran
# 256                                     Supratik Ghatak
# 257                                    Surender Gounder
# 258                          Ranodeep Saha, Vijay Kumar
# 263                       Tushar Bhargava, Anshul Gupta
# 265                                        Arjun Balaji
# 286            Nagmanjunath Shivakumar, Savio Sebastian
# 288   Abhinand Kaseti, Harish B V, Sathvik Vishwanat...
# 289                       Andrew Linfoot, Ayush Jaiswal
# 291                                       Vaibhav Anant
# 292                          Kabandi Saika, Manik Mehta
# 298                         Bharat Gupta, Pritesh Kumar
# 314   Balaji Viswanathan, Bharat Kumar, Mahalakshmi ...
# 316        Suhail Chandhok, Arvind Sivdas, Dhanya Param
# 331                                    Deepshikha Kumar
# 332                                        Suhas raikar
# 333                       Darshan Shah, Soniya Kundnani
# 347                                      Deepthi Ravula
# 349                     Abhishek Satish, Adarsh Warrier
# 355                              Saswat Sahu, Rishi Raj
# 363                         Shubham Gupta, Suresh Singh
# 368                       Ashwin Kumar, Shoaib Mohammed
# 369           Damien Toledo, Jim Bugwadia, Ritesh Patel
# 370                                   Anmol Singh Jaggi
# 371                                        Ashish Rawat
# ...
# 642   Beyond Next Ventures, ArthaVida Ventures, Dr A...  Undisclosed
# 646   Entrepreneurial Development Bank, Bessemer Ven...  Undisclosed
# 649                                   Venture Catalysts  Undisclosed
# 651                                            Pratithi  Undisclosed
# 654   Dr Apoorva Ranjan Sharma, Mrunal Jhaveri, Nira...  Undisclosed
# 661                               Rangsons Technologies  Undisclosed
# 668   Leo Capaitals, Amit Gupta, Abhishek Goyal, Ram...  Undisclosed
# 669                               DSG Consumer Partners  Undisclosed
# 676         Stellaris Venture Partners, Venture Highway  Undisclosed
# 677      River Rock Ventures. Inflection Point Ventures  Undisclosed
# 678                                    Trifecta Capital  Undisclosed
# 680               EMVC, Flourish, Omidyar Network India  Undisclosed
# 682                                Varanium NexGen Fund  Undisclosed
# 684   Bharat Inclusion Seed Fund, Varanium Capital, ...  Undisclosed
# 685                                         Amit Burman  Undisclosed
# 686                                       Bharti Airtel  Undisclosed
# 690   Kalyan Krishnamurthy, Sujeet Kumar, Keshav San...  Undisclosed
# 691                                        Sujeet Kumar  Undisclosed
# 697                            Ankit Bhati, Nitin Gupta  Undisclosed
# 700                                     GHV Accelerator  Undisclosed
# 701                           Josh Liberman, Mark Adams  Undisclosed
# 704                               Mumbai Angels Network  Undisclosed
# 708                         Unicorn Investments Pte Ltd  Undisclosed
# 711   Angellist, Smile Group, Manish Amin, Anil Goel...  Undisclosed
# 715                                          Ratan Tata  Undisclosed
# 716                          VisaVentures, BRI Ventures  Undisclosed
# 719                                    Trifecta Venture  Undisclosed
# 723                   Hari Balasubramanian, EaSyndicate  Undisclosed
# 724                                        Good Capital  Undisclosed
# 726                               Mumbai Angels Network  Undisclosed
# 727                              Unicorn India Ventures  Undisclosed
# 734                                  RiverRock Ventures  Undisclosed
# 735                               Mumbai Angels Network  Undisclosed
# 736                               Mumbai Angels Network  Undisclosed
# 740                                   Venture Catalysts  Undisclosed
# 743                        Mantra Capital, Patni Family  Undisclosed
# 744   Nikhil Vora, Iceland Venture Studio, LetsVentu...  Undisclosed
# 750              Ravikanth Reddy & Mumbai Angel Network  Undisclosed
# 752                                    Pinetree Capital  Undisclosed
# 760                                     Stride Ventures  Undisclosed
# 763     Abhishek Goyal, Bharat Jaisinghani, FirstCheque  Undisclosed
# 765                                       Angel Network  Undisclosed
# 767   INSEAD Angels, IIT Kanpur Angels, Sixth Sense ...  Undisclosed
# 773                                     Angel investors  Undisclosed
# 775                                            Indie VC  Undisclosed
# 776                               Mumbai Angels Network  Undisclosed
# 782                                   Venture Catalysts  Undisclosed
# 783                                      Better Capital  Undisclosed
# 794   Better Capital, LetsVenture, Rohit Chanana, Ja...  Undisclosed
# 804                                   Arka Venture Labs  Undisclosed
# 814                                   Venture Catalysts  Undisclosed
# 815                              Unicorn India ventures  Undisclosed
# 818                                  Ideaspring capital  Undisclosed
# 820                                      MG Motor India  Undisclosed
# 823         Ashneer Grover, Kunal Shah, Ramakant Sharma  Undisclosed
# 824                                         Undisclosed  Undisclosed
# 825               KYT Ventures, First Cheque, AngelList  Undisclosed
# 839                                Mahendra Singh Dhoni  Undisclosed
# 843                                   Venture Catalysts  Undisclosed
# 845                              Orios Venture Partners  Undisclosed
# 846                                        Vishal Dixit  Undisclosed
# 855                Lead Angels Network, Stanford Angels  Undisclosed
# 856                             Education Catalyst Fund  Undisclosed
# 857                                       Angel network  Undisclosed
# 858                               LetsVenture investors  Undisclosed
# 864                                       Rukam Capital  Undisclosed
# 866                                               Ixigo  Undisclosed
# 873                                           Yuanfudao  Undisclosed
# 875                                    Atraxn Partners.  Undisclosed
# 880                                Indian Angel Network  Undisclosed
# 882                                     Accelerator MOX  Undisclosed
# 892                                          AdvantEdge  Undisclosed
# 909                         Triton Investment Advisors,  Undisclosed
# 912                           Kolte-Patil Family Office  Undisclosed
# 913                                      Ashwin Khorana  Undisclosed
# 914                                        Tarun Bhalla  Undisclosed
# 917                                         Z3 Partners  Undisclosed
# 932                                   Venture Catalysts  Undisclosed
# 942                                       IndiaQuotient  Undisclosed
# 947                       Avaana Capital, Titan Capital  Undisclosed
# 954                                 Equanimity Ventures  Undisclosed
# 955                           Mistletoe, Info Edge Asia  Undisclosed
# 957   JITO Angel Network, Ketan Kothari, Girish Jain...  Undisclosed
# 960                  GrowX ventures, Prophetic Ventures  Undisclosed
# 971   Frontline Strategy Finds, SucSEED Venture Part...  Undisclosed
# 977                 Samyakth Capital, Venture Catalysts  Undisclosed
# 978                                     Angel investors  Undisclosed
# 979                                          Mastercard  Undisclosed
# 980                               SOSV, Chinaccelerator  Undisclosed
# 981                                   Venture Catalysts  Undisclosed
# 997                           Yatra Angel Network (YAN)  Undisclosed
# 998                                     Angel investors  Undisclosed
# 999                                     Angel investors  Undisclosed
# 1003                                        Undisclosed  Undisclosed
# 1013                              DSG Consumer Partners  Undisclosed
# 1020  Sprout Venture Partners, JITO Angel Network, L...  Undisclosed
# 1021                                  Venture Catalysts  Undisclosed
# 1022                                      Refex Capital  Undisclosed
# 1023                                  Venture Catalysts  Undisclosed
# 1024                     James Murdoch-led Lupa Systems  Undisclosed
# 1028  IIM Ahmedabad’s incubator (CIIE.CO),Chandigarh...  Undisclosed
# 1040                   HNIs in India, Japan, and the US  Undisclosed
# 1046                                          TechnoGen  Undisclosed
#
#                 Stage Unnamed: 9
# 2            Pre-seed        NaN
# 7          Pre-series        NaN
# 11           Series A        NaN
# 12                NaN        NaN
# 18                NaN        NaN
# 20       Pre-series A        NaN
# 28           Pre-seed        NaN
# 35       Pre-series A        NaN
# 40                NaN        NaN
# 47               Seed        NaN
# 52           Pre-seed        NaN
# 53               Seed        NaN
# 61                NaN        NaN
# 62                NaN        NaN
# 63                NaN        NaN
# 64               Seed        NaN
# 65               Seed        NaN
# 68                NaN        NaN
# 69               Seed        NaN
# 72                NaN        NaN
# 74               Seed        NaN
# 90                NaN        NaN
# 96               Seed        NaN
# 97       Pre-series B        NaN
# 105               NaN        NaN
# 106            Bridge        NaN
# 110               NaN        NaN
# 114               NaN        NaN
# 115      Pre-series A        NaN
# 116               NaN        NaN
# 120               NaN        NaN
# 123              Seed        NaN
# 132               NaN        NaN
# 137      Pre-series A        NaN
# 138      Pre-series A        NaN
# 142      Pre-series A        NaN
# 143               NaN        NaN
# 148      Pre-series A        NaN
# 149      Pre-series A        NaN
# 155              Seed        NaN
# 163               NaN        NaN
# 166               NaN        NaN
# 170               NaN        NaN
# 171               NaN        NaN
# 173               NaN        NaN
# 180              Seed        NaN
# 182               NaN        NaN
# 185               NaN        NaN
# 193               NaN        NaN
# 194      Pre-series A        NaN
# 203               NaN        NaN
# 204      Pre-series A        NaN
# 205               NaN        NaN
# 210            Bridge        NaN
# 213               NaN        NaN
# 214               NaN        NaN
# 228          Series A        NaN
# 244              Seed        NaN
# 246               NaN        NaN
# 251               NaN        NaN
# 256          Pre-seed        NaN
# 257              Seed        NaN
# 258      Pre-series A        NaN
# 263              Seed        NaN
# 265               NaN        NaN
# 286              Seed        NaN
# 288          Series A        NaN
# 289               NaN        NaN
# 291          Pre-seed        NaN
# 292      Pre-series A        NaN
# 298              Seed        NaN
# 314               NaN        NaN
# 316               NaN        NaN
# 331               NaN        NaN
# 332               NaN        NaN
# 333               NaN        NaN
# 347               NaN        NaN
# 349               NaN        NaN
# 355               NaN        NaN
# 363               NaN        NaN
# 368               NaN        NaN
# 369               NaN        NaN
# 370              Seed        NaN
# 371      Pre-series A        NaN
# 377              Seed        NaN
# 381      Pre-series A        NaN
# 383              Seed        NaN
# 395              Seed        NaN
# 399              Seed        NaN
# 411      Pre-series A        NaN
# 448      Pre-series A        NaN
# 462      Seed Funding        NaN
# 478               NaN        NaN
# 479          Pre-Seed        NaN
# 480               NaN        NaN
# 481               NaN        NaN
# 482               NaN        NaN
# 489               NaN        NaN
# 493    Pre-seed Round        NaN
# 496               NaN        NaN
# 498        Seed round        NaN
# 501               NaN        NaN
# 505               NaN        NaN
# 507    Pre seed Round        NaN
# 510               NaN        NaN
# 511        Seed round        NaN
# 516       Angel Round        NaN
# 519               NaN        NaN
# 525               NaN        NaN
# 529               NaN        NaN
# 536        Seed round        NaN
# 537       Angel Round        NaN
# 543               NaN        NaN
# 544        Seed Round        NaN
# 546      Bridge Round        NaN
# 553        Seed Round        NaN
# 556               NaN        NaN
# 558               NaN        NaN
# 562      Pre series A        NaN
# 567        Seed Round        NaN
# 575               NaN        NaN
# 576      Pre series A        NaN
# 577        Seed Round        NaN
# 585    Pre seed round        NaN
# 589        Seed Round        NaN
# 590               NaN        NaN
# 592               NaN        NaN
# 596               NaN        NaN
# 603               NaN        NaN
# 611          Pre-Seed   Pre-Seed
# 614        Seed Round        NaN
# 615    Pre-seed Round        NaN
# 616               NaN        NaN
# 618               NaN        NaN
# 624   Seed Investment        NaN
# 629          Series B        NaN
# 635        Seed Round        NaN
# 636               NaN        NaN
# 638               NaN        NaN
# 640               NaN        NaN
# 642        Seed Round        NaN
# 646          Series C        NaN
# 649               NaN        NaN
# 651               NaN        NaN
# 654               NaN        NaN
# 661      Pre series A        NaN
# 668        Seed Round        NaN
# 669      Pre series A        NaN
# 676        Seed Round        NaN
# 677      Pre series A        NaN
# 678               NaN        NaN
# 680      Pre series A        NaN
# 682               NaN        NaN
# 684      Pre series A        NaN
# 685      Pre series A        NaN
# 686               NaN        NaN
# 690               NaN        NaN
# 691               NaN        NaN
# 697               NaN        NaN
# 700               NaN        NaN
# 701               NaN        NaN
# 704               NaN        NaN
# 708        Seed Round        NaN
# 711      Pre series A        NaN
# 715               NaN        NaN
# 716               NaN        NaN
# 719               NaN        NaN
# 723        Seed Round        NaN
# 724      Pre series A        NaN
# 726               NaN        NaN
# 727               NaN        NaN
# 734      Pre series A        NaN
# 735               NaN        NaN
# 736               NaN        NaN
# 740               NaN        NaN
# 743               NaN        NaN
# 744        Seed Round        NaN
# 750               NaN        NaN
# 752      Pre series A        NaN
# 760               NaN        NaN
# 763        Seed Round        NaN
# 765               NaN        NaN
# 767      Pre series A        NaN
# 773        Seed Round        NaN
# 775               NaN        NaN
# 776      Pre series A        NaN
# 782               NaN        NaN
# 783               NaN        NaN
# 794       Angel Round        NaN
# 804               NaN        NaN
# 814        Seed Round        NaN
# 815               NaN        NaN
# 818               NaN        NaN
# 820               NaN        NaN
# 823    Pre seed round        NaN
# 824        Seed Round        NaN
# 825        Seed Round        NaN
# 839               NaN        NaN
# 843        Seed Round        NaN
# 845               NaN        NaN
# 846               NaN        NaN
# 855               NaN        NaN
# 856               NaN        NaN
# 857               NaN        NaN
# 858        Seed Round        NaN
# 864               NaN        NaN
# 866               NaN        NaN
# 873      Pre series A        NaN
# 875               NaN        NaN
# 880               NaN        NaN
# 882               NaN        NaN
# 892               NaN        NaN
# 909               NaN        NaN
# 912               NaN        NaN
# 913               NaN        NaN
# 914               NaN        NaN
# 917          Series A        NaN
# 932               NaN        NaN
# 942               NaN        NaN
# 947               NaN        NaN
# 954      Pre series A        NaN
# 955               NaN        NaN
# 957               NaN        NaN
# 960        Seed Round        NaN
# 971               NaN        NaN
# 977        Seed Round        NaN
# 978               NaN        NaN
# 979               NaN        NaN
# 980               NaN        NaN
# 981               NaN        NaN
# 997               NaN        NaN
# 998               NaN        NaN
# 999               NaN        NaN
# 1003              NaN        NaN
# 1013     Pre Series A        NaN
# 1020       Seed Round        NaN
# 1021              NaN        NaN
# 1022              NaN        NaN
# 1023              NaN        NaN
# 1024              NaN        NaN
# 1028              NaN        NaN
# 1040       Seed Round        NaN
# 1046         Series A        NaN

# %%
# replacing all Undisclosed in the Amount($) column with 0
data_2020.loc[data_2020['Amount($)']=='Undisclosed',['Amount($)']]=[0]

# %%
# removing all special characters in the colum
data_2020["Amount($)"]=data_2020['Amount($)'].apply(lambda x: str(x).replace("$" ,"")) 
data_2020["Amount($)"]=data_2020['Amount($)'].apply(lambda x: str(x).replace("," ,""))

# %%
# change the data type to a float
# The downcast parameter is used to set the data type to float
data_2020['Amount($)'] = pd.to_numeric(data_2020['Amount($)'], errors='coerce', downcast='float')

# %%
# Replacing nan values with median
data_2020['Amount($)']=data_2020['Amount($)'].fillna(data_2020['Amount($)'].median())

# %% [markdown]
# ### Cleaning the Stage Column

# %%
data_2020['Stage'].unique()
# Out:
# array([nan, 'Pre-seed', 'Seed', 'Pre-series A', 'Pre-series', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Series E', 'Bridge', 'Series D', 'Series B2', 'Series F',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Seed round',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Pre series A', 'Seed Round', 'Bridge Round', 'Pre seed round',
#        'Pre series B', 'Pre series C', 'Seed Investment', 'Series D1',
#        'Mid series', 'Series C, D', 'Seed funding'], dtype=object)

# %%
data_2020.replace({'Stage':{'Pre-Seed':'Seed','Pre-series A':'Series A','Pre-series':'Seed','Pre-series C':'Series C',
                            'Pre-Series B':'Series B','Series A-1':'Series A','Seed Funding':'Seed','Seed round':'Seed',
                            'Pre-seed Round':'Seed','Pre seed Round':'Seed','Seed Round & Series A':'Series A',
                            'Pre Series A':'Series A','Angel Round':'Seed','Pre series A1':'Series A','Series E2':'Series E',
                            'Pre series A':'Series A','Seed Round':'Seed','Bridge Round':'Seed','Bridge':'Seed',
                            'Edge':'Seed','Pre seed round':'Seed','Pre series B':'Series B','Pre series C':'Series C',
                            'Pre series A1':'Series A','Series D1':'Series D','Mid series':'Seed','Series C, D':'Series C',
                           'Pre-series B':'Series B','Series B2':'Series B','Pre- series A':'Series A',
                           'PPre-seed':'Seed','Seed funding':'Seed','Seed A':'Series A','Pre-seed':'Seed','Debt':'Seed','Debt':'Seed',
                            'Angel':'Seed','Secondary Market':'Seed','Equity':'Seed','Grant':'Seed',
                            'Seed Investment':'Seed'}},inplace=True)
data_2020['Stage'].unique()
# Out:
# array([nan, 'Seed', 'Series A', 'Series C', 'Series B', 'Series E',
#        'Series D', 'Series F', 'Series H'], dtype=object)

# %%
# replacing all nan with Unknown
data_2020['Stage']=data_2020['Stage'].fillna('Seed')

# %% [markdown]
# ### Cleaning the `Founders` Column

# %%
# all nan values are to be filled with unknown on the 
data_2020['Founders']=data_2020['Founders'].fillna('Seed')

# %% [markdown]
# ### Cleaning the `Investor` Column

# %%
# all nan values are to be filled with unknown on the 
data_2020['Investor']=data_2020['Investor'].fillna('Unknown')

# %%
# checking for duplicate entries
data_2020.duplicated().value_counts()
# Out:
# False    1052
# True        3
# dtype: int64

# %%
# remove the duplicate record
data_2020=data_2020.drop_duplicates(keep='first')

# %%
data_2020.isnull().sum()
# Out:
# Company/Brand       0
# Founded             0
# HeadQuarter         0
# Sector              0
# What it does        0
# Founders            0
# Investor            0
# Amount($)           0
# Stage               0
# Unnamed: 9       1050
# dtype: int64

# %% [markdown]
# # 2021 Data Set

# %%
data_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %% [markdown]
# ### Cleaning the Founded Column

# %%
data_2021['Founded'].unique()
# Out:
# array([2019., 2015., 2012., 2021., 2014., 2018., 2016., 2020., 2010.,
#        2017., 1993., 2008., 2013., 1999., 1989., 2011.,   nan, 2009.,
#        2002., 1994., 2006., 2000., 2007., 1978., 2003., 1998., 1991.,
#        1984., 2004., 2005., 1963.])

# %%
# convert the data type from float to a string
data_2021['Founded']=data_2021['Founded'].astype(str) 

# removing the decimal points in the year, slicing is used to pick the whole number only
data_2021['Founded']=data_2021.Founded.str.split('.').str[0]

# %%
# changing the data type to numeric
data_2021['Founded']=pd.to_numeric(data_2021['Founded'],errors='coerce',downcast='unsigned')

# %%
# replacing nan with 2021 since it is a 2021 data set
data_2021['Founded']=data_2021['Founded'].fillna(2021)

# %%
data_2021['Founded'].unique()
# Out:
# array([2019., 2015., 2012., 2021., 2014., 2018., 2016., 2020., 2010.,
#        2017., 1993., 2008., 2013., 1999., 1989., 2011., 2009., 2002.,
#        1994., 2006., 2000., 2007., 1978., 2003., 1998., 1991., 1984.,
#        2004., 2005., 1963.])

# %% [markdown]
# ### Cleaning the HeadQuarter Column

# %%
data_2021['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
#        'Online Media\t#REF!', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
# checking for the record with Information Technology & Services at the headquater column
data_2021.loc[data_2021['HeadQuarter']=='Information Technology & Services']
# Out:
#      Company/Brand  Founded                        HeadQuarter  \
# 1176          Peak   2014.0  Information Technology & Services
#
#                               Sector  \
# 1176  Manchester, Greater Manchester
#
#                                            What it does     Founders  \
# 1176  Peak helps the world's smartest companies put ...  Atul Sharma
#
#                     Investor  Amount($)     Stage
# 1176  SoftBank Vision Fund 2  $75000000  Series C

# %% [markdown]
# It is realized that the values at the Sector column and the HeadQuarter column has been interchanged. This is corrected in the cell below.

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='Peak',['HeadQuarter','Sector']]=['Manchester','IT']

# %%
# checking for the record with Online Media\t#REF! at the headquater column
data_2021.loc[data_2021['HeadQuarter']=='Online Media\t#REF!']
# Out:
#      Company/Brand  Founded          HeadQuarter  \
# 1100      Sochcast   2020.0  Online Media\t#REF!
#
#                                                  Sector  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                            What it does  \
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   NaN

# %% [markdown]
# The correction of the transposition is done in the cell below

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='Sochcast',['HeadQuarter','Sector','What it does']]=['Mountain View','Media and Entertainment','Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience']

# %%
# checking for the record with Gurugram\t#REF! at the headquater column
data_2021.loc[data_2021['HeadQuarter']=='Gurugram\t#REF!']
# Out:
#     Company/Brand  Founded      HeadQuarter  \
# 257       MoEVing   2021.0  Gurugram\t#REF!
#
#                                                 Sector  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                     What it does  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Founders  Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000      Seed   NaN

# %% [markdown]
# The correction together with the sector which has now been identified is done in the code below

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='MoEVing',['HeadQuarter','Sector']]=['Gurugram','Automotive']

# %%
# checking for the record with Food & Beverages at the headquater column
data_2021.loc[data_2021['HeadQuarter']=='Food & Beverages']
# Out:
#     Company/Brand  Founded       HeadQuarter     Sector  \
# 241    MasterChow   2020.0  Food & Beverages  Hauz Khas
# 255    MasterChow   2020.0  Food & Beverages  Hauz Khas
#
#                             What it does                       Founders  \
# 241  A ready-to-cook Asian cuisine brand  Vidur Kataria, Sidhanth Madan
# 255  A ready-to-cook Asian cuisine brand  Vidur Kataria, Sidhanth Madan
#
#          Investor Amount($) Stage
# 241  WEH Ventures   $461000  Seed
# 255  WEH Ventures   $461000  Seed

# %% [markdown]
# This investigation also revealed a duplicated entry. The second entry with index 255 will be dropped and then the correction will be done

# %%
# dropping the duplicate with its index
data_2021.drop(index=[255],axis=0, inplace=True)

# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='MasterChow',['HeadQuarter','Sector']]=['Hauz Khas', 'Catering']

# %%
# checking for the record with Computer Games at the headquater column
data_2021.loc[data_2021['HeadQuarter']=='Computer Games']
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 98        FanPlay   2020.0  Computer Games  Computer Games
# 111       FanPlay   2020.0  Computer Games  Computer Games
#
#                                           What it does Founders  \
# 98   A real money game app specializing in trivia g...   YC W21
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor Amount($)     Stage
# 98   Pritesh Kumar, Bharat Gupta  Upsparks  $1200000
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000

# %% [markdown]
# This investigation also revealed a duplicated entry. The second entry with index 111 will be dropped and then the correction will be done.
#
# It also revealed that the amount and stage column has been interchanged.

# %%
# dropping the duplicate with its index
data_2021.drop(index=[111],axis=0, inplace=True)

# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='FanPlay',['HeadQuarter','Sector','Stage','Amount($)']]=['New York', 'Gaming','Unknown',1200000]

# %%
# checking for the record with Pharmaceuticals\t#REF! at the headquater column
data_2021.loc[data_2021['HeadQuarter']=='Pharmaceuticals\t#REF!']
# Out:
#           Company/Brand  Founded             HeadQuarter  \
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %% [markdown]
# This investigation also revealed a duplicated entry. The second entry with index 256 will be dropped and then the correction will be done

# %%
# dropping the duplicate with its index
data_2021.drop(index=[256],axis=0, inplace=True)

# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='Fullife Healthcare',['HeadQuarter','Sector']]=['Unknown', 'Healthcare']

# %%
data_2021.replace({'HeadQuarter':{'New Delhi':'Delhi','Small Towns, Andhra Pradesh':'Andhra Pradesh',
                                 'Thiruvananthapuram':'Trivandrum','Mountain View, CA':'Mountain View',
                                 'Mangalore':'Bengaluru','Bangalore':'Bengaluru'}}, inplace=True)

# %%
# replacing nan with Delhi on the assumption that i is an India startup data set
data_2021['HeadQuarter']=data_2021['HeadQuarter'].fillna('Delhi')

# %% [markdown]
# ### Cleaning the Sector Column

# %%
data_2021['Sector'].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Catering', 'Cosmetics',
#        'Mobility', 'Social media', 'Real Estate', 'Digital platform',
#        'B2B Ecommerce', 'Online Media', 'Social commerce', 'Mobile Games',
#        'Food Production', 'Podcast', 'HeathTech', 'Battery',
#        'Content publishing', 'Water purification', 'Content commerce',
#        'Innovation Management', 'Software company', 'Automation',
#        'Food Industry', 'Celebrity Engagement', 'Trading platform',
#        'Personal Care', 'Cannabis startup', 'Blogging', 'Consulting',
#        'BioTechnology', 'B2B Marketplace', 'Health care', 'Social audio',
#        'Fashion and lifestyle', 'Delivery service', 'B2B Manufacturing',
#        'Home Decor', 'Solar', 'TaaS startup', 'EV startup', 'HR Tech',
#        'Blockchain startup', 'Food and Beverages', 'Beverages',
#        'Manufacturing startup', 'Cryptocurrency',
#        'Vehicle repair startup', 'Advisory firm', 'Legaltech',
#        'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup', 'Media and Entertainment',
#        'Design', 'B2B Travel', 'Interior Design', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
#rename similar sectors with wrong or different spelling to make it consistent
data_2021.replace({'Sector':{'Ecommerce':'E-Commerce','Edtech':'EdTech','Interior design':'Home Decor','Virtual Banking':'Financial Services',
                           'AgriTech':'AgTech','E-commerce & AR':'E-Commerce','Fintech':'FinTech','Infratech':'IT','B2B Supply Chain':'E-Commerce',
                           'Marketing & Customer loyalty':'Customer Service','Automobile & Technology':'Automotive','Transport & Rentals':'Transportation',
                           'HR tech':'Human Resources','AI & Tech':'AI','E-commerce':'E-Commerce','Travel':'Transportation','Health Care':'Healthcare',
                           'Commercial Real Estate':'Real Estate','Cooking':'Catering','Fantasy Sports':'Sports','Consumer':'Consumer Goods',
                           'Healthtech':'Healthcare','E-Sports':'Sports','Mutual Funds':'Finance','Legal tech':'Legal','Accomodation':'Real Estate',
                           'Consumer Lending':'Consumer Goods','Credit':'Credit Cards','Business Travel':'Transportation','Hospital':'Healthcare',
                           'Automobile':'Automotive','Alternative Medicine':'Healthcare','Renewable Energy':'Energy','Clean Energy':'Energy','Music':'Music Streaming',
                           'Health Diagnostics':'Healthcare','Medical':'Healthcare','Enterprise Software':'ERP','Enterprise Resource Planning (ERP)':'ERP',
                           'Audio':'Music Streaming','Air Transportation':'Aerospace','Yoga & wellness':'Fitness','Beauty':'Cosmetics','Big Data':'Analytics',
                           'Food and Beverage':'Catering','Wealth Management':'Finance','Social Media':'Digital Media','Broadcasting':'Media and Entertainment',
                           'News':'Media and Entertainment','Packaging Services':'Logistics','Mobile':'Mobile Phones','Medical Device':'Healthcare',
                           'Continuing Education':'Education','Dental':'Healthcare','Android':'Software','Banking':'Financial Services','Training':'Education',
                           'Digital Marketing':'Advertising','Marketplace':'Advertising','Consumer Electronics':'Consumer Goods','Rental':'Facilities Support Services',
                           'Retail':'Business Development','3D Printing':'Creative Agency','Electric Vehicle':'Automotive','Industrial Automation':'Manufacturing',
                           'Battery':'Energy','Reading Apps':'Apps','B2B':'E-Commerce','Communities':'Environmental Consulting','Smart Cities':'Environmental Consulting',
                           'Health Insurance':'Insurance','Commercial':'Business Development','Digital Entertainment':'Digital Media','Food & tech':'Catering',
                           'Cloud Infrastructure':'Cloud Computing','Marketing':'Advertising','Events':'Creative Agency','Food tech':'Catering',
                           'Artificial Intelligence':'AI','Business Intelligence':'ERP','Information Services':'IT','Information Technology':'IT',
                           'E-Learning':'Education','Tourism':'Hospitality','Industrial':'Manufacturing','Internet':'IT','Internet of Things':'IoT',
                           'Jewellery':'Fashion','Food & Nutrition':'Healthcare','Robotics & AI':'AI', 'E-marketplace':'E-Commerce','Foodtech':'Catering',
                           'Insurance technology':'Insurance','Pharmaceutical':'Healthcare','Safety tech':'Cybersecurity',"Fashion startup":'Fashion',
                             'Deisgning':'Creative Agency','Pharmacy':'Healthcare','Consultancy':'Creative Agency','Tech hub':'IT','E-connect':'Digital Media',
                             'B2B Agritech':'AgTech','Food diet':'Healthcare','Preschool Daycare':'Child Care','AI Robotics':'AI','SaaS/Edtech':'Saas',
                             'Transport & Rentals':'Transportation','Transport Automation':'Transportation','Neo-banking':'Financial Services',
                             'Ad-tech':'Advertising','E-mobility':'Mobile Payment','E tailor':'E-Commerce','Estore':'E-Commerce','Housing & Rentals':'Real Estate',
                             'AI & Deep learning':'AI','Sales & Services':'Business Development','VR & SaaS':'Saas','Hygiene':'CleanTech','Cleantech':'CleanTech',
                             'Visual Media':'Media and Entertainment','Content Marktplace':'Advertising','Machine Learning':'AI','AI & Media':'AI',
                             'E-tail':'E-Commerce','Automotive and Rentals':'Automotive','ravel tech':'Transportation','AI & Data science':'AI',
                             'Finance company':'Finance','Tech company':'IT','Solar Monitoring Company':'Energy','Video sharing platform':'Media and Entertainment',
                             'Gaming startup':'Gaming','Video streaming platform':'Media and Entertainment','Consumer appliances':'Consumer Goods',
                             'Blockchain startup':'Blockchain','Conversational AI platform':'AI','SaaS platform':'Saas','AI platform':'AI',
                             'Escrow':'Legal','Networking platform':'IT','Spacetech':'Aerospace','Trading platform':'E-Commerce','AI Company':'AI',
                             'Photonics startup':'Media and Entertainment','Entertainment':'Media and Entertainment','Scanning app':'Apps',
                             'Skincare startup':'Cosmetics','Food and Beverages':'Catering','FoodTech':'Catering','Biotechnology company':'Environmental Consulting',
                             'Proptech':'Facilities Support Services','Fitness startup':'Fitness','PaaS startup':'Saas','Beverages':'Catering',
                             'Automobiles':'Automotive','Deeptech':'AI','EV startup':'Environmental Consulting','AR/VR startup':'IT','Recruitment startup':'Human Resources',
                             'Tourism & EV':'Hospitality','QSR startup':'Customer Service','Video platform':'Media and Entertainment',
                             'Fusion beverages':'Catering','Job portal':'Human Resources','Dairy startup':'Catering','Content management':'Creative Agency',
                             'Work fulfillment':'Human Resources','HR Tech':'Human Resources','Software Company':'Software','Soil-Tech':'Agriculture',
                             'Travel & SaaS':'Transportation','Hygiene management':'CleanTech','Food & Bevarages':'Catering','Food Delivery':'Catering',
                             'Virtual auditing startup':'FinTech','HealthTech':'Healthcare','AI startup':'AI','Tech Startup':'IT','Medtech':'Healthcare',
                             'Tyre management':'Automotive','Cloud company':'Cloud Computing','Software company':'Software','Venture capitalist':'Finance',
                             'Renewable player':'Energy','IoT startup':'IoT','SaaS startup':'Saas','Aero company':'Aerospace','Marketing company':'Advertising',
                             'Retail startup':'Business Development','Co-working Startup':'Human Resources','—':'Unknown','Brand Marketing':'Advertising',
                             'Fertility tech':'Healthcare','Luxury car startup':'Automotive','FM':'Media and Entertainment','Food':'Catering',
                             'Nutrition sector':'Healthcare','Tech platform':'IT','Video':'Media and Entertainment','Retail Tech':'Business Development',
                             'HeathTech':'Healthcare','Sles and marketing':'Advertising','LegalTech':'Legal','Car Service':'Automotive',
                             'Bike marketplace':'Automotive','Agri tech':'AgTech','Reatil startup':'Business Development','AR platform':'IT',
                             'Content marketplace':'Creative Agency','Interior Design':'Home Decor','Home Design':'Home Decor','InsureTech':'Insurance',
                             'Rental space':'Facilities Support Services','Ayurveda tech':'IT','Packaging solution startup':'Logistics',
                             'Sanitation solutions':'CleanTech','HealthCare':'Healthcare','AI Startup':'AI','Solar solution':'Energy','Tech':'IT',
                             'Jewellery startup':'Fashion','Multinational conglomerate company':'Business Development','Deeptech startup':'AI',
                             'Social Network':'Digital Media','Publication':'Creative Agency','Venture capital':'Finance','Entreprenurship':'Business Development',
                             'E-market':'E-Commerce','Media & Networking':'Media and Entertainment','Automation tech':'Automotive','eMobility':'Mobile Payment',
                             'Food devlivery':'Catering','Warehouse':'Facilities Support Services','Online financial service':'FinTech',
                             'Eyeglasses':'Healthcare','Battery design':'Energy','Online credit management startup':'FinTech','Beverage':'Catering',
                             'TravelTech':'Transportation','Startup laboratory':'Business Development','Personal care startup':'Fitness',
                             'Customer service company':'Customer Service','SaaS\xa0\xa0startup':'Saas','Marketing startup':'Advertising',
                             'Service industry':'Human Resources','Social media':'Digital Media','R startup':'IT','HR Tech startup':'Human Resources',
                             'AR startup':'IT','Automotive Startup':'Automotive','Food Startup':'Catering','EdTech Startup':'Education',
                             'Car Trade':'Automotive','EdtTech':'Education','AI Platform':'AI','Automation':'Automotive','Solar SaaS':'Saas',
                             'WL & RAC protection':'Environmental Consulting','Social commerce':'E-Commerce','Home interior services':'Home Decor',
                             'Agritech startup':'AgTech','API platform':'Software','Deep Tech':'AI','Electricity':'Energy','Automotive company':'Automotive',
                             'FMCG':'Legal','Insurance Tech':'Insurance','Video personalization':'Media and Entertainment','Biomaterial startup':'Manufacturing',
                             'Health':'Healthcare','Craft Beer':'Creative Agency','Investment':'Finance','Linguistic Spiritual':'Education',
                             'Battery manufacturer':'Energy','Nano Distribution Network':'IT','AI health':'AI','Dating app':'Dating',
                             'Media':'Media and Entertainment','Healthcare/Edtech':'Healthcare','Social Commerce':'E-Commerce','Agritech/Commerce':'AgTech',
                             'Mobility tech':'Mobile Phones','Social e-commerce':'E-Commerce','Food & Logistics':'Logistics','SpaceTech':'Aerospace',
                             'Nutrition Tech':'Healthcare','HR':'Human Resources','nan':'Unknown','Agritech':'AgTech','AR/VR':'IT',
                             'Appliance':'Consumer Goods','Mental Health':'Healthcare','Solar Solution':'Energy','Saas':'SaaS','B2B marketplace':'E-Commerce',
                             'Fashion Tech':'Fashion','Nutrition tech':'Healthcare','Health & Wellness':'Fitness','Cloud Kitchen':'Cloud Computing',
                             'IoT/Automobile':'IoT','Eye Wear':'Healthcare','Digital tech':'IT','Data Intelligence':'ERP','Co-living':'Human Resources',
                             'Food & Beverages':'Catering','Defense tech':'Cybersecurity','Construction tech':'Construction','Nutrition':'Healthcare',
                             'Coworking':'Human Resources','Micro-mobiity':'Mobile Phones','Auto-tech':'Automotive','Robotics':'AI','Logitech':'IT',
                             'Med Tech':'Healthcare','Life sciences':'Healthcare','Retail Aggregator':'Business Development','Deep Tech AI':'AI',
                             'Biotech':'Environmental Consulting','HrTech':'Human Resources','AI & Debt':'AI','Transport':'Transportation',
                             'Co-working':'Human Resources','Insurtech':'Insurance','Automotive tech':'Automotive','EV':'Environmental Consulting',
                             'Supply chain, Agritech':'Logistics','Pharma':'Healthcare','Foodtech & Logistics':'Logistics','Housing':'Real Estate',
                             'Data Analytics':'ERP','Investment Tech':'Finance','Biopharma':'Healthcare','Dairy':'Catering','Beauty & wellness':'Fitness',
                             'Media Tech':'Media and Entertainment','E store':'E-Commerce','Data Science':'ERP','Travel tech':'Transportation',
                             'Techonology':'IT','Taxation':'Accounting','Automobile Technology':'Automotive','Food Industry':'Catering','Financial Services':'Financial Services',
                             'Interior & decor':'Home Decor','Health and Fitness':'Fitness','Location Analytics':'ERP','Mobility/Transport':'Transportation',
                           'Technology':'IT','Farming':'Agriculture','Food Processing':'Catering','Collaboration':'Human Resources','Computer':'IT','Career Planning':'Human Resources',
                           'Wedding':'Customer Service','Games':'Gaming','EdTech':'Education','B2B E-commerce':'E-Commerce','Home services':'Home Decor',
                            'B2B service':'E-Commerce','Electronics':'Automotive','IT startup':'IT','Oil and Energy':'Energy','Milk startup':'Catering',
                            'AI Chatbot':'AI','Food delivery':'Catering','Fantasy sports':'Sports','Video communication':'Media and Entertainment',
                            'Skill development':'Education','Recruitment':'Human Resources','Computer Games':'Gaming','Apparel & Fashion':'Fashion',
                            'Logistics & Supply Chain':'Logistics','SportsTech':'Sports','HRTech':'Human Resources','Wine & Spirits':'Catering',
                            '-Commerce':'E-Commerce','Mechanical & Industrial Engineering':'Manufacturing','Lifestyle':'Fitness','Computer software':'Software',
                            'Tech startup':'IT','Digital mortgage':'FinTech','Information Technology & Services':'IT','Furniture':'Home Decor',
                            'Tobacco':'Consumer Goods','Insuretech':'Insurance','MLOps platform':'FinTech','Venture Capital':'Finance','Pet care':'Veterinary',
                            'Drone':'Aeorspace','Wholesale':'Business Development','Spiritual':'Education','E-learning':'Education',
                            'Consumer Services':'Customer Service','Venture Capital & Private Equity':'Finance','Health':'Helathcare',
                             'Health, Wellness & Fitness':'Fitness','Education Management':'Education','Computer Software':'Software',
                             'Software Startup':'Software','Digital platform':'Digital Media','B2B Ecommerce':'E-Commerce',
                             'Online Media':'Media and Entertainment','Mobile Games':'Gaming','Food Production':'Catering',
                             'Podcast':'Media and Entertainment','Content publishing':'Creative Agency','Water purification':'Environmental Consulting',
                             'Content commerce':'Creative Agency','Innovation Management':'Creative Agency','Celebrity Engagement':'Media and Entertainment',
                             'Personal Care':'Consumer Goods','Cannabis startup':'Consumer Goods','Blogging':'Media and Entertainment',
                             'BioTechnology':'Environmental Consulting','B2B Marketplace':'E-Commerce','Health care':'Helathcare',
                             'Social audio':'Media and Entertainment','Fashion and lifestyle':'Fashion','Delivery service':'Logistics',
                            'Computer & Network Security':'IT','OTT':'IT','Capital Markets':'Finance','Social network':'Digital Media',
                             'Hospital & Health Care':'Helathcare','Music Streaming':'Media and Entertainment','Mobility':'Mobile Phones',
                             'Digital platform':'Digital Media','B2B Manufacturing':'Manufacturing','Solar':'Energy','TaaS startup':'SaaS',
                            'Manufacturing startup':'Manufacturing','Vehicle repair startup':'Automotive','Advisory firm':'Legal',
                            'Legaltech':'Legal','Pollution control equiptment':'Environmental Consulting','Fashion & Lifestyle':'Fashion',
                            'D2C':'E-Commerce','Environmental Services':'Environmental Consulting','Merchandise':'Business Development',
                            'Facilities Services':'Facilities Support Services','Marketing & Advertising':'Advertising',
                            'Eyewear':'Helathcare','Healtcare':'Helathcare','D2C Business':'E-Commerce',
                            'Biotechnology':'Environmental Consulting','NFT Marketplace':'E-Commerce','Aeorspace':'Aerospace',
                            'Consumer software':'Consumer Goods','Social community':'Digital Media','Fishery':'Agriculture',
                             'Renewables & Environment':'Energy','Online storytelling':'Media and Entertainment','Aviation':'Aerospace',
                            'IT company':'IT','Environmental service':'Environmental Consulting','Job discovery platform':'Human Resources',
                            'D2C Fashion':'Fashion','Heathcare':'Helathcare','CRM':'ERP','D2C startup':'E-Commerce',
                            'Innovation management':'Creative Agency','Community platform':'Digital Media',
                            'Networking':'IT','Consumer service':'Customer Service','Consumer goods':'Consumer Goods',
                            'MarTech':'Manufacturing','Content creation':'Creative Agency','Augmented reality':'IT',
                           'Crypto':'Cryptocurrency','Bike Rental':'Automotive','Beauty products':'Cosmetics',
                             'FemTech':'Agriculture','Supply chain platform':'Logistics','Social platform':'Digital Media',
                            'AI company':'AI','Sports startup':'Sports','Clothing':'Fashion','Analytics':'ERP',
                            'IoT platform':'IoT','Commerce':'E-Commerce','Matrimony':'Cultural',
                             'Defense & Space':'Cybersecurity','Business Supplies & Equipment':'Business Development',
                            'NFT':'IT','Oil & Energy':'Energy','Company-as-a-Service':'SaaS','Textiles':'Fashion',
                            'Professional Training & Coaching':'Education','Housing Marketplace':'Real Estate',
                            'Real estate':'Real Estate','Furniture Rental':'Home Decor','Equity Management':'Finance',
                           'Cloud kitchen':'Cloud Computing','Community':'Cultural','Higher Education':'Education',
                            'Mechanical Or Industrial Engineering':'Manufacturing','D2C jewellery':'Fashion','Helathcare':'Healthcare',
                            'Sales and Distribution':'Business Development','Translation & Localization':'Cultural',
                            'Investment Banking':'Finance','Femtech':'Agriculture','sports':'Sports',
                            'Foootwear':'Fashion','Legal Services':'Legal','Arts & Crafts':'Creative Agency',
                            'Investment Management':'Finance','Management Consulting':'Human Resources',
                             'B2B startup':'E-Commerce','Telecommunications':'Telecommuncation','Product studio':'Media and Entertainment',
                             'Aviation & Aerospace':'Aerospace','Staffing & Recruiting':'Human Resources',
                            'Design':'Home Decor','B2B Travel':'Transportation'}}, inplace=True)

# %%
data_2021['Sector'].unique()
# Out:
# array(['AI', 'Education', 'E-Commerce', 'FinTech', 'Home Decor',
#        'Healthcare', 'IT', 'Energy', 'Automotive', 'Catering',
#        'Aerospace', 'Dating', 'Gaming', 'Business Development', 'AgTech',
#        'Telecommuncation', 'Logistics', 'Hospitality', 'Fashion',
#        'Advertising', 'Transportation', 'Legal', 'Saas', 'Sports',
#        'Media and Entertainment', 'Digital Media',
#        'Facilities Support Services', 'Human Resources', 'Consumer Goods',
#        'Manufacturing', 'Financial Services', 'Helathcare', 'Fitness',
#        'IoT', 'Software', 'ERP', 'Insurance', 'Finance', 'Veterinary',
#        'Aeorspace', 'Construction', 'Customer Service', 'Music Streaming',
#        'Cosmetics', 'Mobile Phones', 'Real Estate', 'Creative Agency',
#        'Environmental Consulting', 'Consulting', 'SaaS', 'Blockchain',
#        'Cryptocurrency', 'Agriculture', 'Advertisement', 'Cultural',
#        'CleanTech', 'Cybersecurity', 'Maritime', 'Cloud Computing',
#        'Nanotechnology'], dtype=object)

# %%
# replacing nan with unknown
data_2021['Sector']=data_2021['Sector'].fillna('Unknown')

# %% [markdown]
# ### Cleaning the Stage Column

# %%
data_2021['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Unknown', 'Bridge', 'Seed+', 'Series F2', 'Series A+', 'Series G',
#        'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I'],
#       dtype=object)

# %%
data_2021.replace({'Stage':{'Pre-Seed':'Seed','Pre-series A':'Series A','Pre-series':'Seed','Pre-series C':'Series C',
                            'Pre-Series B':'Series B','Series A-1':'Series A','Seed Funding':'Seed','Seed round':'Seed',
                            'Pre-seed Round':'Seed','Pre seed Round':'Seed','Series A2':'Series A','Seies A':'Series A',
                            'Pre Series A':'Series A','Angel Round':'Angel','Pre series A1':'Series A','Pre-series A1':'Series A',
                            'Pre series A':'Series A','Seed Round':'Seed','Bridge Round':'Seed','Bridge':'Seed','Series F2':'Series F',
                            'Edge':'Seed','Pre seed round':'Seed','Series B3':'Series B','Pre series C':'Series C',
                            'Series A+':'Series A','Series D1':'Series D','Early seed':'Seed','Series C, D':'Series C',
                           'Pre-series B':'Series B','Series B2':'Series B','Pre- series A':'Series A','Series F1':'Series F','Debt':'Seed',
                            'Angel':'Seed','Debt':'Seed','Unknown':'Seed',
                            'Angel':'Seed','Secondary Market':'Seed','Equity':'Seed','Grant':'Seed',
                           'Seed+':'Seed','PE':'Seed','Seed A':'Series A','Pre-seed':'Seed'}},inplace=True)
data_2021['Stage'].unique()
# Out:
# array(['Series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Series F', 'Series G', 'Series H', '$300000',
#        '$6000000', '$1000000', 'Series I'], dtype=object)

# %%
# checking for the record with $300000 at the Stage column
data_2021.loc[data_2021['Stage']=='$300000']
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 538   Little Leap   2020.0       Delhi        Education
# 551         BHyve   2020.0      Mumbai  Human Resources
#
#                                           What it does  \
# 538                Soft Skills that make Smart Leaders
# 551  A Future of Work Platform for diffusing Employ...
#
#                                               Founders  \
# 538  Holistic Development Programs for children in ...
# 551                                  Backed by 100x.VC
#
#                             Investor                       Amount($)    Stage
# 538                     Vishal Gupta                    ah! Ventures  $300000
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network, LetsVenture  $300000

# %% [markdown]
# The inestigation reveals that the amount and stage column has been interchanged. Two different records had this transposition error. The code below is used to correct them correct them below.

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='Little Leap',['Amount($)','Sector','Stage']]=[300000, 'Education','Seed']
# correcting the secod record found above
data_2021.loc[data_2021['Company/Brand']=='BHyve',['Amount($)','Stage']]=[300000,'Seed']

# %%
 # checking for the record with $6000000 at the Stage column
data_2021.loc[data_2021['Stage']=='$6000000']
# Out:
#     Company/Brand  Founded HeadQuarter       Sector  \
# 674  MYRE Capital   2020.0      Mumbai  Real Estate
#
#                             What it does  \
# 674  Democratising Real Estate Ownership
#
#                                     Founders     Investor Amount($)     Stage
# 674  Own rent yielding commercial properties  Aryaman Vir       NaN  $6000000

# %% [markdown]
# This output revelaed that the sector named will have to be consistent with others. Aahain the stage column and the Amount column has been transposed. These are corrected in the code below

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='MYRE Capital',['Amount($)','Sector','Stage']]=[6000000, 'Real Estate','Seed']

# %%
 # checking for the record with $1000000 at the Stage column
data_2021.loc[data_2021['Stage']=='$1000000']
# Out:
#         Company/Brand  Founded HeadQuarter     Sector  \
# 677  Saarthi Pedagogy   2015.0   Ahmadabad  Education
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor                        Amount($)     Stage
# 677  Sushil Agarwal  JITO Angel Network, LetsVenture  $1000000

# %% [markdown]
# This output revelaed that the sector named will have to be consistent with others. Aahain the stage column and the Amount column has been transposed. These are corrected in the code below

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='Saarthi Pedagogy',['Amount($)','Sector','Stage']]=[1000000, 'Education','Seed']

# %%
data_2021['Stage'].unique()
# Out:
# array(['Series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Series F', 'Series G', 'Series H', 'Series I'],
#       dtype=object)

# %%
# replacing nan with unknown
data_2021['Stage']=data_2021['Stage'].fillna('Seed')

# %% [markdown]
# ### Cleaning the Amount($) Column

# %%
data_2021['Amount($)'].unique()
# Out:
# array(['$1,200,000', '$120,000,000', '$30,000,000', '$51,000,000',
#        '$2,000,000', '$188,000,000', '$200,000', 'Undisclosed',
#        '$1,000,000', '$3,000,000', '$100,000', '$700,000', '$9,000,000',
#        '$40,000,000', '$49,000,000', '$400,000', '$300,000',
#        '$25,000,000', '$160,000,000', '$150,000', '$1,800,000',
#        '$5,000,000', '$850,000', '$53,000,000', '$500,000', '$1,100,000',
#        '$6,000,000', '$800,000', '$10,000,000', '$21,000,000',
#        '$7,500,000', '$26,000,000', '$7,400,000', '$1,500,000',
#        '$600,000', '$800,000,000', '$17,000,000', '$3,500,000',
#        '$15,000,000', '$215,000,000', '$2,500,000', '$350,000,000',
#        '$5,500,000', '$83,000,000', '$110,000,000', '$500,000,000',
#        '$65,000,000', '$150,000,000,000', '$300,000,000', '$2,200,000',
#        '$35,000,000', '$140,000,000', '$4,000,000', '$13,000,000', nan,
#        '$Undisclosed', '$2000000', '$800000', '$6000000', '$2500000',
#        '$9500000', '$13000000', '$5000000', '$8000000', '$1000000',
#        1200000, '$200000', '$12000000', '$1500000', '$1700000',
#        '$5500000', '$400000', '$150000000', '$4000000', '$100000000',
#        '$500000', '$15000000', '$10000000', '$40000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$21000000',
#        '$1200000', '$52000000', '$3800000', '$17500000', '$42000000',
#        '$2300000', '$7000000', '$30000000', '$450000000', '$28000000',
#        '$300000', '$3500000', '$8500000', '$25000000', '$3000000',
#        '$37000000', '$370000000', '$700000', '$16000000', '$100000',
#        '$44000000', '$770000', '$125000000', '$35000000', '$50000000',
#        '$4900000', '$145000000', '$22000000', '$70000000', '$6600000',
#        '$32000000', '$24000000', '$725000', '$461000', 'Series C', 'Seed',
#        '$96000000', '$60000000', '$500000000', '$266000000', '$4500000',
#        '$325000000', '$6500000', '$1600000', '$225000', '$85000000',
#        '$235000', '$260000', '$2900000', '$53000000', '$1100000',
#        '$150000', '$86000000', '$130000', '$$100,00', '$111000000',
#        '$265000', '$76000000', '$100,000,000', '$75,000,000',
#        '$3,800,000', '$12,000,000', '$1,600,000', '$260,000',
#        '$1,000,000,000', '$18,000,000', '$20,000,000', '$350,000',
#        '$95,000,000', '$4,100,000', '$5,200,000', '$8,000,000',
#        '$1,400,000', '$2,600,000', '$900,000', '$250,000', '$16,000,000',
#        '$7,000,000', '$11,000,000', '$50,000,000', '$14,300,000',
#        '$81,000,000', '$1,300,000', '$8,200,000', '$280,000,000',
#        '$70,000,000', '$720,000', '$600000', '$9000000', '$1800000',
#        '$330000', '$undisclosed', '$200000000', '$36000000', '$67000000',
#        '$10200000', '$220000000', '$108000000', '$75000000', '$450000',
#        '$660000000', 300000, '$45000000', '$3200000', '$370000',
#        'Pre-series A', '$48000000', '$3600000', '$11000000', '$192000000',
#        '$65000000', '$1400000', '$1900000', '$41000000', '$144000000',
#        '$5200000', '$270000000', '$140000', '$250000000', '$320000',
#        '$350000000', '$4800000', '$38000000', '$125000', '$26000000',
#        '$64000000', '$620000', '$900000', 6000000, 1000000, '$2600000',
#        '$1,250,000', '$400,000,000', '$1,700,000', '$27,000,000',
#        '$234,000,000', '$460,000,000', '$13,500,000', '$5,100,000',
#        '$195,000,000', '$125,000', '$45,000,000', '$200,000,000',
#        '$7,300,000', '$6,300,000', '$12,500,000', '$24,000,000',
#        '$140,000', '$16,500,000', '$340,000', '$43,000,000',
#        '$150,000,000', '$3300000', '$92000000', '$17000000', '$135000000',
#        '$$1,55,000', '$2100000', '$840000000', '$248000000', '$4300000',
#        '$570000', '$2200000', '$4700000', '$300000000', '$260000000',
#        '$140000000', '$175000000', '$19000000', '$810000', '$7500000',
#        '$600000000', '$90000000', '$5700000', '$6750000', '$78000000',
#        '$5400000', '$115000000', '$255000000', '$18000000', '$570000000',
#        '$550000', '$2700000', '$4200000', '$31000000', '$540000',
#        '$14000000', '$340000', '$', '$6200000', '$750000', '$6300000',
#        '$23000000', '$55000000'], dtype=object)

# %% [markdown]
# Values such as `Undisclosed`, `Series C`, `Seed`,`$Undisclosed`, `$undisclosed`, `Pre-series A` all wrongly entered into the Amount($) column. This will have to be investigated and corrected.

# %%
# checking for undisclosed in the amount column
data_2021.loc[data_2021['Amount($)']=='Undisclosed']
# Out:
#                Company/Brand  Founded HeadQuarter  \
# 7                Qube Health   2016.0      Mumbai
# 8                   Vitra.ai   2020.0   Bengaluru
# 21                     Uable   2020.0   Bengaluru
# 39                  TruNativ   2019.0      Mumbai
# 54                    AntWak   2019.0   Bengaluru
# 64               Rage Coffee   2018.0       Delhi
# 67                     Kudos   2014.0        Pune
# 316                Hubhopper   2015.0       Delhi
# 319            Battery Smart   2019.0       Delhi
# 321                  Onelife   2019.0      Mumbai
# 325                    Aisle   2014.0   Bengaluru
# 334                  Zingbus   2019.0     Haryana
# 336                 Codingal   2020.0   Bengaluru
# 345               Hypd Store   2020.0       Delhi
# 367                PrepBytes   2019.0    Gurugram
# 376                    ExMyB   2018.0    Gurugram
# 379                     Qin1   2019.0       Noida
# 383                  KIKO TV   2020.0      Mumbai
# 384              Quali55Care   2018.0      Mumbai
# 386                   RevFin   2018.0       Delhi
# 393                     Zouk   2016.0      Mumbai
# 406          Digit Insurance   2016.0   Bengaluru
# 428                   Bolkar   2018.0   Bengaluru
# 429          Wright Research   2019.0      Mumbai
# 436           Oneiric Gaming   2020.0  Chandigarh
# 452                  Agri10x   2018.0        Pune
# 724                Instoried   2018.0   Bengaluru
# 732                 Homingos   2018.0   Bengaluru
# 733  Anar Business Community   2020.0      Mumbai
# 735                  Settlrs   2018.0   Bengaluru
# 766                     Wysa   2015.0   Bengaluru
# 769                  Firmway   2016.0      Mumbai
# 794                   Bijnis   2014.0       Delhi
# 801                  Virohan   2018.0    Gurugram
# 807                ParkSmart   2018.0       Delhi
# 810             Spark Studio   2020.0   Bengaluru
# 814                    Keito   2016.0        Pune
# 820                 LegalPay   2019.0       Delhi
# 824              Avalon Labs   2017.0   Bengaluru
# 827                  Rezo.ai   2017.0       Noida
# 833                  Polygon   2017.0      Mumbai
# 846                 Ingenium   2018.0       Delhi
# 853                  Celcius   2020.0      Mumbai
#
#                           Sector  \
# 7                     Healthcare
# 8                             IT
# 21                     Education
# 39                      Catering
# 54                     Education
# 64                      Catering
# 67                       FinTech
# 316      Media and Entertainment
# 319                       Energy
# 321                   Healthcare
# 325                       Dating
# 334               Transportation
# 336                    Education
# 345              Creative Agency
# 367                    Education
# 376                   Consulting
# 379                    Education
# 383                   E-Commerce
# 384                   Helathcare
# 386                      FinTech
# 393                      Fashion
# 406                      FinTech
# 428                Digital Media
# 429                        Legal
# 436                       Gaming
# 452                       AgTech
# 724              Creative Agency
# 732                           IT
# 733                           IT
# 735  Facilities Support Services
# 766                           AI
# 769                      FinTech
# 794                   E-Commerce
# 801                    Education
# 807                   Automotive
# 810                    Education
# 814                           AI
# 820                      FinTech
# 824                      FinTech
# 827                           AI
# 833               Cryptocurrency
# 846                    Education
# 853                    Logistics
#
#                                           What it does  \
# 7    India's Most Respected Workplace Healthcare Ma...
# 8    Vitra.ai is an AI-based video translation plat...
# 21   Uable offers role based programmes to empower ...
# 39                  TruNativ Foods & Beverages Pvt Ltd
# 54   AntWak provides a video platform for e-learnin...
# 64   Rage Coffee is infused with plant based vitami...
# 67   Kudos is a full stack NBFC, a digital lending ...
# 316  Hubhopper is India's leading podcast hosting, ...
# 319  Battery Smart provides advanced Li-ion batteri...
# 321  Aspire to leverage the gifts of nature and sci...
# 325  Aisle connects the new generation of single in...
# 334  Zingbus is an emerging brand in the intercity ...
# 336        Coding education platform for K-12 students
# 345      A shop worthy content platform, personalized!
# 367  PrepBytes helps college students to learn codi...
# 376  ExMyB provides financial service and consultin...
# 379                 Re-imagining Kids of 21st Century!
# 383  KIKO TV is an AI-based short live video e-comm...
# 384  Deliver highly durable & affordable medical eq...
# 386               RevFin is a digital lending company.
# 393                        100% Vegan bags from India.
# 406  Digit Insurance is a financial services compan...
# 428  Bolkar App is an Audio Based Q&A platform for ...
# 429    Quantitative Investment Management and Research
# 436  Oneiric Gaming connects to fellow dreamers aro...
# 452  Agri10x integrates the entire Agri value-chain...
# 724  Instoried is an augmented writing platform whi...
# 732  Homingos is an Augmented reality (AR)-based so...
# 733  Anar is a communications and networking platfo...
# 735  A B2B rental services company for furniture, h...
# 766  Wysa is an AI conversational agent that has be...
# 769  Firmway is a platform that digitizes balance c...
# 794  Digitizing the Factories of the Unorganised In...
# 801  Virohan is an edtech company using technology ...
# 807     ParkSmart is a parking management application.
# 810  Online courses to build creativity and confide...
# 814  NO-CODE <> Human-assisted machine learning pla...
# 820  A trusted financial partner for advocates and ...
# 824  Avalon Labs incubates, invests, partners with ...
# 827  Conversational AI platform - Innovate the way ...
# 833      Polygon is a blockchain scalability platform.
# 846  Ingenium Education has been pushing e-learning...
# 853  The “ONLINE” Cold Chain network for Reefer tru...
#
#                                               Founders  \
# 7                                          Gagan Kapur
# 8                                       Akash Nidhi PS
# 21                                      Saurabh Saxena
# 39                     Pranav Malhotra, Mamta Malhotra
# 54   Basav Nagur, Joybroto Ganguly, Sudhanshu Shekh...
# 64                                        Bharat Sethi
# 67                                         Naresh Vigh
# 316                                   Gautam Raj Anand
# 319                    Pulkit Khurana, Siddharth Sikka
# 321                                    Gaurav Aggarwal
# 325                                        Able Joseph
# 334                                  Mratunjay Beniwal
# 336                     Satyam Baranwal, Vivek Prakash
# 345                    Ashwarya Garg, Akshay Bhatnagar
# 367                 Aditya Bhushan Verma, Mamta Kumari
# 376                                       Nishant Behl
# 379                                        Ishan Gupta
# 383                                    Shivam Varshney
# 384                                    Harddik K Patel
# 386                                    Sameer Aggarwal
# 393                                        Disha Singh
# 406                                       Kamesh Goyal
# 428  Abhishek Tripathi, Dhruv Kaushal, Prince Tripa...
# 429                                   Sonam Srivastava
# 436                                       Avneet Singh
# 452  Abhijith Naraparaju, Pankajj P. Ghode, Sundeep...
# 724                          Sharmin Ali, Sutanshu Raj
# 732         Shourya Agarwal, Malhar Patil, Rajat Gupta
# 733                          Nishank Jain, Sanjay Bhat
# 735                Gaurav Ranebennur, Nishanth Janadri
# 766                      Jo Aggarwal, Ramakant Vempati
# 769                      Prashant Gupta, Vivek Chandan
# 794  Chaitanya Rathi, Shubham Agarwal, Siddharth Ra...
# 801        Archit Jayasal, Kunaal Dudeja, Nalin Saluja
# 807  Prateek Garg, Rahul Gupta, Ratan Anmol Sethi, ...
# 810                                    Anushree Goenka
# 814                                           Amal P S
# 820                                       Kundan Shahi
# 824                                        Varun Mayya
# 827                          Manish Gupta, Rashi Gupta
# 833       Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 846      Pramudit Somvanshi, Mohit Patel, Aakash Gupta
# 853           Swarup Bose, Rajneesh Raman, Arbind Jain
#
#                                               Investor    Amount($)     Stage
# 7                            Inflection Point Ventures  Undisclosed  Series A
# 8                                    Inflexor Ventures  Undisclosed      Seed
# 21                       Chiratae Ventures, JAFCO Asia  Undisclosed      Seed
# 39                                           9Unicorns  Undisclosed      Seed
# 54                      Vaibhav Domkundwar, Kunal Shah  Undisclosed      Seed
# 64                          GetVantage, Prakash Katama  Undisclosed  Series A
# 67                            Marquee fintech founders  Undisclosed  Series A
# 316     ITI Growth Opportunities Fund, Unit-E Ventures  Undisclosed      Seed
# 319                             Orios Venture Partners  Undisclosed      Seed
# 321                          Wipro venture capital arm  Undisclosed      Seed
# 325                     Anas Rahman Junaid, Vinod Jose  Undisclosed  Series A
# 334      Venture Catalysts, 9Unicorns Accelerator Fund  Undisclosed  Series A
# 336                    Y Combinator, Rebright Partners  Undisclosed      Seed
# 345                                         ScoopWhoop  Undisclosed      Seed
# 367                                Equanimity Ventures  Undisclosed      Seed
# 376                                        Campus Fund  Undisclosed      Seed
# 379                                  Venture Catalysts  Undisclosed  Series A
# 383    Sunil Kumar Singhvi, 9Unicorns Accelerator Fund  Undisclosed  Series A
# 384         India Accelerator’s Angel Investor Network  Undisclosed      Seed
# 386                                   Shell Foundation  Undisclosed      Seed
# 393                                      Titan Capital  Undisclosed      Seed
# 406                      A91 Partners, Faering Capital  Undisclosed      Seed
# 428                                   GSF, Pras Hanuma  Undisclosed      Seed
# 429                        Ajat Hukkoo, Piyush Chaplot  Undisclosed      Seed
# 436                                    Trishneet Arora  Undisclosed      Seed
# 452                                           Omnivore  Undisclosed      Seed
# 724                         EXPERT DOJO, Mumbai Angels  Undisclosed      Seed
# 732                  Sundi Natarajan, Srinivas Anumolu  Undisclosed      Seed
# 733                        Titan Capital, First Cheque  Undisclosed      Seed
# 735                                 MaGEHold Pte. Ltd.  Undisclosed  Series A
# 766                           Kae Capital, Pi Ventures  Undisclosed      Seed
# 769                                                NaN  Undisclosed      Seed
# 794       Sequoia Capital India, Matrix Partners India  Undisclosed      Seed
# 801  National Skill Development Corporation, Rianta...  Undisclosed      Seed
# 807                 Shireen Rangaswamy, Dilesh Gathani  Undisclosed      Seed
# 810                                     Better Capital  Undisclosed      Seed
# 814                Rajesh Agarwal, Nandkishore Mundada  Undisclosed      Seed
# 820                                          9Unicorns  Undisclosed      Seed
# 824  Tanglin Ventures, Better Capital, Whiteboard C...  Undisclosed  Series A
# 827                   Devesh Sachdev, Bhavesh Manglani  Undisclosed      Seed
# 833                           Mark Cuban, MiH Ventures  Undisclosed      Seed
# 846                                        Lead Angels  Undisclosed      Seed
# 853                                Eaglewings Ventures  Undisclosed      Seed

# %% [markdown]
# The invetsigation output above revealed  that none of the records had the amount wrongly entered in a different column. It is obvious that the amount was not disclosed. Theey are replace with 0.

# %%
# replacing the Undisclosed with nan
data_2021.replace({'Amount($)':{'Undisclosed',np.nan}}, inplace=True)

# %%
# checking for $Undisclosed in the amount column
data_2021.loc[data_2021['Amount($)']=='$Undisclosed']
# Out:
#                Company/Brand  Founded    HeadQuarter                   Sector  \
# 87               Karbon Card   2019.0      Bengaluru                  FinTech
# 99                   NeoDocs   2020.0         Mumbai               Healthcare
# 112                  NeoDocs   2020.0         Mumbai               Healthcare
# 123                Imagimake   2011.0         Mumbai           Consumer Goods
# 127                    Akudo   2020.0      Bengaluru                  FinTech
# 130               CommerceUp   2018.0       Gurugram                       IT
# 132                     Hike   2012.0          Delhi                       IT
# 140               Snack Amor   2014.0         Mumbai                 Catering
# 146              BatteryPool   2018.0           Pune               Automotive
# 167                MetroRide   2020.0      Bengaluru           Transportation
# 171                Unacademy   2015.0      Bengaluru                Education
# 192                 AyuRythm   2017.0      Bengaluru               Healthcare
# 193                   Enguru   2014.0      Bengaluru                Education
# 207                 Fabheads   2015.0        Chennai            Manufacturing
# 210    MedPrime Technologies   2014.0          Thane               Healthcare
# 234              FanAnywhere   2021.0      Bengaluru       Financial Services
# 248              FanAnywhere   2021.0      Bengaluru       Financial Services
# 300      Karkinos Healthcare   2020.0         Mumbai               Helathcare
# 304                  Zorgers   2013.0         Mohali               Helathcare
# 305                   BangDB   2015.0      Bengaluru                 Software
# 592           Accio Robotics   2020.0      Bengaluru            Manufacturing
# 596                     Almo   2020.0       Gurugram                  Fashion
# 598                 GalaxEye   2020.0        Chennai                Aerospace
# 607     Onelife Nutriscience   2019.0         Mumbai               Healthcare
# 608                Flatheads   2019.0      Bengaluru                  Fashion
# 609            Fable Fintech   2015.0         Mumbai                  FinTech
# 613              Cora Health   2020.0      Bengaluru               Healthcare
# 616                 Cashfree   2015.0      Bengaluru                  FinTech
# 632      Wellbeing Nutrition   2019.0         Mumbai               Healthcare
# 642            Wherehouse.io   2020.0          Delhi                Logistics
# 647             WaterScience   2014.0      Bengaluru               E-Commerce
# 650          Juicy chemistry   2014.0     Coimbatore               Healthcare
# 655               saarthi.ai   2017.0      Bengaluru                       AI
# 659                  PazCare   2021.0      Bengaluru                Insurance
# 660          Answer Genomics   2019.0      Bengaluru               Healthcare
# 667           The Switch Fix   2019.0       Gurugram               Healthcare
# 669               DigiSparsh   2020.0         Mumbai                  FinTech
# 671              Pathfndr.io   2015.0      Bengaluru                     Saas
# 676              MicroDegree   2019.0      Bengaluru                Education
# 679               Kwik Foods   2020.0       Gurugram                 Catering
# 684               Green Cure   2015.0          Delhi               Healthcare
# 687                 ApnaKlub   2020.0      Bengaluru               E-Commerce
# 688                 LegalPay   2019.0          Delhi                  FinTech
# 689                   Lavado   2016.0         Mumbai         Customer Service
# 690                   Navars   2019.0      Hyderabad                Education
# 696                    Humit   2020.0      Bengaluru          Music Streaming
# 698                  NIRAMAI   2016.0      Bengaluru               Healthcare
# 699                 Intervue   2021.0          Delhi                     Saas
# 706             Powerhouse91   2020.0       Gurugram           Consumer Goods
# 708                 Chargeup   2019.0          Delhi                   Energy
# 871                TurboHire   2019.0      Hyderabad                 Software
# 873                  SatSure   2017.0      Bengaluru            Cybersecurity
# 918         Zenpay Solutions   2019.0          Delhi       Financial Services
# 920               Arbo Works   2021.0  Mountain View                 Software
# 956               Kissan Pro   2021.0      Jharkhand              Agriculture
# 963              LeadSquared   2011.0      Bengaluru                 Software
# 964                 Phool.co   2017.0         Kanpur                   Energy
# 967                  mHealth   2020.0          Delhi                  Fitness
# 1044                  Shumee   2014.0      Bengaluru     Business Development
# 1061              Wallmantra   2013.0          Noida          Creative Agency
# 1063                Aquatein   2019.0         Mumbai                 Catering
# 1071               PumPumPum   2018.0       Gurugram               Automotive
# 1079              My3DSelfie   2016.0       Guwahati          Creative Agency
# 1088  Nimble Growth Organics   2016.0      Bengaluru              Agriculture
# 1093                  Upgame   2017.0       Gurugram                   Sports
# 1116                PayCardo   2021.0           Pune       Financial Services
# 1118              Expertrons   2019.0         Mumbai                Education
# 1127                  Frenzi   2020.0         Mumbai  Media and Entertainment
# 1128            Leverage Edu   2017.0          Delhi                Education
# 1160   Atomberg Technologies   2012.0         Mumbai           Consumer Goods
# 1161         Genext Students   2013.0         Mumbai                Education
# 1166               OckyPocky   2015.0       Gurugram                Education
# 1193         Sapio Analytics   2019.0         Mumbai                 Software
#
#                                            What it does  \
# 87    Prime objective is to empower Indian startups ...
# 99    Neodocs is a part of India's prominent Social ...
# 112   Neodocs is a part of India's prominent Social ...
# 123   Imagimake – one of the fastest growing and mos...
# 127   Akudo is pioneering the concept of Learning-Fi...
# 130   Grow and manage ecommerce business from single...
# 132   Hike is an Indian AI-led Unicorn startup that ...
# 140   Snack Amor aims is to offer a healthy, natural...
# 146   Building the Operating System for managing Ele...
# 167   Urban Mobility Affordable, Punctual & Sustaina...
# 171   Unacademy aims to build the world's largest on...
# 192   AyuRythm is the world's first completely digit...
# 193   Enguru provides a personalized & gamified Engl...
# 207   Fabheads is a hardware startup creating automa...
# 210   MedPrime Technologies is a medical device comp...
# 234                              Celebrity NFT platform
# 248                              Celebrity NFT platform
# 300   Medical center for treatment of complex cancer...
# 304   Zorgers Home Healthcare is India’s most truste...
# 305   A Converged NoSQL Data Platform for Predictive...
# 592   Accio Robotics is involved in the designing an...
# 596   Almo is a Premium Men's essentianls wear brand...
# 598   GalaxEye enables businesses to make better Dec...
# 607   Onelife Nutriscience is a consumer healthcare ...
# 608   Flatheads is a lifestyle brand that designs an...
# 609   Fable Fintech is being seed-funded by the CCAv...
# 613   Social Commerce Marketplace for health and wel...
# 616   Cashfree is a payments and banking technology ...
# 632   Organic whole food nutrition to keep up with t...
# 642   Wherehouse.io is a supply chain intelligence c...
# 647   The aim of making good water affordable and ac...
# 650   Juicy Chemistry operates as an eponymous consu...
# 655   Multilingual Conversational Enterprise AI Plat...
# 659   Paz Care is India's leading Employee Benefits ...
# 660   A healthcare company that uses genome-based da...
# 667   The Switch Fix is a plant-based clean and cons...
# 669   DigiSparsh is India's first and only healthcar...
# 671   Intelligent Travel Tech Stack making sense of ...
# 676   MicroDegree is an ed-tech platform working tow...
# 679   Kwik Foods is one of the fastest-growing D2C f...
# 684   World's first company to combine German Engine...
# 687   Supporting independent businesses and retail e...
# 688   A tech focused B2B litigation finance company ...
# 689   A startup that is trying to permanently change...
# 690   Navars Edutech comprises dynamic mix of intell...
# 696   Humit is a social networking app for music sha...
# 698   NIRAMAI has developed a novel breast cancer sc...
# 699   World's fastest collaborative environment to t...
# 706   A tech-driven company that acquires, operates,...
# 708   "Battery as a Service" for 3 wheeler & 2 wheelers
# 871   Industry-leading augmented intelligence softwa...
# 873   SatSure is an innovative decision analytics co...
# 918   India’s fastest growing fintech company, which...
# 920                                  Finance technology
# 956   Full stack solution on agri advisory, input pu...
# 963   LeadSquared is a marketing automation and sale...
# 964   Flowercycling technologies to upcycle cellulos...
# 967   mHealth  is AI based corporate wellness platfo...
# 1044  An Indian, mom-made toy brand passionate about...
# 1061  WallMantra is a well reputed wall decoration o...
# 1063  India's First Protein Water in 21g and 10g Var...
# 1071  Pumpumpum is empowering millennials with a sma...
# 1079    World's first to create 3d figurine from photos
# 1088  Nimble Growth Organics is the new age Agri sta...
# 1093  Upgame is the leading data intelligence and pr...
# 1116  A true Contactless & Cashless and secure payme...
# 1118  The world's largest AI Videobot platform provi...
# 1127   India’s Fastest Growing Streaming Social Network
# 1128         India's Most Trusted Study Abroad Platform
# 1160             A maker of energy-efficient smart fans
# 1161  LIVE online classes with expert tutors for K-1...
# 1166  OckyPocky is India's 1st interactive English l...
# 1193  Sapio helps government create policies driven ...
#
#                                                Founders  \
# 87    Pei-fu Hsieh, Amit Jangir, Kartik Jain, Sunil ...
# 99           Nikunj Malpani, Anurag Meena, Pratik Lodha
# 112          Nikunj Malpani, Anurag Meena, Pratik Lodha
# 123                         Disha Katharani, Ravi Jalan
# 127       Lavika Aggarwal, Sajal Khanna, Jagveer Gandhi
# 130                                       Piyush Pathak
# 132                                 Kavin Bharti Mittal
# 140                                       Deepak Grover
# 146                                      Ashwin Shankar
# 167                       Girish Nagpal, Kaaman Agarwal
# 171            Gaurav Munjal, Hemesh Singh, Roman Saini
# 192                                      Abhilesh Gupta
# 193        Arshan Vakil, Tahem Veer Verma, Udit Hinduja
# 207                                   Dhinesh Kanagaraj
# 210   Samrat, Greeshma Unnikrishnan, Binil Jacob, Ma...
# 234                         Varun Chaudhary, Amit Kumar
# 248                         Varun Chaudhary, Amit Kumar
# 300                         R Venkataramanan, Ravi Kant
# 304              Varun Gupta, Anil Kumar, Abhinav Gupta
# 305                                        Sachin Sinha
# 592                     Tuhin Sharma, Pranav Srinivasan
# 596                                       Abhishek Shah
# 598   Denil Chawda, Kishan Thakkar, Pranit Mehta, Sa...
# 607                                     Gaurav Aggarwal
# 608                Ganesh Balakrishnan, Utkarsh Biradar
# 609                                  Naushad Contractor
# 613                    Shrijit Venkatesh, Snigdha Kumar
# 616                            Akash Sinha, Reeju Datta
# 632                                     Avnish Chhabria
# 642     Vaibhav Chawla, Jeevan Prakash, Lavelesh Sharma
# 647                                            Sudeep N
# 650                                Megha, Pritesh Asher
# 655   Piyush Dangaich, Sameer Sinha, Sangram Sabat, ...
# 659                                       Sanchit Malik
# 660                                   Rahul Ranganathan
# 667                         Abhishek Kumar, Rhea Shukla
# 669                       Saurabh Soni, Akhilesh Gandhi
# 671                                         Varun Gupta
# 676       Gaurav Kamath, Rakesh Kothari, Manikanta Nair
# 679                       Prabhleen Kaur, Harshal Patel
# 684                                        Sanchit Garg
# 687                                Shruti, Manish Kumar
# 688                                        Kundan Shahi
# 689                                          Disha Jain
# 690                                  Sravan Varma Datla
# 696        Rohit Ganapathy, Prithvi Sankar, Ishaan Negi
# 698                                    Geetha Manjunath
# 699               Rahul Arora, Pushpender Singh Rautela
# 706                       Shashwat Diesh, Aqib Mohammed
# 708                        Varun Goenka, Akshay Kashyap
# 871                                      Deepak Agrawal
# 873   Prateep Basu, Rashmit Singh Sukhmani, Abhishek...
# 918                                      Ankit Bhargava
# 920                                     Caesar Sengupta
# 956                                      Ravi Dasoundhi
# 963                                        Nilesh Patel
# 964                                       Ankit Agarwal
# 967         Rajesh Munjal, Balwinder Singh, Monika Garg
# 1044                                 Meeta Sharma Gupta
# 1061                                     Shivam Agarwal
# 1063                   Ananth B Prabhala, Mitisha Mehta
# 1071                                      Tarun Lawadia
# 1079                                      Harsha P Deka
# 1088  Rahul Saria, Nagendra Kalkuli, Abhisek Bhagcha...
# 1093                                     Sameer Sawhney
# 1116                   Vivek Kumar Choubey, Vivek Kumar
# 1118                         Jatin Solanki, Vivek Gupta
# 1127        Balkrishna Singh, Harvinderjit Singh Bhatia
# 1128                                  Akshay Chaturvedi
# 1160                         Manoj Meena, Sibabrata Das
# 1161                    Ali Asgar Kagzi, Piyush Dhanuka
# 1166                                       Amit Agrawal
# 1193  Hardik Somani, Ashwin Srivastava, Shripal Jain...
#
#                                                Investor     Amount($)  \
# 87                                         Y Combinator  $Undisclosed
# 99               Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 112              Y Combinator, 9Unicorns, Titan Capital  $Undisclosed
# 123                                            Velocity  $Undisclosed
# 127                   Y Combinator, Incubate Fund India  $Undisclosed
# 130                                         NB Ventures  $Undisclosed
# 132                            Binny Bansal, Kunal Shah  $Undisclosed
# 140         Sanchit Agarwal, Sujan Sinha, Michael Cooke  $Undisclosed
# 146                                                 IAN  $Undisclosed
# 167                                                 NaN  $Undisclosed
# 171                                     Bhavin Turakhia  $Undisclosed
# 192                             SucSEED Indovation Fund  $Undisclosed
# 193   Potencia Ventures, Bisk Ventures, LetsVenture,...  $Undisclosed
# 207   Inflection Point Ventures, Rockstud Capital, F...  $Undisclosed
# 210                 Mumbai Angels Network, Social Alpha  $Undisclosed
# 234         Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 248         Oasis Capital, Scorpio VC, DeltaHub Capital  $Undisclosed
# 300                             Reliance Digital Health  $Undisclosed
# 304                           Ritu Marya Family Office.  $Undisclosed
# 305                                        Ten Innovate  $Undisclosed
# 592                                          Uday Sodhi  $Undisclosed
# 596                                      Angelist India  $Undisclosed
# 598                                     Speciale Invest  $Undisclosed
# 607                                        Lasons India  $Undisclosed
# 608                     Pankaj Chaddah, Srivatsan Rajan  $Undisclosed
# 609                                               Paytm  $Undisclosed
# 613                                                 NaN  $Undisclosed
# 616                   State Bank of India, Y Combinator  $Undisclosed
# 632                                                Klub  $Undisclosed
# 642                                      Better Capital  $Undisclosed
# 647                                                 NaN  $Undisclosed
# 650                            Spring Marketing Capital  $Undisclosed
# 655                                    Nvidia Inception  $Undisclosed
# 659                     Ashish Hemrajani, Parikshit Dar  $Undisclosed
# 660                   India Accelerator, Lyxel&Flamingo  $Undisclosed
# 667                        Venture Catalysts, 9unicorns  $Undisclosed
# 669                                    GoAhead Ventures  $Undisclosed
# 671                                      Arali Ventures  $Undisclosed
# 676          Research Innovation Incubation Design Labs  $Undisclosed
# 679                                           9Unicorns  $Undisclosed
# 684                                   Venture Catalysts  $Undisclosed
# 687                  Blume Ventures, Whiteboard Capital  $Undisclosed
# 688                           Ashwini Kakkar. 9Unicorns  $Undisclosed
# 689                                         Ashish Shah  $Undisclosed
# 690                                        Faad Network  $Undisclosed
# 696                                        Antler India  $Undisclosed
# 698                                           CDC Group  $Undisclosed
# 699                           Titan Capital, Kunal Shah  $Undisclosed
# 706                          Crossbeam Venture Partners  $Undisclosed
# 708                                          Mapmyindia  $Undisclosed
# 871                               Arcilla, Samir Khosla  $Undisclosed
# 873                                     Baring PE India  $Undisclosed
# 918                             The StarupLab, AngelBay  $Undisclosed
# 920                                     Sequoia Capital  $Undisclosed
# 956                                                EKKI  $Undisclosed
# 963                   International Finance Corporation  $Undisclosed
# 964   Alia Bhatt, IAN Fund, Social Alpha, Draper Ric...  $Undisclosed
# 967                                   India Accelerator  $Undisclosed
# 1044                                          Dia Mirza  $Undisclosed
# 1061                                           Velocity  $Undisclosed
# 1063                                Eaglewings Ventures  $Undisclosed
# 1071                                       LC Nueva AIF  $Undisclosed
# 1079                                    NEVF, AccelNest  $Undisclosed
# 1088                                                NaN  $Undisclosed
# 1093                         James Milner, Adam Lallana  $Undisclosed
# 1116                                           MaGEHold  $Undisclosed
# 1118                       Kunal Shah, Anant Maheshwari  $Undisclosed
# 1127                            SucSEED Indovation Fund  $Undisclosed
# 1128  Vijay Shekhar Sharma, Rohit Kapoor, Amanpreet ...  $Undisclosed
# 1160                                     Ka Enterprises  $Undisclosed
# 1161                                  Navneet Education  $Undisclosed
# 1166              Sujeet Kumar, SucSEED Indovation Fund  $Undisclosed
# 1193                        Rachit Poddar, Rajesh Gupta  $Undisclosed
#
#          Stage
# 87        Seed
# 99        Seed
# 112       Seed
# 123       Seed
# 127       Seed
# 130       Seed
# 132       Seed
# 140       Seed
# 146       Seed
# 167       Seed
# 171       Seed
# 192       Seed
# 193   Series A
# 207   Series A
# 210       Seed
# 234       Seed
# 248       Seed
# 300       Seed
# 304       Seed
# 305       Seed
# 592       Seed
# 596       Seed
# 598       Seed
# 607       Seed
# 608       Seed
# 609   Series A
# 613       Seed
# 616       Seed
# 632       Seed
# 642       Seed
# 647       Seed
# 650       Seed
# 655       Seed
# 659       Seed
# 660       Seed
# 667       Seed
# 669       Seed
# 671   Series A
# 676       Seed
# 679       Seed
# 684   Series A
# 687   Series A
# 688       Seed
# 689       Seed
# 690       Seed
# 696       Seed
# 698       Seed
# 699       Seed
# 706       Seed
# 708   Series A
# 871       Seed
# 873       Seed
# 918       Seed
# 920       Seed
# 956       Seed
# 963       Seed
# 964       Seed
# 967       Seed
# 1044      Seed
# 1061      Seed
# 1063      Seed
# 1071      Seed
# 1079  Series A
# 1088      Seed
# 1093      Seed
# 1116      Seed
# 1118      Seed
# 1127      Seed
# 1128      Seed
# 1160      Seed
# 1161      Seed
# 1166      Seed
# 1193      Seed

# %% [markdown]
# The invetsigation output above with 73 records revealed that none of the records had the amount wrongly entered in a different column. It is obvious that the amount was not disclosed. They are replace with 0.

# %%
# replacing the $Undisclosed with nan
data_2021.replace({'Amount($)':{'$Undisclosed',np.nan}}, inplace=True)

# %%
# checking for $undisclosed in the amount column
data_2021.loc[data_2021['Amount($)']=='$undisclosed']
# Out:
#                       Company/Brand  Founded HeadQuarter  \
# 485              Learn4o Technology   2020.0      Jaipur
# 491                          Keeros   2017.0     Lucknow
# 498                     SuperBeings   2019.0   Bengaluru
# 500                           Hyreo   2016.0  Trivandrum
# 501                     GODI Energy   2020.0   Hyderabad
# 517                       NFTically   2021.0    Gurugram
# 522                     CareerNinja   2017.0      Mumbai
# 533                      Slang Labs   2017.0   Bengaluru
# 534                       NirogGyan   2019.0    Gurugram
# 542                           SMOOR   2008.0   Bengaluru
# 546                     UrbanKisaan   2017.0   Hyderabad
# 552                     Indi Energy   2019.0     Roorkee
# 553                 The Ayurveda Co   2021.0    Gurugram
# 559                        TyrePlex   2020.0       Delhi
# 567                       Leegality   2016.0    Gurugram
# 568               Arcatron Mobility   2015.0        Pune
# 570                   PeakPerformer   2020.0   Bengaluru
# 574                        Pocketly   2019.0   Bengaluru
# 576                         CoRover   2016.0   Bengaluru
# 582                           CanPe   2019.0   Bengaluru
# 589                        Codedamn   2020.0       Delhi
# 590  Biocraft Innovation Technology   2019.0       Noida
#
#                        Sector  \
# 485                 Education
# 491                  Catering
# 498                  Software
# 500           Human Resources
# 501                Automotive
# 517                E-Commerce
# 522                 Education
# 533                  Software
# 534                Healthcare
# 542                  Catering
# 546                  Catering
# 552                    Energy
# 553            Consumer Goods
# 559                E-Commerce
# 567                        IT
# 568                Healthcare
# 570                 Education
# 574                   FinTech
# 576                        IT
# 582                  Software
# 589                  Software
# 590  Environmental Consulting
#
#                                           What it does  \
# 485  Trying to solve the problem of unemployment in...
# 491  Keeros Roasted Supersnacks that are Healthy fo...
# 498  Continuous Leadership Development & Employee E...
# 500  Hyreo stands for delivering a ‘customer-like’ ...
# 501  GODI is a technology innovation organization f...
# 517  NFT Marketplace to buy or sell NFT tokens in m...
# 522  Careerninja Is A Funded, Early-stage Ed-tech V...
# 533  Slang Labs provides accurate and multilingual ...
# 534  Simplifying Diagnostics for labs, doctors, and...
# 542  Instigate your sixth sense with our new range ...
# 546  A modern farms close to where your home is. Cr...
# 552  Indi Energy is an energy storage startup invol...
# 553  The Ayurveda Co. represents things that are al...
# 559  Tyreplex is digitizing the tyre dealers in India.
# 567  The market standard for eSign, eStamp and Docu...
# 568  Mission is to advance global standards of assi...
# 570  A goal-oriented, outcome-driven platform to ma...
# 574  Pocketly provides quick cash on hand, anytime ...
# 576  CoRover is the world’s first and the highest R...
# 582  Digital-first debt collections platform that i...
# 589  Codedamn enables anyone to learn and practice ...
# 590  Innovation startup developing bamboo resources...
#
#                                               Founders  \
# 485                                   Kamal Kant Gupta
# 491                         Sachin Sahni, Simran Sahni
# 498     Yasharth Mishra, Gaurav Bhawnani, Kunal Mishra
# 500               Arun Satyan, Mahesh Raju, Sreenath N
# 501                                        Mahesh Godi
# 517                                   Toshendra Sharma
# 522                                  Shronit Ladhaniai
# 533                                   Kumar Rangarajan
# 534                     Joyneel Acharya, Shweta Gandhi
# 542                                       Vimal Sharma
# 546  Srinivas Chaganti, Vihari Kanukollu, Sairam Reddy
# 552                                     Dr. ASIT SAHOO
# 553                     Param Bhargava, Shreedha Singh
# 559              Puneet Bhaskar, Rupendra Pratap Singh
# 567                                      Shivam Singla
# 568                                    Ganesh Sonawane
# 570                Aishwarya Goel, Gaurav Jhunjhnuwala
# 574                       Aarav Bhatia, Navdeesh Ahuja
# 576    Ankush Sabharwal, Manav Gandotra, Kunal Bhakhri
# 582                                  Arindam Choudhury
# 589                                        Mehul Mohan
# 590                       Vibha Mittal, Anubhav Mittal
#
#                                      Investor     Amount($)     Stage
# 485                                       IAN  $undisclosed      Seed
# 491                         Venture Catalysts  $undisclosed  Series A
# 498                           Endiya Partners  $undisclosed      Seed
# 500                         Callapina Capital  $undisclosed  Series A
# 501                        Blue Ashva Capital  $undisclosed      Seed
# 517                            Jayanti Kanani  $undisclosed      Seed
# 522                           Unitus Ventures  $undisclosed      Seed
# 533                        100x Entrepreneurs  $undisclosed      Seed
# 534                Healthcare veterans, PIEDS  $undisclosed      Seed
# 542                                      Klub  $undisclosed      Seed
# 546                 BASF Venture Capital GmbH  $undisclosed      Seed
# 552                     Mumbai Angels Network  $undisclosed      Seed
# 553  GetVantage, Velocity, Shiprocket Capital  $undisclosed      Seed
# 559                       AdvantEdge Founders  $undisclosed      Seed
# 567                       IIFL, Mumbai Angels  $undisclosed  Series A
# 568                                      Klub  $undisclosed      Seed
# 570                              Antler India  $undisclosed      Seed
# 574                                       NaN  $undisclosed      Seed
# 576              Canbank Venture Capital Fund  $undisclosed      Seed
# 582                           Axilor Ventures  $undisclosed      Seed
# 589                              Antler India  $undisclosed      Seed
# 590                        JITO Angel Network  $undisclosed      Seed

# %% [markdown]
# The invetsigation output above revealed that none of the records had the amount wrongly entered in a different column. It is obvious that the amount was not disclosed. They are replace with 0

# %%
# replacing the $undisclosed with 0
data_2021.replace({'Amount($)':{'$undisclosed',np.nan}}, inplace=True)

# %%
# checking for Series C in the amount column
data_2021.loc[data_2021['Amount($)']=='Series C']
# Out:
#           Company/Brand  Founded HeadQuarter      Sector  What it does  \
# 242  Fullife Healthcare   2009.0     Unknown  Healthcare  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C  Seed

# %% [markdown]
# This output revelas that there haas been some transposition at the investor, amount and stage column.
#
# This is corrected in the code below

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='Fullife Healthcare',['Amount($)','Investor','Stage']]=[22000000, 'Morgan Stanley','Series C']

# %%
# checking for Seed in the amount column
data_2021.loc[data_2021['Amount($)']=='Seed']
# Out:
#      Company/Brand  Founded HeadQuarter      Sector  \
# 257        MoEVing   2021.0    Gurugram  Automotive
# 1148     Godamwale   2016.0      Mumbai   Logistics
#
#                                            What it does  \
# 257                         Vikash Mishra, Mragank Jain
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                             Founders        Investor  \
# 257   Anshuman Maheshwary, Dr Srihari Raju Kalidindi        $5000000
# 1148       Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!
#
#      Amount($) Stage
# 257       Seed  Seed
# 1148      Seed  Seed

# %% [markdown]
# The output of the investigation shows that two records were involved with this error. The stage, investor and Amount columns were interchanged. This is corrected in the code below

# %%
# correcting the wrong placement of the HeadQuarter and Sector values
data_2021.loc[data_2021['Company/Brand']=='MoEVing',['Amount($)','Investor','Stage']]=[5000000, 'Unknown','Seed']

#correcting the second record
data_2021.loc[data_2021['Company/Brand']=='Godamwale',['Amount($)','Investor','Stage', 'Sector']]=[1000000, 'Unknown','Seed','Logistics']

# %%
# checking for Pre-series A in the amount column
data_2021.loc[data_2021['Amount($)']=='Pre-series A']
# Out:
#     Company/Brand  Founded HeadQuarter     Sector  \
# 545     AdmitKard   2016.0       Noida  Education
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders  Investor     Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  Pre-series A
#
#     Stage
# 545  Seed

# %% [markdown]
# The invetsor, Amount, and stage columns has been interchanged. The Sector column will be renamed to be consistent with others.
#
# This is correcetd in the code below

# %%
data_2021.loc[data_2021['Company/Brand']=='AdmitKard',['Amount($)','Investor','Stage', 'Sector']]=[1000000, 'Unknown','Series A','Education']

# %%
#First change the data type to a string to work on the special characters
data_2021['Amount($)']=data_2021['Amount($)'].astype(str)

# %%
# removing all special characters in the colum
data_2021["Amount($)"]=data_2021['Amount($)'].apply(lambda x: str(x).replace("$" ,"")) 
data_2021["Amount($)"]=data_2021['Amount($)'].apply(lambda x: str(x).replace("," ,""))

# %%
# change the data type to a float
# The downcast parameter is used to set the data type to float
data_2021['Amount($)'] = pd.to_numeric(data_2021['Amount($)'], errors='coerce', downcast='float')

# %%
#replacing nan with median
data_2021['Amount($)']=data_2021['Amount($)'].fillna(data_2021['Amount($)'].median())

# %% [markdown]
# ### Cleaning the `Founders` Column

# %%
# all nan values are to be filled with unknown on the 
data_2021['Founders']=data_2021['Founders'].fillna('Unknown')

# %% [markdown]
# ### Cleaning the `Investor` Column

# %%
# all nan values are to be filled with unknown on the 
data_2021['Investor']=data_2021['Investor'].fillna('Unknown')

# %%
# checking for duplicate entries
data_2021.duplicated().value_counts()
# Out:
# False    1188
# True       18
# dtype: int64

# %%
# remove the duplicate record
data_2021=data_2021.drop_duplicates(keep='first')

# %%
# checking for null values
data_2021.isna().value_counts()
# Out:
# Company/Brand  Founded  HeadQuarter  Sector  What it does  Founders  Investor  Amount($)  Stage
# False          False    False        False   False         False     False     False      False    1188
# dtype: int64

# %% [markdown]
# # Combining all the data sets

# %%
# #creating a variable to hold the different dataframes
data=[data_2018,data_2019,data_2020,data_2021]
#concatenating the varibale holding the various dataframes
combined_data=pd.concat(data,ignore_index=True)
combined_data.head()
# Out:
#      Company/Brand              Sector     Stage  Amount($) HeadQuarter  \
# 0  TheCollegeFever         Advertising      Seed   250000.0   Bengaluru
# 1  Happy Cow Dairy         Agriculture      Seed  1300000.0      Mumbai
# 2       MyLoanCare        Credit Cards  Series A  1300000.0     Gurgaon
# 3      PayMe India  Financial Services      Seed  2000000.0       Noida
# 4         Eunimart          E-Commerce      Seed  1300000.0   Hyderabad
#
#                                         What it does  Founded Founders  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...   2018.0      NaN
# 1  A startup which aggregates milk from dairy far...   2018.0      NaN
# 2          Leading Online Loans Marketplace in India   2018.0      NaN
# 3  PayMe India is an innovative FinTech organizat...   2018.0      NaN
# 4  Eunimart is a one stop solution for merchants ...   2018.0      NaN
#
#   Investor Unnamed: 9
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN

# %%
combined_data.shape
# Out:
# (2854, 10)

# %% [markdown]
# ### Saving the combined data set as a new file and reloading it for analysis

# %%
#saving the new dataframe after concatenation in order to have it work on it without having to change the other datasets
combined_data.to_csv('combined_data.csv')
combined_data.head()
# Out:
#      Company/Brand              Sector     Stage  Amount($) HeadQuarter  \
# 0  TheCollegeFever         Advertising      Seed   250000.0   Bengaluru
# 1  Happy Cow Dairy         Agriculture      Seed  1300000.0      Mumbai
# 2       MyLoanCare        Credit Cards  Series A  1300000.0     Gurgaon
# 3      PayMe India  Financial Services      Seed  2000000.0       Noida
# 4         Eunimart          E-Commerce      Seed  1300000.0   Hyderabad
#
#                                         What it does  Founded Founders  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...   2018.0      NaN
# 1  A startup which aggregates milk from dairy far...   2018.0      NaN
# 2          Leading Online Loans Marketplace in India   2018.0      NaN
# 3  PayMe India is an innovative FinTech organizat...   2018.0      NaN
# 4  Eunimart is a one stop solution for merchants ...   2018.0      NaN
#
#   Investor Unnamed: 9
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# dropping unwanted column 
combined_data.drop('Unnamed: 9',axis=1, inplace=True)
combined_data.head()
# Out:
#      Company/Brand              Sector     Stage  Amount($) HeadQuarter  \
# 0  TheCollegeFever         Advertising      Seed   250000.0   Bengaluru
# 1  Happy Cow Dairy         Agriculture      Seed  1300000.0      Mumbai
# 2       MyLoanCare        Credit Cards  Series A  1300000.0     Gurgaon
# 3      PayMe India  Financial Services      Seed  2000000.0       Noida
# 4         Eunimart          E-Commerce      Seed  1300000.0   Hyderabad
#
#                                         What it does  Founded Founders  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...   2018.0      NaN
# 1  A startup which aggregates milk from dairy far...   2018.0      NaN
# 2          Leading Online Loans Marketplace in India   2018.0      NaN
# 3  PayMe India is an innovative FinTech organizat...   2018.0      NaN
# 4  Eunimart is a one stop solution for merchants ...   2018.0      NaN
#
#   Investor
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
dfSummary(combined_data, is_collapsible = False)
# Out:
# <style type="text/css">
# #T_f3029 thead>tr>th {
#   text-align: left;
# }
# #T_f3029_row0_col0, #T_f3029_row1_col0, #T_f3029_row2_col0, #T_f3029_row3_col0, #T_f3029_row4_col0, #T_f3029_row5_col0, #T_f3029_row6_col0, #T_f3029_row7_col0, #T_f3029_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_f3029_row0_col1, #T_f3029_row1_col1, #T_f3029_row2_col1, #T_f3029_row3_col1, #T_f3029_row4_col1, #T_f3029_row5_col1, #T_f3029_row6_col1, #T_f3029_row7_col1, #T_f3029_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_f3029_row0_col2, #T_f3029_row1_col2, #T_f3029_row2_col2, #T_f3029_row3_col2, #T_f3029_row4_col2, #T_f3029_row5_col2, #T_f3029_row6_col2, #T_f3029_row7_col2, #T_f3029_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_f3029_row0_col3, #T_f3029_row1_col3, #T_f3029_row2_col3, #T_f3029_row3_col3, #T_f3029_row4_col3, #T_f3029_row5_col3, #T_f3029_row6_col3, #T_f3029_row7_col3, #T_f3029_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_f3029_row0_col4, #T_f3029_row1_col4, #T_f3029_row2_col4, #T_f3029_row3_col4, #T_f3029_row4_col4, #T_f3029_row5_col4, #T_f3029_row6_col4, #T_f3029_row7_col4, #T_f3029_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_f3029_row0_col5, #T_f3029_row1_col5, #T_f3029_row2_col5, #T_f3029_row3_col5, #T_f3029_row4_col5, #T_f3029_row5_col5, #T_f3029_row6_col5, #T_f3029_row7_col5, #T_f3029_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_f3029">
#   <caption><strong>Data Frame Summary</strong><br>combined_data<br>Dimensions: 2,854 x 9<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_f3029_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_f3029_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_f3029_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_f3029_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_f3029_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_f3029_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3029_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f3029_row0_col1" class="data row0 col1" ><strong>Company/Brand</strong><br>[object]</td>
#       <td id="T_f3029_row0_col2" class="data row0 col2" >1. BharatPe<br>2. Zomato<br>3. MPL<br>4. Nykaa<br>5. Zetwerk<br>6. Vedantu<br>7. Trell<br>8. Spinny<br>9. Capital Float<br>10. Rebel Foods<br>11. other</td>
#       <td id="T_f3029_row0_col3" class="data row0 col3" >10 (0.4%)<br>7 (0.2%)<br>6 (0.2%)<br>6 (0.2%)<br>6 (0.2%)<br>6 (0.2%)<br>6 (0.2%)<br>6 (0.2%)<br>5 (0.2%)<br>5 (0.2%)<br>2,791 (97.8%)</td>
#       <td id="T_f3029_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f3029_row1_col1" class="data row1 col1" ><strong>Sector</strong><br>[object]</td>
#       <td id="T_f3029_row1_col2" class="data row1 col2" >1. FinTech<br>2. Healthcare<br>3. IT<br>4. E-Commerce<br>5. Education<br>6. Catering<br>7. EdTech<br>8. Financial Services<br>9. Automotive<br>10. AI<br>11. other</td>
#       <td id="T_f3029_row1_col3" class="data row1 col3" >265 (9.3%)<br>193 (6.8%)<br>185 (6.5%)<br>178 (6.2%)<br>169 (5.9%)<br>137 (4.8%)<br>119 (4.2%)<br>99 (3.5%)<br>96 (3.4%)<br>88 (3.1%)<br>1,325 (46.4%)</td>
#       <td id="T_f3029_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f3029_row2_col1" class="data row2 col1" ><strong>Stage</strong><br>[object]</td>
#       <td id="T_f3029_row2_col2" class="data row2 col2" >1. Seed<br>2. Series A<br>3. Series B<br>4. Series C<br>5. Series D<br>6. Series E<br>7. Series F<br>8. Series H<br>9. Series G<br>10. Series I</td>
#       <td id="T_f3029_row2_col3" class="data row2 col3" >1,877 (65.8%)<br>600 (21.0%)<br>156 (5.5%)<br>118 (4.1%)<br>52 (1.8%)<br>30 (1.1%)<br>13 (0.5%)<br>4 (0.1%)<br>3 (0.1%)<br>1 (0.0%)</td>
#       <td id="T_f3029_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f3029_row3_col1" class="data row3 col1" ><strong>Amount($)</strong><br>[float64]</td>
#       <td id="T_f3029_row3_col2" class="data row3 col2" >Mean (sd) : 96763981.1 (3098984217.1)<br>min < med < max:<br>0.0 < 2000000.0 < 149999992832.0<br>IQR (CV) : 6100000.0 (0.0)</td>
#       <td id="T_f3029_row3_col3" class="data row3 col3" >420 distinct values</td>
#       <td id="T_f3029_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f3029_row4_col1" class="data row4 col1" ><strong>HeadQuarter</strong><br>[object]</td>
#       <td id="T_f3029_row4_col2" class="data row4 col2" >1. Bengaluru<br>2. Mumbai<br>3. Delhi<br>4. Gurugram<br>5. Chennai<br>6. Pune<br>7. Noida<br>8. Gurgaon<br>9. Hyderabad<br>10. Jaipur<br>11. other</td>
#       <td id="T_f3029_row4_col3" class="data row4 col3" >922 (32.3%)<br>467 (16.4%)<br>436 (15.3%)<br>239 (8.4%)<br>106 (3.7%)<br>104 (3.6%)<br>86 (3.0%)<br>80 (2.8%)<br>76 (2.7%)<br>31 (1.1%)<br>307 (10.8%)</td>
#       <td id="T_f3029_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_f3029_row5_col1" class="data row5 col1" ><strong>What it does</strong><br>[object]</td>
#       <td id="T_f3029_row5_col2" class="data row5 col2" >1. BYJU'S is an educational techn<br>2. Provides online learning class<br>3. BharatPe develops a QR code-ba<br>4. Onine learning platform<br>5. Mobile Premier League is a ski<br>6. Offers techno logistics soluti<br>7. Offers a variety of bikes and <br>8. Freshtohome is an e-commerce p<br>9. Operations and manpower outsou<br>10. DealShare is a Social Commerce<br>11. other</td>
#       <td id="T_f3029_row5_col3" class="data row5 col3" >5 (0.2%)<br>5 (0.2%)<br>4 (0.1%)<br>4 (0.1%)<br>4 (0.1%)<br>3 (0.1%)<br>3 (0.1%)<br>3 (0.1%)<br>3 (0.1%)<br>3 (0.1%)<br>2,817 (98.7%)</td>
#       <td id="T_f3029_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_f3029_row6_col1" class="data row6 col1" ><strong>Founded</strong><br>[float64]</td>
#       <td id="T_f3029_row6_col2" class="data row6 col2" >Mean (sd) : 2018.1 (3.3)<br>min < med < max:<br>1963.0 < 2019.0 < 2021.0<br>IQR (CV) : 2.0 (603.1)</td>
#       <td id="T_f3029_row6_col3" class="data row6 col3" >30 distinct values</td>
#       <td id="T_f3029_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_f3029_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_f3029_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_f3029_row7_col1" class="data row7 col1" ><strong>Founders</strong><br>[object]</td>
#       <td id="T_f3029_row7_col2" class="data row7 col2" >1. nan<br>2. Seed<br>3. Un

# %% [markdown]
# This summary output revelas one duplicated entry after merging the four data sets as one. The duplicate has to be dropped.
#     Since the initial 2018 data set did not have the `Founders` and `Investor` columns, it has been filled with `nan`. The cleaned records are identified with `Unknown`

# %%
# Confirming checks for duplicate entries
combined_data.duplicated().value_counts()
# Out:
# False    2854
# dtype: int64

# %% [markdown]
# ### Visually Inspecting Missing Data

# %%
plt.figure(figsize=(10,6))
sns.heatmap(combined_data.isna(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap indicate a clustered missing values for the founders and Investors column. This is as a result of the 2018 data set not having values for this field before the data set merge.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### 1. Analysis on The `Amount($)` Column

# %%
combined_data['Amount($)'].head(20)
# Out:
# 0      250000.0
# 1     1300000.0
# 2     1300000.0
# 3     2000000.0
# 4     1300000.0
# 5     1600000.0
# 6     1300000.0
# 7     1300000.0
# 8     1300000.0
# 9     1300000.0
# 10    1300000.0
# 11    1300000.0
# 12    1300000.0
# 13    1300000.0
# 14    1300000.0
# 15    1300000.0
# 16     150000.0
# 17    1100000.0
# 18    1300000.0
# 19    1300000.0
# Name: Amount($), dtype: float64

# %%
# calculate basic statistical measures
combined_data['Amount($)'].describe()
# Out:
# count    2.854000e+03
# mean     9.676398e+07
# std      3.098984e+09
# min      0.000000e+00
# 25%      9.000000e+05
# 50%      2.000000e+06
# 75%      7.000000e+06
# max      1.500000e+11
# Name: Amount($), dtype: float64

# %% [markdown]
# The above metrics are visually inspected with a box plot below

# %%
sns.boxplot(data=combined_data, x='Amount($)')
# Out:
# <AxesSubplot:xlabel='Amount($)'>

# %% [markdown]
# There are clear outliers in the amount column after which the rest of the values are clustered together

# %%
# calculate z-scores
z_score=scipy.stats.zscore(combined_data['Amount($)'])
z_score.head(20)
# Out:
# 0    -0.031149
# 1    -0.030810
# 2    -0.030810
# 3    -0.030584
# 4    -0.030810
# 5    -0.030714
# 6    -0.030810
# 7    -0.030810
# 8    -0.030810
# 9    -0.030810
# 10   -0.030810
# 11   -0.030810
# 12   -0.030810
# 13   -0.030810
# 14   -0.030810
# 15   -0.030810
# 16   -0.031181
# 17   -0.030875
# 18   -0.030810
# 19   -0.030810
# Name: Amount($), dtype: float64

# %% [markdown]
# The z score is a type of statistical measurement that gives an idea of how far a raw score is from the mean of a distribution

# %%
# find the indices of the outliers
outliers_index = np.where(z_score >3)[0]
outliers_index
# Out:
# array([ 892, 1739], dtype=int64)

# %%
# remove the outliers
combined_data = combined_data.drop(combined_data.index[outliers_index])

# %%
sns.boxplot(data=combined_data, x='Amount($)')
# Out:
# <AxesSubplot:xlabel='Amount($)'>

# %% [markdown]
# There seem to be more outliers which has the potential of distorting the mean. The median will however be less affected

# %% [markdown]
# ### 2. Analysis of the `Stage` Column

# %%
(combined_data["Stage"].value_counts(normalize=True)*100)
# Out:
# Seed        65.743338
# Series A    21.037868
# Series B     5.469846
# Series C     4.137447
# Series D     1.823282
# Series E     1.051893
# Series F     0.455820
# Series H     0.140252
# Series G     0.105189
# Series I     0.035063
# Name: Stage, dtype: float64

# %% [markdown]
# The high count of unnknowns is as a result of the 2018 data set. The info above is in percentage terms. This is graphically represented in the graph below

# %%
   fig=sns.catplot(y="Stage",data=combined_data, kind="count", height=4, aspect=1.5)

# %% [markdown]
# ### 3. Analysis of the `Sector` Column

# %%
(combined_data["Sector"].value_counts(normalize=True)*100)
# Out:
# FinTech                        9.256662
# Healthcare                     6.767181
# IT                             6.486676
# E-Commerce                     6.241234
# Education                      5.925666
# Catering                       4.803647
# EdTech                         4.172511
# Financial Services             3.471248
# Automotive                     3.366059
# AI                             3.085554
# Media and Entertainment        2.419355
# AgTech                         2.384292
# Logistics                      2.349229
# Consumer Goods                 1.718093
# Unknown                        1.683029
# Finance                        1.683029
# Human Resources                1.647966
# Gaming                         1.647966
# Fitness                        1.612903
# Software                       1.577840
# Fashion                        1.472651
# Business Development           1.437588
# Saas                           1.297335
# Transportation                 1.122020
# Digital Media                  1.122020
# SaaS                           1.122020
# Energy                         1.086957
# Environmental Consulting       1.051893
# Insurance                      0.981767
# Hospitality                    0.946704
# Helathcare                     0.911641
# Advertising                    0.876578
# Real Estate                    0.806452
# Apps                           0.771388
# Manufacturing                  0.736325
# Cosmetics                      0.736325
# Sports                         0.701262
# Home Decor                     0.701262
# Agriculture                    0.666199
# Creative Agency                0.631136
# IoT                            0.596073
# Facilities Support Services    0.561010
# Aerospace                      0.525947
# Legal                          0.490884
# Customer Service               0.490884
# Mobile Phones                  0.420757
# ERP                            0.350631
# CleanTech                      0.315568
# Analytics                      0.315568
# Consulting                     0.315568
# Blockchain                     0.280505
# Cloud Computing                0.280505
# Biotechnology                  0.245442
# Credit Cards                   0.245442
# Construction                   0.245442
# Cryptocurrency                 0.210379
# Music Streaming                0.210379
# Child Care                     0.175316
# Crowdfunding                   0.175316
# Dating                         0.175316
# Cybersecurity                  0.140252
# Accounting                     0.140252
# Veterinary                     0.140252
# Cultural                       0.140252
# Aeorspace                      0.105189
# Mobile Payment                 0.105189
# Telecommuncation               0.105189
# Nanotechnology                 0.070126
# Mobile Payments                0.070126
# Automotive tech                0.070126
# Food                           0.070126
# Market Research                0.070126
# Telecommunication              0.035063
# Crowdsourcing                  0.035063
# Advertisement                  0.035063
# File Sharing                   0.035063
# Health                         0.035063
# Interior design                0.035063
# Ecommerce                      0.035063
# Eyewear                        0.035063
# Online Portals                 0.035063
# Search Engine                  0.035063
# Biopharma                      0.035063
# Fraud Detection                0.035063
# Trading Platform               0.035063
# Dietary Supplements            0.035063
# Government                     0.035063
# Classifieds                    0.035063
# Embedded Systems               0.035063
# Consumer Applications          0.035063
# Maritime                       0.035063
# Name: Sector, dtype: float64

# %% [markdown]
# The FinTech sector has the highest percentage of 9.2%, followed by Healthcare 6.8% etc. This is also represented graphically below

# %%
   sns.catplot(y="Sector",data=combined_data, kind="count", height=12.7, aspect=1.2)

# %% [markdown]
# Since there are about 90 different sectors, it will not be ideal to represent them all on a graph as it will not be visually appeaing, there compromising on undesrtanding. Futher analysis will sort either the top 120 or the least 10 for analysis

# %% [markdown]
# ### 4. Analysis of the Founded Column

# %%
  sns.catplot(y="Founded",data=combined_data, kind="count", height=6, aspect=1)

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### 1. Analysis of the `Founded` and `Amount($)` Columns

# %%
# Group the DataFrame by the 'Stage' column and count the occurrences of each stage
amt_stage_count = combined_data.groupby('Founded')['Amount($)'].count()
amt_stage_count.head()
# Out:
# Founded
# 1963.0    1
# 1978.0    1
# 1984.0    1
# 1989.0    2
# 1991.0    1
# Name: Amount($), dtype: int64

# %%
sns.lineplot(data=combined_data,
            y='Founded',
            x='Amount($)'
            )
# Out:
# <AxesSubplot:xlabel='Amount($)', ylabel='Founded'>

# %% [markdown]
# The graph shows that only a few start up from 2012 and beyond have received enough funding. Again the funding for start-up took a marginal increase since 2012 and has since be on a stable rise

# %% [markdown]
# ### 2. Analysis of the `Amount($)` and the `Founded` Column

# %%
sns.regplot(x='Amount($)', y='Founded', data=combined_data, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='Amount($)', ylabel='Founded'>

# %% [markdown]
# The regression graph indicated a weak and negative relationship between year of funding and amount of funding

# %%
af_correlation = combined_data[['Amount($)', 'Founded']].corr()
sns.heatmap(af_correlation, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 3. Analysis of Stage and Founded Column

# %%
   fig=sns.catplot(y="Stage",x="Founded",data=combined_data, kind="strip", height=4, aspect=1.5)

# %% [markdown]
# It is observed that the seed stage has more spread across the various years as compared to the other stages. They are clustered between 2010 and 2021

# %% [markdown]
# ### 4. Analysis of all other  Numeric Columns

# %%
sns.pairplot(combined_data, vars=None, hue='Stage', diag_kind='auto', markers='*', plot_kws=None, diag_kws=None, grid_kws=None, height=3.5,aspect=1.5)

# %% [markdown]
# ## Answering The Business Questions

# %% [markdown]
# ### Question 1. Which sector receive the most funding?

# %%
# Group the DataFrame by the 'sector' column and count the occurrences of each stage
sectoramt_count = combined_data.groupby('Sector')['Amount($)'].count().reset_index()

# # Sort the counts in descending order and select the top 10 values
top_count = sectoramt_count.sort_values(by='Amount($)', ascending=False).head(10)


# # Create the vertical bar chart
figure = plt.figure(figsize = (10, 5))
topgraph = sns.barplot(data=top_count, x='Amount($)', y='Sector',orient='h')

# Add labels and title
plt.ylabel("Sector")
plt.xlabel("Amount($)\n\n")
plt.title("Top 10 Sectors With Most Start-up Investment\n")
plt.show()

# Group the DataFrame by the 'sector' column and count the occurrences of each stage
sectoramt_count = combined_data.groupby('Sector')['Amount($)'].count().reset_index()

# # Sort the counts in descending order and select the last 10 values
bottom_count = sectoramt_count.sort_values(by='Amount($)', ascending=False).tail(10)

# # Create the vertical bar chart
figure = plt.figure(figsize = (10, 5))
bottomgraph = sns.barplot(data=bottom_count, x='Amount($)', y='Sector',orient='h')

# Add labels and title
plt.ylabel("Sector")
plt.xlabel("Amount($)")
plt.title("Bottom 10 Sectors With Most Start-up Investment\n")
plt.show()

gp=top_count = sectoramt_count.sort_values(by='Amount($)', ascending=False)

# %% [markdown]
# The two graph above confirms that the the sector or industry of the start-up can influence the funding it receives. Other varibales like the stage of the start-up might come to play. However, the sector affects the amount of funding received.
#
# The first graph which showed the top 10 indicates that most of the funding were received in technology dominated sectors.
# The second graph which show the bottom 10. indicates less difference in the sectors as most of them received similar funding

# %%
sns.catplot(data=gp, y='Sector',x='Amount($)', kind='bar', height=14, aspect=1.2)

# %% [markdown]
# ### Question 2. What is the trend of funding over the years with respect to location?

# %%
# Group the DataFrame by the 'headquater' column and count the occurrences of each stage
hqamt_grp = combined_data.groupby('HeadQuarter')['Amount($)'].sum().reset_index()

# # Sort the counts in descending order and select the top 10 values
top_grp = hqamt_grp.sort_values(by = 'Amount($)', ascending = False).head(10)

# # Create the vertical bar chart
sns.barplot(data=top_grp, x='Amount($)', y='HeadQuarter',orient='h',)

plt.ylabel("Location")
plt.xlabel("Amount($)")
plt.title("Top 10 Location With Most Start-up Investment\n")
plt.show()

# %%
# Group the DataFrame by the 'Stage' column and count the occurrences of each stage
Stageamt_grp = combined_data.groupby('Stage')['Amount($)'].sum().reset_index()

# # Sort the counts in descending order and select the top 10 values
top_grp = Stageamt_grp.sort_values(by = 'Amount($)', ascending = False).head(10)

# # Create the vertical bar chart
sns.barplot(data=top_grp, x='Amount($)', y='Stage',orient='h',)

plt.ylabel("Stage")
plt.xlabel("Amount($)")
plt.title("Top 10 Location With Most Start-up Investment\n")
plt.show()

# %% [markdown]
# The graph supports the notion that the location of the start up can  affect its funding.

# %% [markdown]
# ### Question 3. Which stage had the highest amount of funding?

# %%
# Group the DataFrame by the 'Stage' column and count the occurrences of each stage
Stageamt_grp = combined_data.groupby('Stage')['Amount($)'].sum().reset_index()

# # Sort the counts in descending order and select the top 10 values
top_grp = Stageamt_grp.sort_values(by = 'Amount($)', ascending = False).head(10)

# # Create the vertical bar chart
sns.barplot(data=top_grp, x='Amount($)', y='Stage',orient='h',)

plt.ylabel("Stage")
plt.xlabel("Amount($)")
plt.title("Top 10 Location With Most Start-up Investment\n")
plt.show()

# %% [markdown]
# The seed stage has the highest start-up investment

# %% [markdown]
# ### Question 4. Which investor makes the highest investment?

# %%
# Group the DataFrame by the 'investors' column and count the occurrences of each stage
invamt_grp = combined_data.groupby('Investor')['Amount($)'].sum().reset_index()

# # Sort the counts in descending order and select the top 10 values
invamt_grp = invamt_grp.sort_values(by = 'Amount($)', ascending = False).head(10)


figure = plt.figure(figsize = (10, 5))

# Create a bar chart using seaborn
sns.barplot(y='Investor', x='Amount($)', data=invamt_grp)

# Add labels and title
plt.ylabel("Investor")
plt.xlabel("Amount($)")
plt.title("Top 10 Investors with the Most Investment")

# Rotate y-labels by 30 degrees
#ax.set_yticklabels(ax.get_yticklabels(), rotation=30)


# set y ticks and labels
plt.xticks(rotation = 0)

# Show the plot
plt.show()

# %% [markdown]
# ### Hypothesis Testing

# %%
# # Create a variable to hold the columns on which hypothesis is to be tested
# hypothesis = pd.crosstab(combined_data['Founded'], combined_data['Amount($)'])

# # Perform the chi-square test
# p= p_value(hypothesis)
# print("P-value:", p)

# %%
# Group the DataFrame by the 'sector' column and count the occurrences of each stage
sectoramt_count = combined_data.groupby('Sector')['Amount($)'].count().reset_index()

# # Sort the counts in descending order and select the top 10 values
top_count = sectoramt_count.sort_values(by='Amount($)', ascending=False).head(5)
top_count
# Out:
#         Sector  Amount($)
# 49     FinTech        264
# 58  Healthcare        193
# 63          IT        185
# 37  E-Commerce        178
# 41   Education        169

# %%
pd.set_option('display.float_format', lambda x: '{:.0f}'.format(x))

# %%
import scipy.stats as stats

# Define the null hypothesis and alternative hypothesis
null_hypothesis = "264 is the highest"
alternative_hypothesis = "264 is not the highest"

# Collect and prepare your data
data = [264, 193, 185, 178, 169]

# Set the significance level (alpha) to 0.05
alpha = 0.05

# Conduct the one-sample t-test
t_statistic, p_value = stats.ttest_1samp(data, 10)

# Interpret the results
if p_value < alpha:
    print(f"Reject the null hypothesis: {alternative_hypothesis}")
else:
    print(f"Fail to reject the null hypothesis: {null_hypothesis}")
In this example, we define the null and alternative hypotheses, collect and prepare our data, set the significance level to 0.05, and conduct a one-sample t-test using the ttest_1samp() function from the scipy library. We then interpret the results by comparing the p-value to the significance level and printing whether we reject or fail to reject the null hypothesis.
# Out:
#   File "C:\Users\PROSPER\AppData\Local\Temp\ipykernel_8328\1368688303.py", line 21
#     In this example, we define the null and alternative hypotheses, collect and prepare our data, set the significance level to 0.05, and conduct a one-sample t-test using the ttest_1samp() function from the scipy library. We then interpret the results by comparing the p-value to the significance level and printing whether we reject or fail to reject the null hypothesis.
#        ^
# SyntaxError: invalid syntax
